# %% [markdown]
# # Generate a local copy of Wookieepedia pages for subsequent vectorisation
#
# (Best to get the web part done and can then rebuild a vector store quickly)

# %%
import requests
from bs4 import BeautifulSoup
from tqdm.auto import tqdm

import os
import re

from pathlib import Path
from collections import Counter

# %%
# Get character and location keywords to search by scanning the local copies of the 6 film scripts

all_matches, all_locations, all_likely_planets, all_likely_characters = set(), set(), set(), set()

for script in Path('scripts').iterdir():
    # if script.name == 'Episode VI - Return of the Jedi.txt':
    if script.is_file():
        print(script)
        with open(script, 'r') as file: text = file.read()
        text = re.sub(r'^[\t ]+', '', text, flags = re.MULTILINE) # No leading space
        matchesl = re.findall(r'^(?:\d+[\t ]+)?([A-Z][A-Z\.\-/ ]+[A-Z])[\t ]*(?::.+)?$', text, flags = re.MULTILINE) # All caps name-like line starts (possibly with scene number and possibly with colon and dialogue)
        print(matchesl)

        matches = set(matchesl)
        all_matches |= matches
        print(len(matches))
        print(matches)

        locations = {m[1].strip() for s in matches if (m := re.search(r'(?:INT|EXT|S )\.? ?([^-]+) ?.+', s))} # First portions of location descriptions
        all_locations |= locations
        print(locations)

        likely_planets = {k for k, n in Counter([l.split(' ')[0] for l in locations]).items() if n > 1} # Most mentioned 1-st words
        all_likely_planets |= likely_planets
        print(likely_planets)

        likely_characters = {s for s in matches if not re.search('INT|EXT|S ', s)}
        all_likely_characters |= likely_characters
        print(likely_characters)

        print()

print(len(all_matches))
print(sum(len(x) for x in [all_locations, all_likely_planets, all_likely_characters]))

matches_to_search = all_locations | all_likely_planets | all_likely_characters
# Out:
# scripts\Episode I - The Phantom Menace.txt
# ['TITLE CARD', 'INT. REPUBLIC CRUISER - COCKPIT', 'QUI-GON', 'CAPTAIN', 'QUI-GON', 'CAPTAIN', 'CAPTAIN', 'NUTE', 'INT. FEDERATION BATTLESHIP - DOCKING BAY - SPACE', 'INT. FEDERATION BATTLESHIP - CONFERENCE ROOM', 'OBI-WAN', 'QUI-GON', 'OBI-WAN', 'QUI-GON', 'OBI-WAN', 'QUI-GON', 'OBI-WAN', 'QUI-GON', 'INT. FEDERATION BATTLESHIP - BRIDGE', 'NUTE', 'DOFINE', 'INT. FEDERATION BATTLESHIP - HALLWAY', 'NUTE', 'INT. FEDERATION BATTLESHIP - BRIDGE', 'NUTE', 'RUNE', 'NUTE', 'RUNE', 'NUTE', 'RUNE', 'INT. FEDERATION BATTLESHIP - HALLWAY - OUTSIDE BRIDGE', 'INT. FEDERATION BATTLESHIP - BRIDGE', 'NUTE', 'RUNE', 'NUTE', 'RUNE', 'INT. FEDERATION BATTLESHIP - HALLWAY - OUTSIDE BRIDGE', 'QUI-GON', 'OBI-WAN', 'OBI-WAN', 'QUI-GON', 'INT. FEDERATION BATTLESHIP - BRIDGE', 'RUNE', 'TEY HOW', 'INT. FEDERATION BATTLESHIP - MAIN BAY', 'QUI-GON', 'OBI-WAN', 'QUI-GON', 'OBI-WAN', 'INT. FEDERATION BATTLESHIP - BRIDGE', 'TEY HOW', 'RUNE', 'NUTE', 'NUTE', 'AMIDALA', 'NUTE', 'AMIDALA', 'NUTE', 'AMIDALA', 'NUTE', 'AMIDALA', 'NUTE', 'AMIDALA', 'RUNE', 'NUTE', 'RUNE', 'NUTE', 'INT. NABOO PALACE - THRONE ROOM', 'PALPATINE', 'AMIDALA', 'CAPT. PANAKA', 'BIBBLE', 'CAPT. PANAKA', 'BIBBLE', 'AMIDALA', 'CAPT. PANAKA', 'AMIDALA', 'BIBBLE', 'CAPT. PANAKA', 'AMIDALA', 'EXT. NABOO SWAMP - SHALLOW LAKE - TWILIGHT', 'RUNE', 'NUTE', 'EXT. NABOO SWAMP - TWILIGHT', 'JAR JAR', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'OBI-WAN', 'QUI-GON', 'QUI-GON', 'OBI-WAN', 'JAR JAR', 'OBI-WAN', 'QUI-GON', 'JAR JAR', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'QUI-GON', 'QUI-GON', 'OBI-WAN', 'JAR JAR', 'EXT. NABOO SWAMP LAKE - TWILIGHT', 'QUI-GON', 'JAR JAR', 'JAR JAR', 'OBI-WAN', 'EXT. NABOO LAKE - UNDERWATER', 'INT. OTOH GUNGA - CITY SQUARE', 'JAR JAR', 'CAPT. TARPALS', 'JAR JAR', 'INT. OTOH GUNGA - HIGH TOWER BOARD ROOM', 'BOSS NASS', 'QUI-GON', 'BOSS NASS', 'OBI-WAN', 'BOSS NASS', 'OBI-WAN', 'BOSS NASS', 'QUI-GON', 'BOSS NASS', 'QUI-GON', 'BOSS NASS', 'QUI-GON', 'OBI-WAN', 'QUI-GON', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'OBI-WAN', 'QUI-GON', 'QUI-GON', 'BOSS NASS', 'QUI-GON', 'BOSS NASS', 'JAR JAR', 'QUI-GON', 'BOSS NASS', 'QUI-GON', 'BOSS NASS', 'JAR JAR', 'INT. SUB COCKPIT - UNDERWATER', 'JAR JAR', 'OBI-WAN', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'JAR JAR', 'OBI-WAN', 'JAR JAR', 'OBI-WAN', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'OBI-WAN', 'JAR JAR', 'QUI-GON', 'INT. FEDERATION BATTLESHIP - BRIDGE', 'NUTE', 'DARTH SIDIOUS', 'NUTE', 'DARTH SIDIOUS', 'NUTE', 'RUNE', 'NUTE', 'INT. SUB COCKPIT - UNDERWATER', 'OBI-WAN', 'QUI-GON', 'JAR JAR', 'OBI-WAN', 'JAR JAR', 'JAR JAR', 'QUI-GON', 'OBI-WAN', 'JAR JAR', 'QUI-GON', 'NUTE', 'JAR JAR', 'EXT. THEED - ESTUARY - DAY', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'OBI-WAN', 'JAR JAR', 'JAR JAR', 'QUI-GON', 'QUI-GON', 'JAR JAR', 'OBI-WAN', 'JAR JAR', 'JAR JAR', 'OBI-WAN', 'JAR JAR', 'EXT. THEED - PALACE - DAY', 'INT. THEED - PALACE THRONE ROOM - DAY', 'BIBBLE', 'NUTE', 'AMIDALA', 'NUTE', 'EXT. PALACE - PLAZA - DAY', 'JAR JAR', 'QUI-GON', 'BIBBLE', 'QUI-GON', 'CAPT. PANAKA', 'QUI-GON', 'CAPT. PANAKA', 'INT. CENTRAL HANGER - HALLWAY - DAY', 'CAPT. PANAKA', 'QUI-GON', 'AMIDALA', 'QUI-GON', 'BIBBLE', 'CAPT. PANAKA', 'QUI-GON', 'BIBBLE', 'CAPT. PANAKA', 'BIBBLE', 'AMIDALA', 'PADME', 'QUI-GON', 'AMIDALA', 'INT. CENTRAL HANGER - DAY', 'CAPT. PANAKA', 'OBI-WAN', 'GUARD DROID', 'QUI-GON', 'DROID GUARD', 'INT. NABOO SPACECRAFT - COCKPIT', 'RIC OLIE', 'INT. NABOO SPACECRAFT - DROID HOLD', 'OBI-WAN', 'JAR JAR', 'JAR JAR', 'JAR JAR', 'RIC OLIE', 'RIC OLIE', 'QUI-GON', 'OBI-WAN', 'CAPT. PANAKA', 'QUI-GON', 'CAPT. PANAKA', 'OBI-WAN', 'CAPT. PANAKA', 'QUI-GON', 'INT. FEDERATION BATTLESHIP - CONFERENCE ROOM', 'NUTE', 'DARTH SIDIOUS', 'NUTE', 'DARTH SIDIOUS', 'NUTE', 'DARTH SIDIOUS', 'DARTH SIDIOUS', 'NUTE', 'NUTE', 'RUNE', 'INT. NABOO SPACECRAFT - QUEENS CHAMBERS', 'CAPT. PANAKA', 'AMIDALA', 'CAPT. PANAKA', 'AMIDALA', 'AMIDALA', 'QUI-GON', 'CAPTAIN PANAKA', 'QUI-GON' ...
# 167
# {'WATTO', 'INT. FEDERATION BATTLESHIP - HALLWAY - OUTSIDE BRIDGE', 'EXT. MOS ESPA - STREET - DAY', 'EXT. MOS ESPA - ARENA - VIEWING PLATFORM - DAY', 'DARTH SIDIOUS', 'INT. THEED - POWER GENERATOR - MELTING PIT', 'EXT. PALACE - PLAZA - DAY', 'EXT. THEED - PALACE - DAY', 'INT. MOS ESPA - ARENA - PRIVATE BOX - DAY', 'EXT. NABOO SPACECRAFT - TATOOINE DESERT - DAY', 'RUNE', 'INT. NABOO FIGHTER - COCKPIT - SPACE', 'QUI-GON', 'OBI-WAN', 'CAPT. TARPALS', 'INT. THEED - POWER GENERATOR PIT - DAY', 'INT. THEED - PALACE THRONE ROOM - DAY', 'DARTH MAUL', 'AKS MOE', 'INT. PALACE OF THE JEDI - COUNCIL CHAMBERS - SUNSET', 'EXT. CORUSCANT - SENATE LANDING PLATFORM - NIGHT', 'EXT. THEED - PALACE - OVER WATERFALL - DAY', 'CAPTAIN PANAKA', 'PILOT', 'IRIS OUT', 'EXT. TATOOINE - DESERT MESA - NIGHT', 'EXT. CORUSCANT - BALCONY OVERLOOKING CITY - NIGHT', 'INT. CENTRAL HANGER - HALLWAY - DAY', 'KI-ADI', 'EXT. MOS ESPA - SLAVE QUARTERS - BACK YARD - SUNRISE', 'KITSTER', 'BATTLE DROID CAPTAIN', 'VALORUM', 'INT. NABOO SPACECRAFT - COCKPIT', 'EXT. MOS ESPA - STREET - MARKET - DAY', 'EXT. NABOO SWAMP - DAY', 'BRAVO THREE', 'EXT. MOS ESPA - STREET - ALCOVE - DAY', 'INT. THEED - POWER GENERATOR ELECTRIC BEAM - HALLWAY', 'EXT. THEED - CENTRAL PLAZA - DAY', 'INT. FEDERATION BATTLESHIP - DOCKING BAY - SPACE', 'INT. NABOO STARFIGHTER - COCKPIT -SPACE', 'INT. NABOO PALACE - THRONE ROOM', 'INT. ANBOO SPACECRAFT - COCKPIT', 'EXT. TATOOINE - NABOO SPACECRAFT RAMP - DAY', 'INT. THEED - PALACE - HALLWAY - DAY', 'INT. NABOO SPACECRAFT - MAIN AREA', 'EXT. TATOOINE - DESERT - SPACESHIP - DAY', 'EXT. SLAVE QUARTERS - BALCONY - NIGHT', 'INT. SPACE - NABOO SPACECRAFT COCKPIT', 'BRAVO TWO', 'ARTOO BEEPS', 'JAR JAR', 'EXT. MOS ESPA - SLAVE QUARTERS - PORCH - DAY', 'JIRA', 'EXT. MOS ESPA - ARENA - DAY', 'DROID GUARD', 'EXT. MOS ESPA - ARENA - GRANDSTAND - DAY', 'AMIDALA', 'INT. NABOO STARFIGHTER - COCKPIT - FEDERATION HANGER', 'ANAKIN', 'INT. FEDERATION BATTLESHIP - HALLWAY', 'EXT. THEED - ESTUARY - DAY', 'INT. SUB COCKPIT - UNDERWATER', 'PADME', 'INT. NABOO PALACE - THRONE ROOM - DAY', 'INT. OTOH GUNGA - HIGH TOWER BOARD ROOM', 'EXT. NABOO SWAMP LAKE - DAY', 'GENERAL CEEL', 'ANKAIN', 'SABE', 'EXT. CORUSCANT - SENATE LANDING PLATFORM - DAY', 'GUI-GON', 'INT. NABOO SPACECRAFT - MAIN HOLD', 'GREEDO', 'INT. PALPATINES QUARTERS - SUNSET', 'DOFINE', 'EXT. TATOOINE - DESERT MESA - DAY', 'MACE WINDU', 'TITLE CARD', 'LOTT DOD', 'INT. TEMPLE OF THE JEDI - COUNCIL CHAMBERS - DAY', 'EXT. MOS ESPA - STREET - SLAVE QUARTERS - DAY', 'SEBULBA', 'INT. NABOO STARFIGHTER - COCKPIT - SPACE', 'EXT. NABOO GRASS PALINS - DAY', 'FODE/BEED', 'CAPT. PANAKA', 'INT. MOS ESPA - ARENA - MAIN HANGER - DAY', 'INT. FEDERATION BATTLESHIP - MAIN BAY', 'INT. THED - PALACE THRONE ROOM - DAY', 'THREEPIO', 'SEEK', 'GUARD DROID', 'EXT. THEED - CENTRAL HANGER - DAY', 'SHMI', 'EXT. NABOO SWAMP LAKE - TWILIGHT', 'YODA', 'ASSEMBLY', 'GUARDS', 'INT. REPUBLIC CRUISER - COCKPIT', 'EXT. TATOOINE - DESERT - NABOO SPACECRAFT - DAY', 'PALAPATINE', 'MAD AMEDDA', 'VENDOR', 'FODE BEED', 'CAPTAIN', 'EXT . NABOO GRASS PLAINS DAY', 'RIC OLIE', 'INT. OTOH GUNGA - CITY SQUARE', 'INT. NABOO PALACE - THRONE ROOM - THEED - NIGHT', 'EXT. PALACE OF THE JEDI - BALCONY - SUNSET', 'GUNGAN LOOKOUT', 'EXT. MOS ESPA - JUNK DEALER PLAZA - DAY', 'INT. MAIN ROTUNDA - GALACTIC SENATE - DAY', 'EXT. NABOO SWAMP - SHALLOW LAKE - TWILIGHT', 'EXT MOS ESPA - SLAVE QUARTERS - PORCH - DAY', 'INT. MAIN HANGER - COURTYARD - DAY', 'INT. CENTRAL HANGER - DAY', 'NUTE', 'EXT. TATOOINE - STREET - SLAVE QUARTERS - DAY', 'INT. COCKPIT - SPACE', 'ANAKNI', 'INT. NABOO CRUISER COCKPIT - DAY', 'INT. FEDERATION BATTLESHIP - CONFERENCE ROOM', 'EXT. NABOO LAKE - UNDERWATER', 'WALD', 'MAS AMEDDA', 'EXT. NABOO GRASS PLAINS - DAY', 'INT. NABOO SPACECRAFT - DROID HOLD', 'EXT. MOS ESPA - DESERT RACE ARENA - DAY', 'GUARD', 'EXT. NABOO SACRED TEMPLE RUINS - DAY', 'EXT. THEED - CENTRAL PLAZA - FUNERAL TEMPLE STEPS - SUNSET', 'FANTA', 'EXT. MOS ESPA - ARENA - STARTING GRID - DAY', ...
# {'COCKPIT', 'SLAVE QUARTERS', '. NABOO GRASS PLAINS DA', 'OU', 'OTOH GUNGA', 'MAIN ROTUNDA', 'FEDERATION BATTLESHIP', 'NABOO STARFIGHTER', 'PALPATINES QUARTERS', 'NABOO GRASS PLAINS', 'PALACE OF THE JEDI', 'THEED', 'THED', 'ANBOO SPACECRAFT', 'NABOO SWAMP', 'NABOO SPACECRAFT', 'NAS', 'MOS ESPA', 'SUB COCKPIT', 'NABOO PALACE', 'NABOO SACRED TEMPLE RUINS', 'CENTRAL HANGER', 'REPUBLIC CRUISER', 'TURRET ROOM', 'TATOOINE', 'NABOO SWAMP LAKE', 'TEMPLE OF THE JEDI', 'SPACE', 'PALACE', 'NABOO GRASS PALINS', 'NABOO FIGHTER', 'CORUSCANT', 'NABOO LAKE', 'NABOO EDGE OF SWAMP/ GRASS PLAINS', 'NABOO CRUISER COCKPIT', 'MAIN HANGER', 'MO', 'AMEDD'}
# {'MAIN', 'NABOO', 'PALACE'}
# {'MACE WINDU', 'TITLE CARD', 'LOTT DOD', 'WATTO', 'NUTE', 'ANAKNI', 'DARTH SIDIOUS', 'SEBULBA', 'WALD', 'GUARD', 'BRAVO TWO', 'FODE/BEED', 'CAPT. PANAKA', 'ARTOO BEEPS', 'JAR JAR', 'RUNE', 'FANTA', 'QUI-GON', 'OBI-WAN', 'THREEPIO', 'SEEK', 'CAPT. TARPALS', 'JIRA', 'GUARD DROID', 'PANAKA', 'SHMI', 'DARTH MAUL', 'YODA', 'DROID GUARD', 'PILOT', 'CAPTAIN PANAKA', 'ASSEMBLY', 'GUARDS', 'AMEE', 'FIGHTER PILOT', 'AMIDALA', 'PALAPATINE', 'MAD AMEDDA', 'BIBBLE', 'ANAKIN', 'VENDOR', 'PADME', 'ANAKN', 'KI-ADI', 'FODE BEED', 'BATTLE DROID CAPTAIN', 'KITSTER', 'PALPATINE', 'CAPTAIN', 'VALORUM', 'BAIL ORGANA', 'RIC OLIE', 'BRAVO THREE', 'JABBA', 'GUNGAN LOOKOUT', 'ODY', 'GENERAL CEEL', 'ANKAIN', 'SABE', 'GUI-GON', 'GREEDO', 'FOUR', 'RABE', 'TEY HOW', 'DOFINE'}
#
# scripts\Episode II - Attack of the Clones.txt
# ['EXT. SPACE', 'CAPTAIN TYPHO', 'PADM', 'CORD', 'AMIDALA', 'AMIDALA', 'CAPTAIN TYPHO', 'CAPTAIN TYPHO', 'EXT. SENATE BUILDING - DAY', 'INT. SENATE CHAMBER - DAY', 'MAS AMEDDA', 'PALPATINE', 'PALPATINE', 'SENATOR ASK AAK', 'AMBASSADOR DARSANA', 'ORN FREE TAA', 'PALPATINE', 'AMIDALA', 'PALPATINE', 'PADM', 'PADM', 'PADM', 'ORN FREE TAA', 'PALPATINE', 'EXT. EXECUTIVE QUARTERS BUILDING - DAY', 'PALPATINE', 'MACE WINDU', 'PALPATINE', 'MACE WINDU', 'PALPATINE', 'YODA', 'PALPATINE', 'MACE WINDU', 'YODA', 'DAR WAC', 'PALPATINE', 'YODA', 'PADM', 'MACE WINDU', 'PADM', 'MACE WINDU', 'KI-ADI-MUNDI', 'YODA', 'PALPATINE', 'PADM', 'PALPATINE', 'BAIL ORGANA', 'PADM', 'PALPATINE', 'PADM', 'PALPATINE', 'MACE WINDU', 'PALPATINE', 'PADM', 'PALPATINE', 'MACE WINDU', 'YODA', 'PALPATINE', 'EXT. SENATE APARTMENTS - TWILIGHT', 'JAR JAR', 'OBI-WAN', 'JAR JAR', 'JAR JAR', 'ANAKIN', 'JAR JAR', 'JAR JAR', 'OBI-WAN', 'PADM', 'OBI-WAN', 'PADM', 'ANAKIN', 'PADM', 'OBI-WAN', 'CAPTAIN TYPHO', 'PADM', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'PADM', 'CAPTAIN TYPHO', 'JAR JAR', 'ANAKIN', 'JAR JAR', 'OBI-WAN', 'ANAKIN', 'EXT. JEDI TEMPLE - EVENING', 'MACE WINDU', 'YODA', 'MACE WINDU', 'YODA', 'MACE WINDU', 'YODA', 'MACE WINDU', 'YODA', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'EXT. SENATE APARTMENTS - ENTRANCE - NIGHT', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'ANAKIN', 'EXT. ENTERTAINMENT STREET - NIGHT', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'INT. NIGHTCLUB - NIGHT', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ELAN SLEAZEBAGGANO', 'OBI-WAN', 'ELAN', 'OBI-WAN', 'ELAN', 'ANAKIN', 'EXT. ALLEY OUTSIDE NIGHTCLUB - NIGHT', 'OBI-WAN', 'ZAM WESSEL', 'OBI-WAN', 'ZAM WESSEL', 'ANAKIN', 'ZAM WESSEL', 'OBI-WAN', 'ANAKIN', 'ZAM', 'OBI-WAN', 'PADM', 'JAR JAR', 'PADM', 'JAR JAR', 'PADM', 'JAR JAR', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADME', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'CAPTAIN TYPHO', 'PADM', 'DORME', 'PADM', 'DORME', 'PADM', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'PADM', 'ANAKIN', 'PADM', 'OBI-WAN', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'OBI-WAN', 'CAPTAIN TYPHO', 'EXT. FREIGHTER DOCKS - CORUSCANT - DAY', 'OBI-WAN', 'OBI-WAN', 'OBI-WAN', 'SERVER', 'FOOD SERVER', 'ANAKIN', 'ANAKIN', 'PADM', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'ANAKIN', 'PADM', 'ANAKIN', 'HERMIONE', 'OBI-WAN', 'HERMIONE BAGWA', 'OBI-WAN', 'HERMIONE BAGWA', 'DEXTER JETTSTER', 'OBI-WAN', 'DEXTER JETTSTER', 'HERMIONE BAGWA', 'OBI-WAN', 'DEXTER JETTSTER', 'OBI-WAN', 'DEXTER JETTSTER', 'OBI-WAN', 'DEXTER JETTSTER', 'DEXTER JETTSTER', 'OBI-WAN', 'DEXTER JETTSTER', 'OBI-WAN', 'DEXTER JETTSTER', 'OBI-WAN', 'DEXTER JETTSTER', 'OBI-WAN', 'DEXTER JETTSTER', 'OBI-WAN', 'DEXTER JETTSTER', 'EXT. NABOO SPACEPORT - DAY', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'QUEEN JAMILLIA', 'PADM', 'SIO BIBBLE', 'QUEEN JAMILLIA', 'PADM', 'SIO  ...
# 84
# {'ORN FREE TAA', 'WATTO', 'RUWEE', 'DARTH SIDIOUS', 'INT. GUNSHIP NUMBER ONE - DAY', 'OWEN', 'OBI-WAN', 'DORME', 'JANGO FETT', 'SUN RIT', 'MACE', 'KI-ADI-MUNDI', 'ZAM WESSEL', 'CLONE CAPTAIN', 'LAMA SU', 'THE END', 'EXT. NABOO LAKE RETREAT - NIGHT', 'PLO KOON', 'CORD', 'COUNT DOOKU', 'OBI-WAM', 'QUEEN JAMILLIA', 'WINDU', 'CAPTAIN TYPHO', 'EXT. SENATE APARTMENTS - ENTRANCE - NIGHT', 'HERMIONE', 'EXT. SENATE APARTMENTS - TWILIGHT', 'BERU', 'JEDI CHILD JACK', 'ELAN SLEAZEBAGGANO', 'EXT. FREIGHTER DOCKS - CORUSCANT - DAY', 'ARTOO BEEPS', 'JAR JAR', 'EXT. JEDI TEMPLE - DAY', 'BOBA FETT', 'JOCASTA NU', 'AMIDALA', 'ZAM', 'ANAKIN', 'SOLA', 'INT. NIGHTCLUB - NIGHT', 'PADME', 'BOBA', 'SENATOR ASK AAK', 'PADM', 'SIO BIBBLE', 'AMBASSADOR DARSANA', 'EXT. JEDI TEMPLE - EVENING', 'MACE WINDU', 'MACE-WINDU', 'SERVER', 'CHILDREN', 'EXT. ALLEY OUTSIDE NIGHTCLUB - NIGHT', 'ELAN', 'EXT. NABOO SPACEPORT - DAY', 'THREEPIO', 'SHMI', 'YODA', 'EXT. SENATE BUILDING - DAY', 'DROID CAPTAIN', 'DEXTER JETTSTER', 'DAR WAC', 'CLIEGG', 'PAMDE', 'INT. GEONOSIS TUNNEL TO EXECUTION ARENA - DAY', 'JANGO', 'NUTE GUNRAY', 'INT. GUNSHIP NUMBER TWO - DAY', 'JOVAL', 'MAS AMEDDA', 'JEDI CHILD MAY', 'EXT. SPACE', 'HERMIONE BAGWA', 'INT. SENATE CHAMBER - DAY', 'JOBAL', 'EXT. ENTERTAINMENT STREET - NIGHT', 'TAUN WE', 'DOOKU', 'PALPATINE', 'POGGLE', 'BAIL ORGANA', 'INT. TUSKEN RAIDER HUTT - NIGHT', 'FOOD SERVER', 'EXT. EXECUTIVE QUARTERS BUILDING - DAY'}
# {'AMEDD', 'SENATE BUILDING', 'ENTERTAINMENT STREET', 'FREIGHTER DOCKS', 'GEONOSIS TUNNEL TO EXECUTION ARENA', 'GUNSHIP NUMBER TWO', 'SENATE APARTMENTS', 'GUNSHIP NUMBER ONE', 'JEDI TEMPLE', 'ER JETTSTE', 'TUSKEN RAIDER HUTT', 'SENATE CHAMBER', 'EXECUTIVE QUARTERS BUILDING', 'NABOO LAKE RETREAT', 'NABOO SPACEPORT', 'ALLEY OUTSIDE NIGHTCLUB', 'NIGHTCLUB', 'SPAC'}
# {'GUNSHIP', 'SENATE', 'NABOO'}
# {'MACE WINDU', 'CAPTAIN TYPHO', 'MACE-WINDU', 'WATTO', 'ORN FREE TAA', 'SERVER', 'HERMIONE', 'CHILDREN', 'DARTH SIDIOUS', 'RUWEE', 'BERU', 'JEDI CHILD JACK', 'ELAN SLEAZEBAGGANO', 'JEDI CHILD MAY', 'OWEN', 'ARTOO BEEPS', 'JAR JAR', 'ELAN', 'OBI-WAN', 'DORME', 'THREEPIO', 'JANGO FETT', 'SUN RIT', 'SHMI', 'YODA', 'HERMIONE BAGWA', 'MACE', 'DROID CAPTAIN', 'BOBA FETT', 'JOBAL', 'JOCASTA NU', 'AMIDALA', 'ZAM', 'KI-ADI-MUNDI', 'ANAKIN', 'DAR WAC', 'TAUN WE', 'ZAM WESSEL', 'CLONE CAPTAIN', 'SOLA', 'CLIEGG', 'PAMDE', 'PADME', 'BOBA', 'LAMA SU', 'DOOKU', 'THE END', 'PALPATINE', 'POGGLE', 'BAIL ORGANA', 'PLO KOON', 'JANGO', 'SENATOR ASK AAK', 'PADM', 'CORD', 'SIO BIBBLE', 'FOOD SERVER', 'COUNT DOOKU', 'AMBASSADOR DARSANA', 'OBI-WAM', 'NUTE GUNRAY', 'QUEEN JAMILLIA', 'JOVAL', 'WINDU'}
#
# scripts\Episode III - Revenge of the Sith.txt
# ['EXT. SPACE', 'INT. ANAKINS STARFIGHTER COCKPIT-SPACE', 'ANAKIN', 'OBI-WAN', 'EXT. CORUSCANT-SPACE BATTLE', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'ANAKIN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ODD BALL', 'OBI-WAN', 'ODD BALL', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ODD BALL', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'ANAKIN', 'ODD BALL', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'INT. BRIDGE-TRADE FEDERATION CRUISER', 'GENERAL GRIEVOUS', 'CAPTAIN', 'GENERAL GRIEVOUS', 'INT. HANGAR-TRADE FEDERATION CRUISER', 'BODYGUARD I', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'INT. GENERATOR ROOM-TRADE FEDERATION CRUISER', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'INT. VENT SHAFT-TRADE FEDERATION CRUISER', 'ANAKIN', 'INT. SMALL PASSAGEWAY-TRADE FEDERATION CRUISER', 'INT. HALLWAY-TRADE FEDERATION CRUISER', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'INT. VENT SHAFT-TRADE FEDERATION CRUISER', 'INT. GENERATOR ROOM-TRADE FEDERATION CRUISER', 'EXT. TRADE FEDERATION CRUISER-BATTLE', 'INT. HALLWAY-TRADE FEDERATION CRUISER', 'OBI-WAN', 'INT. WIDE HALLWAY-TRADE FEDERATION CRUISER', 'ANAKIN', 'BATTLE DROID', 'INT HANGAR-TRADE FEDERATION CRUISER', 'INT. ELEVATOR-TRADE FEDERATION CRUISER', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'INT MAIN HANGAR-TRADE FEDERATION CRUISER', 'INT. ELEVATOR-TRADE FEDERATION CRUISER', 'OBI-WAN', 'OBI-WAN', 'INT MAIN HANGAR-TRADE FEDERATION CRUISER', 'OBI-WAN', 'INT. ELEVATOR SHAFT-TRADE FEDERATION CRUISER', 'INT. ELEVATOR-TRADE FEDERATION CRUISER', 'OBI-WAN', 'INT. ELEVATOR SHAFT-TRADE FEDERATION CRUISER', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'OBI-WAN', 'INT. ELEVATOR-TRADE FEDERATION CRUISER', 'OBI-WAN', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'INT. ELEVATOR-TRADE FEDERATION CRUISER', 'OBI-WAN', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'INT. ELEVATOR SHAFT-TRADE FEDERATION CRUISER', 'OBI-WAN', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'INT. ELEVATOR SHAFT-TRADE FEDERATION CRUISER', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'OBI-WAN', 'ANAKIN', 'PALPATINE', 'OBI-WAN', 'ANAKIN', 'PALPATINE', 'OBI-WAN', 'COUNT DOOKU', 'OBI-WAN', 'COUNT DOOKU', 'ANAKIN', 'COUNT DOOKU', 'COUNT DOOKU', 'COUNT DOOKU', 'PALPATINE', 'ANAKIN', 'PALPATINE', 'ANAKIN', 'PALPATINE', 'ANAKIN', 'ANAKIN', 'PALPATINE', 'PALPATINE', 'ANAKIN', 'PALPATINE', 'ANAKIN', 'INT. BRIDGE-TRADE FEDERATION CRUISER', 'GENERAL GRIEVOUS', 'PILOT', 'INT. BATTLESTATIONS-REPUBLIC CRUISER', 'ANAKIN', 'ANAKIN', 'ANAKIN', 'INT. BRIDGE-TRADE FEDERATION CRUISER', 'PILOT', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'INT. BRIDGE-TRADE FEDERATION CRUISER', 'PILOT', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'EXT. SPACE-CORUSCANT', 'ANAKIN', 'INT. BRIDGE-TRADE FEDERATION CRUISER', 'GENERAL GRIEVOUS', 'PILOT', 'INT. ELEVATOR SHAFT ON SIDE-TRADE FEDERATION CRUISER', 'ANAKIN', 'OBI-WAN', 'ANAKINN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'INT. ELEVATOR LOBBY-TRADE FEDERATION CRUISER', 'OBI-WAN', 'ANAKIN', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'INT. HALLWAY TO HANGAR BAY-TRADE FEDERATION CRUISER', 'INT. DOORW ...
# 201
# {'INT. JEDI GUNSHIP-LANDING PLATFORM-EARLY EVENING', 'EXT. UTAPAU-UNDERWATER SINKHOLE-DAY', 'EXT. MUSTAFAR-LANDING PLATFORM-NABOO SKIFF-DAY', 'DARTH SIDIOUS', 'INT HANGAR-TRADE FEDERATION CRUISER', 'INT. VENT SHAFT-TRADE FEDERATION CRUISER', 'CLONE COMMANDER BACARA', 'CLONE COMMANDER APPO', 'EXT. DAGOBAH-DAY', 'EXT. IMPERIAL STAR DESTROYER-SPACE', 'EXT. CORUSCANT-CLONE LANDING PLATFORM-DAY', 'ROYAL GUARD', 'FANG ZAR', 'CAPTAIN ANTILLES', 'GIDDEAN DANU', 'INT. POLIS MASSA-MEDICAL CENTER-DREAM', 'INT. UTAPAU-LANDING PLATFORM-HALLWAY-DAY', 'QUI-GON', 'EXT. UTAPAU-OBSERVATION DECK-DAY', 'OBI-WAN', 'INT. CORUSCANT-JEDI TEMPLE-BRIEFING ROOM-DAY', 'EXT. CORUSCANT-SENATE OFFICE BUILDING-NIGHT', 'EXT. MYGEETO-DAWN', 'MACE', 'EXT. MUSTAFAR-JEDI STARFIGHTER-SPACE', 'INT. CORUSCANT-JEDI TEMPLE ENTRY-NIGHT', 'PILOT', 'BANA BREEMU', 'EXT. MUSTAFAR-MAIN CONTROL CENTER BALCONY-DAY', 'EXT. UTAPAU STAIRWAY-SINKHOLE RIM-DAY', 'EXT. UTAPAU-WINDMILLS-DAY', 'ANAKINN', 'INT. UTAPAU-CITY TUNNEL SYSTEM-DAY', 'EXT. SPACE-CORUSCANT', 'CLONE CAPTAIN', 'CLONE COMMANDER THIRE', 'EXT. MUSTAFAR-LAVA FIELDS-DAY', 'AT-ST CLONE SERGEANT', 'EXT. MUSTAFAR-VOLCANO EDGE-DAY', 'AAYLA', 'INT. DOORWAY TO HANGAR BAY-TRADE FEDERATION CRUISER', 'EXT. NABOO-MAIN SQUARE-DAWN', 'PLO KOON', 'INT. MUSTAFAR-PASSAGES TO MAIN CONTROL CENTER-DAY', 'INT. UTAPAU-CITY-DRAGON CORRAL-DAY', 'COUNT DOOKU', 'EXT. CORUSCANT-SENATE OFFICE BUILDING-LANDING PLATFORM-LATE AFTERNOON', 'EXT. CORUSCANT-SENATE OFFICE BUILDING-LANDING PLATFORM-EARLY EVENING', 'INT. CORUSCANT-SENATE OFFICE BUILDING-WIRING CHUTE-NIGHT', 'EXT. HULL-TRADE FEDERATION CRUISER-SPACE', 'EXT. JEDI FIGHTER-SPACE', 'INT. ALDERAAN-STARCRUISER-HALLWAY-DAY', 'EXT. CORUSCANT-SPACE BATTLE', 'CAPTAIN TYPHO', 'MOTEE', 'INT. ALDERAAN STARCRUISER-HALLWAY- SPACE', 'QUI -GON', 'CLONE SERGEANT', 'INT. UTAPAU-TENTH LEVEL-CONTROL CENTER-DAY', 'JAR JAR', 'CREATURE', 'INT. CORUSCANT-JEDI TEMPLE-CONTROL CENTER-NIGHT', 'INT. CORUSCANT-JEDI TEMPLE-HALLWAY-SUNSET', 'WRANGLER', 'INT. CORUSCANT-JEDI TEMPLE-YODAS QUARTERS-DAY', 'EXT. UTAPAU-CLIFF AND LANDING PLATFORM-DAY', 'EXT. KASHYYYK-DAY', 'INT. ESCAPE POD-SPACE', 'INT. HANGAR-TRADE FEDERATION CRUISER', 'RUNE HAAKO', 'EXT. NABOO-ALDERAAN STARCRUISER', 'EXT. UTAPAU-MAIN CITY PLAZA-DAY', 'EXT. UTAPAU-SINKHOLE WALL-LIZARD-DAY', 'INT. WIDE HALLWAY-TRADE FEDERATION CRUISER', 'EXT. MUSTAFAR-LANDING PLATFORM-NABOO CRUISER-DAY', 'EXT. KASHYYYK-MEETING HALL-DAY', 'ANAKIN', 'INT. CORUSCANT-JEDI TEMPLE-HALLWAY OUTSIDE COUNCIL CHAMBERS-DAY', 'BLY', 'PADME', 'INT. CORUSCANT-SENATE OFFICE BUILDING-MAIN HALLWAY-DAY', 'EXT. CORUSCANT-SENATE OFFICE BUILDING-SUNSET', 'EXT. MUSTAFAR-LANDING PLATFORM-IMPERIAL SHUTTLE-DAY', 'EXT. KASHYYYK-LAKE ON VILLAGE EDGE-DUSK', 'BAIL', 'EXT. CORUSCANT-CITYSCAPE-PRE-DAWN', 'INT. ALDERAAN CRUISER-CONFERENCE ROOM', 'EXT. UTAPAU-SPACE', 'INT. MUSTAFAR-COXFERENCE ROOM-DAY', 'INT. REPUBLIC BATTLE CRUISER-HANGAR-SPACE', 'EXT. KASHYYYK-BEACH HEAD-DAY', 'INT. MUSTAFAR-MAIN CONTROL CENTER-HALLWAY-DAY', 'INT. CORUSCANT-IMPERIAL REHAB CENTER-DAY', 'EXT. TRADE FEDERATION CRUISER-BATTLE', 'EXT. CORUSCANT-JEDI TEMPLE-LANDING PLATFORM-PRE-DAWN', 'INT. UTAPAU-CONFERENCE ROOM-GRAND CHAMBER-DAY', 'MACE WINDU', 'INT. CORUSCANT-CHANCELLOR S OFFICE-EARLY EVENING', 'INT. KASHYYYK-HOLOGRAM AREA-DAY', 'EXT. MUSTAFAR-COLLECTION PANELS-DAY', 'INT. POD BAY-TRADE FEDERATION CRUISER-SPACE', 'INT. CORUSCANT-JEDI TEMPLE-COMPUTER ROOM-NIGHT', 'EXT. LANDING PLATFORM-CORUSCANT-IMPERIAL REHAB CENTER-DAY', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'INT. CORUSCANT-JEDI TEMPLE-MASSIVE MAIN HALLWAY AND ALCOVE-LATE AFTERNOON', 'INT. CORUSCANT-SENATE CHAMBER-MAIN ARENA-NIGHT', 'ODD BALL', 'INT. SMALL PASSAGEWAY-TRADE FEDERATION CRUISER', 'EXT. SALEUCAMI-FOREST', 'TERR TANEEL', 'CLONE PILOT', 'SUPER BATTLE DROID', 'EXT. KASHYYYK-EDGE OF VILIAGE-DAY', 'THREEPIO', 'EXT. ALDERAAN-STARCRUISER-SPACE', 'INT. POLIS MASSA-OBSERVATION DOME-NIGHT', 'YODA', 'EXT. BRIDGE-TRADE FEDERATION CRUISER', 'INT. CORUSCANT-GALAXIES OPER ...
# {'GENERATOR ROOM', 'KASHYYYK', 'SALEUCAMI', 'HANGAR', 'HALLWAY', 'CATO XEIMOIDIA', 'UTAPAU', 'JEDI GUNSHIP', 'TRADE FEDERATION CRUISER', 'MYGEETO', 'POD BAY', 'ELEVATOR SHAFT', 'REPUBLIC BATTLE CRUISER', 'CRUISER', 'DOORWAY TO HANGAR BAY', 'NABOO SKIF', 'HANGAR DOORWAY', 'POLIS MASSA', 'ESCAPE POD', 'SMALL PASSAGEWAY', 'ELEVATOR LOBBY', 'NABOO', 'FELUCIA', 'BRIDGE', 'ELEVATOR', 'ANAKINS STARFIGHTER COCKPIT', 'HULL', 'TATOOINE', 'CATO NEIMOIDIA', 'ALDERAAN CRUISER', 'ALDERAAN STARCRUISER', 'VENT SHAFT', 'WIDE HALLWAY', 'MUSTAFAR', 'SPACE', 'SPAC', 'DAGOBAH', 'HALLWAY TO HANGAR BAY', 'LANDING PLATFORM', 'CORUSCANT', 'IMPERIAL STAR DESTROYER', 'ELEVATOR SHAFT ON SIDE', 'ALDERAAN', 'MAIN HANGAR', 'JEDI FIGHTER', 'AMEDD', 'UTAPAU STAIRWAY', 'BATTLESTATIONS'}
# {'ELEVATOR', 'HANGAR', 'HALLWAY', 'CATO', 'UTAPAU', 'ALDERAAN', 'JEDI', 'NABOO'}
# {'MACE WINDU', 'CAPTAIN TYPHO', 'MOTEE', 'DABTH SIDIOUS', 'DARTH SIDIOUS', 'DARTH VADER', 'QUI -GON', 'CLONE COMMANDER BACARA', 'CLONE COMMANDER APPO', 'CLONE SERGEANT', 'BODYGUARD I', 'GUARD', 'ROYAL GUARD', 'ODD BALL', 'CAPTAIN ANTILLES', 'FANG ZAR', 'GIDDEAN DANU', 'JAR JAR', 'TERR TANEEL', 'CREATURE', 'CLONE PILOT', 'QUI-GON', 'SUPER BATTLE DROID', 'OBI-WAN', 'THREEPIO', 'WRANGLER', 'YODA', 'MACE', 'PILOT', 'BANA BREEMU', 'RUNE HAAKO', 'YOUNGLINGS', 'ANAKIN/OBI-WAN', 'CLONE TROOPER', 'FANGZAR', 'ANAKIN', 'ANAKINN', 'BODYGUARD', 'CLONE CAPTAIN', 'CLONE COMMANDER THIRE', 'BLY', 'PADME', 'CLONE COMMANDER CODY', 'AT-ST CLONE SERGEANT', 'CHI EEKWAY', 'BAIL', 'GENERAL GRIEVOUS', 'AAYLA', 'CAPTAIN', 'PALPATINE', 'BAIL ORGANA', 'PLO KOON', 'MEDICAL DROID', 'CLONE COMMANDER GREE', 'COUNT DOOKU', 'NUTE GUNRAY', 'BATTLE DROID', 'MON MOTHMA'}
#
# scripts\Episode IV - A New Hope.txt
# ['STAR WARS', 'A NEW HOPE', 'JOURNAL OF THE WHILLS', 'INT. REBEL BLOCKADE RUNNER - MAIN PASSAGEWAY', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'EXT. SPACECRAFT IN SPACE', 'INT. REBEL BLOCKADE RUNNER', 'THREEPIO', 'EXT. TATOOINE - DESERT WASTELAND - DAY', 'LUKE', 'INT. REBEL BLOCKADE RUNNER - MAIN HALLWAY', 'INT. REBEL BLOCKADE RUNNER', 'INT. REBEL BLOCKADE RUNNER', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'INT. REBEL BLOCKADE RUNNER - CORRIDOR', 'IMPERIAL OFFICER', 'VADER', 'VADER', 'REBEL OFFICER', 'VADER', 'VADER', 'INT. REBEL BLOCKADE RUNNER - SUBHALLWAY', 'TROOPER', 'TROOPER', 'INT. REBEL BLOCKADE RUNNER - SUBHALLWAY', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'INT. IMPERIAL STARDESTROYER', 'CHIEF PILOT', 'CAPTAIN', 'INT. LIFEPOD', 'THREEPIO', 'THREEPIO', 'EXT. TATOOINE - ANCHORHEAD SETTLEMENT - POWER STATION - DAY', 'WOMAN', 'INT. POWER STATION - DAY', 'FIXER', 'CAMIE', 'LUKE', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'DEAK', 'DAY', 'LUKE', 'BIGGS', 'LUKE', 'LUKE', 'CAMIE', 'FIXER', 'INT. REBEL BLOCKADE RUNNER - HALLWAY', 'LEIA', 'VADER', 'LEIA', 'VADER', 'COMMANDER', 'VADER', 'COMMANDER', 'VADER', 'SECOND OFFICER', 'VADER', 'COMMANDER', 'EXT. SPACE', 'EXT. TATOOINE - DESERT', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'EXT. TATOOINE - DUNE SEA', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'EXT. TATOOINE - ANCHORHEAD SETTLEMENT - POWER STATION - DAY', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'EXT. TATOOINE - ROCK CANYON - SUNSET', 'EXT. TATOOINE - ROCK CANYON - SANDCRAWLER - SUNSET', 'INT. SANDCRAWLER - HOLD AREA', 'INT. SANDCRAWLER - PRISON AREA', 'THREEPIO', 'EXT. TATOOINE - ROCK CANYON - SANDCRAWLER - SUNSET', 'EXT. TATOOINE - DESERT - DAY', 'FIRST TROOPER', 'SECOND TROOPER', 'EXT. TATOOINE - DUNES', 'INT. SANDCRAWLER', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'EXT. TATOOINE - DESERT - LARS HOMESTEAD - AFTERNOON', 'BERU', 'LUKE', 'OWEN', 'THREEPIO', 'OWEN', 'THREEPIO', 'OWEN', 'THREEPIO', 'OWEN', 'THREEPIO', 'OWEN', 'LUKE', 'OWEN', 'LUKE', 'LUKE', 'OWEN', 'LUKE', 'OWEN', 'THREEPIO', 'LUKE', 'OWEN', 'LUKE', 'OWEN', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'INT. LARS HOMESTEAD - GARAGE AREA - LATE AFTERNOON', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'LEIA', 'LUKE', 'THREEPIO', 'LEIA', 'THREEPIO', 'LUKE', 'THREEPIO', 'LEIA', 'THREEPIO', 'LUKE', 'THREEPIO', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'LUKE', 'THREEPIO', 'LUKE', 'LUKE', 'LUKE', 'THREEPIO', 'AUNT BERU', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'INT. LARS HOMESTEAD - DINING AREA', 'LUKE', 'OWEN', 'LUKE', 'LUKE', 'OWEN', 'LUKE', 'OWEN', 'LUKE', 'OWEN', 'LUKE', 'OWEN', 'LUKE', 'OWEN', 'OWEN', 'LUKE', 'OWEN', 'LUKE', 'AUNT BERU', 'LUKE', 'AUNT BERU', 'OWEN', 'AUNT BERU', 'OWEN', 'EXT. TATOOINE - LARS HOMESTEAD', 'INT. LARS HOMESTEAD - GARAGE', 'LUKE', 'THREEPIO', 'LUKE', 'EXT. TATOOINE - LARS HOMESTEAD', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'OWEN', 'LUKE', 'LUKE', 'THREEPIO', 'INT. LARS HOMESTEAD - PLAZA', 'OWEN', 'INT. LARS HOMESTEAD - KITCHEN', 'OWEN', 'AUNT BERU', 'OWEN', 'AUNT BERU', 'OWEN', 'DAY', 'LUKE', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'EXT. TATOOINE - ROCK MESA - DUNE SEA - COASTLINE - DAY', 'EXT. TATOOINE - ROCK MESA - CANYON', 'EXT. TATOOINE - ROCK CANYON - FLOOR', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'LUKE', 'THREEPIO', 'LUKE', 'EXT. TATOOINE - ROCK CANYON - RIDGE - DAY', 'LUKE', 'EXT. TATOOINE - ROCK CANYON - FLOOR - DAY', 'BEN', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'BEN', 'LUKE', 'EXT. TATOOINE - SAND PIT - ROCK  ...
# 191
# {'DODONNA', 'DAY', 'EXT. TIE FIGHTER', 'CHIEF', 'STAR WARS', 'INT. MILLENNIUM FALCON - MAIN PASSAGEWAY', 'INT. MASSASSI - WAR ROOM BRIEFING AREA', 'EXT. SPACE - PLANET TATOOINE', 'OWEN', 'REBEL OFFICER', 'GANTRY OFFICER', 'INT. MILLENNIUM FALCON - PASSAGEWAY', 'INT. REBEL BLOCKADE RUNNER - MAIN HALLWAY', 'EXT. DEATH STAR TRENCH', 'EXT. SPACECRAFT IN SPACE', 'INT. X-WING FIGHTER - COCKPIT - TRAVELING', 'RED SEVEN', 'EXT. TIE FIGHTER - SPACE', 'FIXER', 'EXT. TATOOINE - DESERT - LARS HOMESTEAD - AFTERNOON', 'SECOND OFFICER', 'EXT. TATOOINE - DUNE SEA', 'INT. DEATH STAR - UNUSED HALLWAY', 'GOLD FIVE', 'READ LEADER', 'INT. REBEL BLOCKADE RUNNER - SUBHALLWAY', 'INT. MOS EISLEY - CANTINA', 'OFFICER CASS', 'JOURNAL OF THE WHILLS', 'A NEW HOPE', 'INT. MASSASSI OUTPOST - WAR ROOM', 'MASSASSI INTERCOM VOICE', 'EXT. MASSASSI OUTPOST - JUNGLE', 'EXT. DEATH STAR SURFACE - GUN EMPLACEMENTS', 'THE END', 'SPACE', 'EXT. SPACE AROUND THE DEATH STAR', 'EXT. DEATH STAR', 'INT. ANOTHER COCKPIT', 'TROOPER', 'SPEEDER LOT', 'EXT. TATOOINE - DUNES', 'RED LEADER', 'RED ELEVEN', 'WILLARD', 'EXT. SPACE - ANOTHER ANGLE', 'INT. MILLENNIUM FALCON - CHEWBACCA', 'FIRST OFFICER', 'EXT. SPACE - DEATH STAR TRENCH', 'INT. MASSASSI OUTPOST - MAIN HANGAR', 'INT. MASSASSI OUTPOST - MAIN THRONE ROOM', 'BERU', 'INT. IMPERIAL STARDESTROYER', 'DEATH STAR INTERCOM VOICE', 'CHIEF PILOT', 'INT. LARS HOMESTEAD - GARAGE', 'INT. DEATH STAR - HALLWAY LEADING TO MAIN FORWARD BAY', 'INT. DEATH STAR - HALLWAY', 'INT. MILLENNIUM FALCON - GUNPORT', 'GOLD LEADER', 'RED TEN', 'EXT. TATOOINE - MOS EISLEY - STREET - ALLEYWAY - USED', 'CREATURE', 'EXT. DEATH STAR - HUGE PORT DOORS', 'INT. DEATH STAR', 'INTERCOM VOICE', 'BEN', 'INT. DEATH STAR - CELL ROW', 'INT. RED LEADER STARSHIP - COCKPIT', 'TARKIN', 'INT. MILLENNIUM FALCON - GUNPORTS', 'MOTTI', 'COMMANDER', 'INT. TATOOINE - MOS EISLEY - CANTINA', 'INT. DEATH STAR - DETENTION AREA - HALLWAY', 'CONTROL OFFICER', 'RED NINE', 'INT. DEATH STAR - MAIN HALLWAY', 'LEIA', 'EXT. MASSASSI OUTPOST', 'INT. LARS HOMESTEAD - KITCHEN', 'VOICE OVER DEATH STAR INTERCOM', 'EXT. TATOOINE - ROCK CANYON - FLOOR - DAY', 'INT. REBEL BLOCKADE RUNNER - HALLWAY', 'INT. DETENTION AREA', 'CAMIE', 'VOICE', 'EXT. TATOOINE - SAND PIT - ROCK MESA - DAY', 'INT. MILLENNIUM FALCON - COCKPIT - GUNPORTS', 'BASE VOICE', 'INT. DEATH STAR - MAIN BAY GANTRY - CONTROL TOWER', 'WEDGE', 'TECHNICIAN', 'INT. MILLENNIUM FALCON - GUNPORTS - COCKPIT', 'AREA', 'INT. DEATH STAR - CONFERENCE ROOM', 'EXT. MILLENNIUM FALCON - IN SPACE', 'INT. REBEL BLOCKADE RUNNER - CORRIDOR', 'EXT. TATOOINE - MOS EISLEY - STREETS', 'EXT. TATOOINE - DESERT WASTELAND - DAY', 'EXT. SPACE - MILLENNIUM FALCON/TIE FIGHTERS', 'EXT. DEATH STAR SURFACE', 'WINGMAN', 'GREEDO', 'PORKINS', 'INT. MILLENNIUM FALCON', 'INT. TIE FIGHTER - COCKPIT', 'EXT. SPACE AROUND FOURTH MOON OF YAVIN', 'INT. LARS HOMESTEAD - DINING AREA', 'EXT. TATOOINE - WASTELAND', 'EXT. SPACE - MILLENNIUM FALCON', 'EXT. TATOOINE - ROCK CANYON - RIDGE - DAY', 'INT. DEATH STAR - NARROW PASSAGEWAY', 'INT. DEATH STAR - CENTRAL CORE SHAFT', 'EXT. TATOOINE - DESERT - DAY', 'INT. LIFEPOD', 'IMPERIAL OFFICER', 'INT. MILLENNIUM FALCON - CENTRAL HOLD AREA', 'INT. DEATH STAR - FORWARD BAY - COMMAND OFFICE', 'THREEPIO', 'EXT. YAVIN - JUNGLE', 'INT. DEATH STAR - MAIN FORWARD BAY', 'EXT. FOURTH MOON OF YAVIN', 'EXT. TATOOINE - ROCK CANYON - SUNSET', 'EXT. SURFACE OF THE DEATH STAR', 'EXT. SURFACE AROUND THE DEATH STAR', 'EXT. DEATH STAR - GUN EMPLACEMENTS', 'INT. DEATH STAR - MAIN FORWARD BAY - SERVICE PANEL', 'WOMAN', 'HUMAN', 'INT. SANDCRAWLER - HOLD AREA', 'EXT. TATOOINE - ROCK CANYON - SANDCRAWLER - SUNSET', 'TAGGE', 'INT. DEATH STAR - GARBAGE ROOM', 'INT. MILLENNIUM FALCON - HALLWAY', 'CAPTAIN', 'INT. LARS HOMESTEAD - GARAGE AREA - LATE AFTERNOON', 'BIGGS', 'EXT. SURFACE OF DEATH STAR', 'INT. DEATH STAR - DOCKING BAY', 'HAN', 'EXT. HYPERSPACE', 'INT. DEATH STAR - BLAST CHAMBER', 'INT. MASSASSI OUTPOST - MAIN HANGAR DECK', 'INT. MASSASSI - MAIN HANGAR DECK' ...
# {'TIE FIGHTE', 'DEATH STA', 'TIE FIGHTER', 'MOS EISLEY', 'MASSASSI OUTPOST', 'MILLENNIUM FALCON', 'X', 'FOURTH MOON OF YAVI', 'YAVIN', 'SANDCRAWLER', 'SPACE AROUND THE DEATH STA', 'MASSASSI', 'OVER STAR', 'DEATH STAR SURFAC', 'IMPERIAL STARDESTROYE', 'HYPERSPAC', 'DEATH STAR', 'MILLENNIUM FALCO', 'SANDCRAWLE', 'SPACECRAFT IN SPAC', 'ERCOM VOIC', 'RED LEADER STARSHIP', 'DETENTION ARE', 'TATOOINE', 'LARS HOMESTEAD', 'POWER STATION', 'LIFEPO', 'ERCO', 'SURFACE OF THE DEATH STA', 'SPACE AROUND THE DEATH STAR', 'REBEL BLOCKADE RUNNE', 'SPACE', 'SPAC', 'DOCKING PORT ENTRY', 'REBEL BLOCKADE RUNNER', 'DEATH STAR TRENC', 'DEATH STAR SURFACE', 'SURFACE AROUND THE DEATH STA', 'SPACE AROUND FOURTH MOON OF YAVI', 'SURFACE OF DEATH STA', 'MASSASSI OUTPOS', 'ANOTHER COCKPI'}
# {'DEATH', 'TIE', 'SURFACE', 'MILLENNIUM', 'MASSASSI', 'SPACE', 'REBEL'}
# {'DODONNA', 'DAY', 'VADER', 'FIRST OFFICER', 'CHIEF', 'STAR WARS', 'BERU', 'OWEN', 'CHIEF PILOT', 'REBEL OFFICER', 'GOLD LEADER', 'RED TEN', 'GANTRY OFFICER', 'IMPERIAL OFFICER', 'CREATURE', 'BARTENDER', 'GOLD TWO', 'THREEPIO', 'BEN', 'RED SEVEN', 'ASTRO-OFFICER', 'FIXER', 'TARKIN', 'SECOND OFFICER', 'GOLD FIVE', 'READ LEADER', 'PORKINS', 'MOTTI', 'COMMANDER', 'CONTROL OFFICER', 'WOMAN', 'OFFICER CASS', 'RED NINE', 'LUKE', 'HUMAN', 'JOURNAL OF THE WHILLS', 'LEIA', 'A NEW HOPE', 'TAGGE', 'SECOND TROOPER', 'THE END', 'CAMIE', 'SPACE', 'VOICE', 'BASE VOICE', 'TECHNICIAN', 'CAPTAIN', 'WEDGE', 'BIGGS', 'AUNT BERU', 'DEAK', 'FIRST TROOPER', 'HAN', 'AREA', 'JABBA', 'TROOPER', 'SPEEDER LOT', 'RED LEADER', 'RED ELEVEN', 'OFFICER', 'WILLARD', 'WINGMAN', 'GREEDO', 'TROOPER VOICE'}
#
# scripts\Episode V - The Empire Strikes Back.txt
# ['THE EMPIRE STRIKES BACK', 'EXT. GALAXY - PLANET HOTH', 'EXT. HOTH - METEORITE CRATER - SNOW PLAIN - DAY', 'EXT. PLAIN OF HOTH - DAY', 'LUKE', 'HAN', 'LUKE', 'HAN', 'LUKE', 'LUKE', 'LUKE', 'EXT. HOTH - REBEL BASE ENTRANCE - DAY', 'INT. HOTH - REBEL BASE - MAIN HANGAR DECK', 'HAN', 'HAN', 'INT. HOTH - REBEL BASE - COMMAND CENTER', 'RIEEKAN', 'HAN', 'RIEEKAN', 'HAN', 'RIEEKAN', 'HAN', 'RIEEKAN', 'HAN', 'RIEEKAN', 'HAN', 'HAN', 'LEIA', 'HAN', 'INT. HOTH - REBEL BASE - ICE CORRIDOR', 'LEIA', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'INT. HOTH - REBEL BASE - ANOTHER ICE CORRIDOR', 'THREEPIO', 'THREEPIO', 'INT. HOTH - REBEL BASE - MAIN HANGAR DECK', 'HAN', 'THREEPIO', 'HAN', 'THREEPIO', 'HAN', 'THREEPIO', 'HAN', 'THREEPIO', 'HAN', 'THREEPIO', 'HAN', 'THREEPIO', 'HAN', 'THREEPIO', 'DECK OFFICER', 'HAN', 'DECK OFFICER', 'HAN', 'DECK OFFICER', 'THREEPIO', 'HAN', 'THREEPIO', 'INT. HOTH - REBEL BASE - MAIN ICE TUNNEL', 'DECK OFFICER', 'HAN', 'DECK OFFICER', 'HAN', 'DECK OFFICER', 'HAN', 'ASSISTANT OFFICER', 'DECK OFFICER', 'HAN', 'EXT. HOTH - ICE GORGE - DUSK', 'EXT. HOTH - ENTRANCE TO ICE GORGE - DUSK', 'EXT. HOTH - SNOW PLAIN - DUSK', 'THREEPIO', 'THREEPIO', 'EXT. HOTH - SNOW DRIFT - DUSK', 'INT. REBEL BASE - MAIN HANGAR DECK - ENTRANCE - NIGHT', 'LIEUTENANT', 'THREEPIO', 'DERLIN', 'DERLIN', 'LIEUTENANT', 'THREEPIO', 'THREEPIO', 'EXT. HOTH - SNOW DRIFT - DUSK', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'HAN', 'HAN', 'LUKE', 'HAN', 'LUKE', 'HAN', 'LUKE', 'HAN', 'LUKE', 'HAN', 'EXT. HOTH - SNOWDRIFT - DAWN', 'INT. SNOWSPEEDER COCKPIT', 'ZEV', 'EXT. HOTH - SNOWDRIFT', 'INT. SNOWSPEEDER - COCKPIT', 'ZEV', 'HAN', 'ZEV', 'EXT. HOTH - SNOWDRIFT - DAY', 'INT. REBEL BASE - MEDICAL CENTER', 'INT. REBEL BASE - MEDICAL CENTER - RECOVERY ROOM', 'THREEPIO', 'THREEPIO', 'HAN', 'LUKE', 'HAN', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'HAN', 'LEIA', 'HAN', 'LEIA', 'ANNOUNCER', 'HAN', 'THREEPIO', 'INT. HOTH - REBEL BASE - COMMAND CENTER', 'RIEEKAN', 'RIEEKAN', 'SENIOR CONTROLLER', 'LEIA', 'HAN', 'SENIOR CONTROLLER', 'THREEPIO', 'HAN', 'RIEEKAN', 'EXT. HOTH - SNOW PLAIN - DAY', 'INT. HOTH - REBEL BASE - COMMAND CENTER', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'RIEEKAN', 'EXT. SPACE - IMPERIAL FLEET', 'PIETT', 'OZZEL', 'PIETT', 'OZZEL', 'PIETT', 'OZZEL', 'PIETT', 'VADER', 'PIETT', 'VADER', 'OZZEL', 'VADER', 'INT. HOTH - REBEL BASE - TRANSPORT BAY', 'REBEL CAPTAIN', 'REBEL FIGHTER', 'INT. HOTH - REBEL BASE - MAIN HANGAR DECK', 'HAN', 'INT. REBEL BASE - MEDICAL CENTER', 'MEDICAL DROID', 'LUKE', 'MEDICAL DROID', 'LUKE', 'INT. REBEL BASE - MAIN HANGAR DECK', 'LUKE', 'HAN', 'LUKE', 'HAN', 'LUKE', 'CONTROLLER', 'RIEEKAN', 'VADER', 'VEERS', 'VADER', 'VEERS', 'VADER', 'VEERS', 'OZZEL', 'VADER', 'PIETT', 'VADER', 'PIETT', 'INT. REBEL BASE - MAIN HANGAR DECK', 'LEIA', 'HOBBIE', 'LEIA', 'PILOTS', 'LEIA', 'DERLIN', 'EXT. HOTH - ICE PLAIN - SNOW TRENCH - DAY', 'EXT. HOTH - ICE PLAIN - POWER GENERATORS', 'INT. REBEL BASE - COMMAND CENTER', 'RIEEKAN', 'EXT. ICE PLAIN', 'EXT. SPACE - IMPERIAL STAR DESTROYER', 'INT. IMPERIAL STAR DESTROYER - BRIDGE', 'CONTROLLER', 'CAPTAIN', 'INT. REBEL BASE - COMMAND CENTER', 'WOMAN CONTROLLER', 'EXT. REBEL BASE ICE CAVE - ION CANNON', 'EXT. SPACE - HOTH - REBEL TRANSPORT', 'INT. REBEL BASE - MAIN HANGAR DECK', 'ANNOUNCER', 'DACK', 'LUKE', 'DACK', 'LUKE', 'EXT. HOTH - ICE PLAIN', 'EXT. HOTH - ICE PLAIN - SNOW TRENCH', 'TRENCH OFFICER', 'INT. REBEL BASE - CORRIDOR', 'TRENCH OFFICER', 'CONTROLLER', 'EXT. HOTH - ICE PLAIN - SNOW TRENCH', 'LUKE', 'EXT. HOTH - ICE PLAIN - BATTLEFIELD', 'LUKE', 'DACK', 'LUKE', 'EXT. HOTH - ICE PLAIN - BATTLEFIELD', 'LUKE', 'LUKE', 'EXT. HOTH - ICE PLAIN - BATTLEFIELD', 'EXT. HOTH - ICE PLAIN - SNOWTRENCH', 'EXT. HOTH - ICE PLAIN - BATTLEFIELD', 'INT. IMPERIAL SNOW WALKER - COCKPIT', 'LUKE', 'LUKE', 'DACK', 'LUKE', 'EXT. HOTH - ICE PLAIN - BATTLEFIELD', 'LUKE', 'EXT. HOTH - ICE PLAIN - SNOW TRENCH AREA', 'EXT. HOTH - ICE PLAIN - B ...
# 178
# {'EXT. SPACE - REBEL STAR CRUISER', 'SECOND THREEPIO', 'INT. REBEL BASE - MEDICAL CENTER - RECOVERY ROOM', 'VEERS', 'INT. CLOUD CITY - JUNK ROOM', 'EXT. SPACE - REBEL CRUISER', 'REBEL CAPTAIN', 'EXT. ASTEROID CAVE - MILLENNIUM FALCON', 'TRENCH OFFICER', 'TRACKING OFFICER', 'EXT. SPACE - IMPERIAL STAR DESTROYER', 'INT. ASTEROID CAVE - MILLENNIUM FALCON - COCKPIT', 'SECOND CONTROLLER', 'EXT. BESPIN SYSTEM - MILLENNIUM FALCON - DAWN', 'EXT. HOTH - ICE PLAIN - POWER GENERATORS', 'SECOND OFFICER', 'PILOT', 'PILOTS', 'EXT. HOTH - SNOW PLAIN - DUSK', 'OZZEL', 'INT. HOTH - REBEL BASE - MAIN ICE TUNNEL', 'INT. GANTRY - OUTSIDE CONTROL ROOM - REACTOR SHAFT', 'INT. REBEL BASE - MAIN HANGAR DECK - ENTRANCE - NIGHT', 'EXT. CLOUD CITY - LANDING PLATFORM - DUSK', 'DISSOLVE TO', 'INT. REACTOR SHAFT', 'EXT. HOTH - SNOWDRIFT', 'EXT. HOTH - ICE PLAIN - SNOWTRENCH', 'INT. MAIN HANGAR - MILLENNIUM FALCON - COCKPIT', 'INT. MILLENNIUM FALCON - MAIN HOLD AREA', 'INT. CLOUD CITY - CORRIDOR LEADING TO LANDING PLATFORM', 'EXT. CLOUD CITY - LANDING PLATFORM', 'THE END', 'EXT. MILLENNIUM FALCON - BOTTOM OF CLOUD CITY', 'INT. EXHAUST PIPE', 'INT. GIANT ASTEROID CRATER', 'INT. CLOUD CITY - CARBON-FREEZING CHAMBER - ANTEROOM', 'EXT. HOTH - REBEL BASE ENTRANCE - DAY', 'EXT. DAGOBAH - CAVE - DUSK', 'STRANGE VOICE', 'EXT. HOTH - ICE PLAIN - SNOW TRENCH', 'EXT. ICE PLAIN', 'EXT. DAGOBAH - BOG CLEARING - DUSK', 'EXT. BOTTOM OF CLOUD CITY', 'EXT. SPACE - MILLENNIUM FALCON - ASTEROID FIELD', 'INT. HOTH - REBEL BASE - TRANSPORT BAY', 'DECK OFFICER', 'INT. STAR CRUISER - MEDICAL CENTER', 'EXT. DAGOBAH - BOG - DUSK', 'EXT. HOTH - ICE PLAIN - BATTLEFIELD', 'EXT. HOTH - BATTLEFIELD - ICE PLAIN', 'INT. CLOUD CITY - CARBON-FREEZING CHAMBER', 'EXT. SPACE - MILLENNIUM FALCON - TIE FIGHTERS - STAR DESTROYER', 'EXT. BESPIN SURFACE - MILLENNIUM FALCON', 'INT. IMPERIAL SNOW WALKER - COCKPIT', 'INT. ASTEROID CAVE - MILLENNIUM FALCON - HOLD AREA', 'LIEUTENANT', 'INT. CLOUD CITY - LIVING QUARTERS - DAY', 'EXT. REBEL BASE ICE CAVE - ION CANNON', 'CREATURE', 'INT. CLOUD CITY - CORRIDOR - DAY', 'INTERCOM VOICE', 'EXT. HOTH - METEORITE CRATER - SNOW PLAIN - DAY', 'BEN', 'INT. CLOUD CITY - DINING ROOM', 'EXT. HOTH - ICE PLAIN - SNOW TRENCH - DAY', 'EXT. DAGOBAH - DAY', 'EXT. SPACE - MILLENNIUM FALCON - STAR DESTROYERS', 'BOBA FETT', 'EXT. SPACE - PLANET DAGOBAH', 'DACK', 'EXT. HOTH - ICE PLAIN - SNOW TRENCH AREA', 'ASSISTANT OFFICER', 'LEIA', 'EXT. HOTH - SNOW PLAIN - DAY', 'EXT. SPACE - MILLENNIUM FALCON - TIE FIGHTERS', 'INT. REBEL BASE - CORRIDOR', 'EXT. SPACE - IMPERIAL FLEET', 'INT. MILLENNIUM FALCON - HOLD', 'WEDGE', 'CONTROLLER', 'INT. HOTH - REBEL BASE - ICE CORRIDORS', 'END CREDITS FADE IN AND OUT OVER BACKGROUND', 'EXT. MILLENNIUM FALCON - ASTEROID BELT', 'EXT. MAIN HANGAR - MILLENNIUM FALCON', 'INT. CLOUD CITY - PRISON ENTRY AREA', 'INT. CLOUD CITY - ANTEROOM', 'EXT. BOTTOM OF CLOUD CITY - WEATHER VANE - DUSK', 'EXT. GALAXY - SPACE', 'INT. MILLENNIUM FALCON', 'INT. HOTH - REBEL BASE - COMMAND CENTER', 'INT. HOTH - REBEL BASE - MAIN HANGAR DECK', 'INT. HOTH - REBEL BASE - ICE CORRIDOR', 'EXT. HOTH - SNOWDRIFT - DAY', 'EXT. SPACE - MILLENNIUM FALCON', 'EXT. MILLENNIUM FALCON - GIANT ASTEROID CRATER', 'PIETT', 'WOMAN CONTROLLER', 'EXT. BOTTOM OF CLOUD CITY - WEATHER VANE', 'NEEDA', 'INT. CLOUD CITY - TUNNEL AND REACTOR CONTROL ROOM', 'INT. STAR DESTROYER - BRIDGE', 'IMPERIAL OFFICER', 'INT. SPACE SLUG MOUTH', 'THREEPIO', 'EXT. SPACE - STAR DESTROYERS - ASTEROID FIELD', 'INT. MAIN HANGAR - MILLENNIUM FALCON - MAIN HOLD', 'EXT. HOTH - ENTRANCE TO ICE GORGE - DUSK', 'YODA', 'SENIOR CONTROLLER', 'HEAD CONTROLLER', 'REBEL FIGHTER', 'EXT. BATTLEFIELD - SNOW TRENCH', 'EXT. MILLENNIUM FALCON - GIANT ASTEROID', 'INT. CLOUD CITY - HALLWAY LEADING TO ANTEROOM', 'FIRST CONTROLLER', 'ANNOUNCER', 'EXT. SPACE - STAR DESTROYER - ASTEROID BELT', 'EXT. HOTH - SNOWDRIFT - DAWN', 'CAPTAIN', 'ZEV', 'EXT. CLOUD CITY - MILLENNIUM FALCON - DUSK', 'HAN', 'RIEEKAN', 'EXT. PLAIN OF HOTH - DAY', 'INT. DAG ...
# {'BESPIN SYSTEM', 'CAVE ENTRANCE', 'SNOWSPEEDER COCKPI', 'EAST LANDING PLATFORM', 'PLAIN OF HOTH', 'SNOWSPEEDER', 'MILLENNIUM FALCON', 'FADE IN AND OUT OVER BACKGROUN', 'HOTH', 'BESPIN SURFACE', 'ICE PLAI', 'REACTOR SHAF', 'BOTTOM OF CLOUD CITY', 'STAR DESTROYER', 'BATTLEFIELD', 'GANTRY', 'GALAXY', 'MILLENNIUM FALCO', 'SPACE SLUG MOUT', 'ERCOM VOIC', 'OFFICE', 'BOTTOM OF CLOUD CIT', 'ASTEROID BELT', 'BAC', 'REBEL BASE', 'SPACE', 'SPAC', 'DAGOBAH', 'LANDING PLATFORM', 'GIANT ASTEROID CRATE', 'CLOUD CITY', 'EXHAUST PIP', 'IMPERIAL STAR DESTROYER', 'STAR CRUISER', 'MAIN HANGAR', 'ASTEROID CAVE', 'REBEL BASE ICE CAVE', 'IMPERIAL SNOW WALKER'}
# {'BESPIN', 'STAR', 'BOTTOM', 'SNOWSPEEDER', 'MILLENNIUM', 'IMPERIAL', 'ASTEROID', 'SPACE', 'REBEL'}
# {'VADER', 'SECOND THREEPIO', 'DECK OFFICER', 'VEERS', 'IMPERIAL SOLDIER', 'PIETT', 'REBEL CAPTAIN', 'WOMAN CONTROLLER', 'TRENCH OFFICER', 'NEEDA', 'LIEUTENANT', 'TRACKING OFFICER', 'IMPERIAL OFFICER', 'CREATURE', 'THREEPIO', 'SECOND CONTROLLER', 'BEN', 'YODA', 'SENIOR CONTROLLER', 'SECOND OFFICER', 'BOBA FETT', 'PILOT', 'HEAD CONTROLLER', 'PILOTS', 'REBEL FIGHTER', 'DACK', 'OZZEL', 'EMPEROR', 'HOBBIE', 'ASSISTANT OFFICER', 'DISSOLVE TO', 'LUKE', 'LEIA', 'FIRST CONTROLLER', 'ANNOUNCER', 'THE END', 'CAPTAIN', 'ZEV', 'WEDGE', 'CONTROLLER', 'HAN', 'MEDICAL DROID', 'DERLIN', 'RIEEKAN', 'STRANGE VOICE', 'OFFICER', 'LANDO', 'JANSON'}
#
# scripts\Episode VI - Return of the Jedi.txt
# ['RETURN', 'OF THE', 'JEDI', 'SPACE', 'RETURN OF THE JEDI', 'INT IMPERIAL SHUTTLE - COCKPIT', 'SHUTTLE CAPTAIN', 'SHUTTLE CAPTAIN', 'INT DEATH STAR - CONTROL ROOM', 'OFFICER', 'OPERATOR', 'INT DEATH STAR - MAIN DOCKING BAY', 'JERJERROD', 'VADER', 'JERJERROD', 'VADER', 'JERJERROD', 'VADER', 'JERJERROD', 'VADER', 'VADER', 'JERJERROD', 'VADER', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'STRANGE VOICE', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'BIB', 'THREEPIO', 'BIB', 'THREEPIO', 'THREEPIO', 'BIB', 'THREEPIO', 'THREEPIO', 'JABBA', 'THREEPIO', 'LUKE', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'INT DUNGEON CORRIDOR', 'THREEPIO', 'INT BOILER ROOM', 'NINEDENINE', 'THREEPIO', 'NINEDENINE', 'THREEPIO', 'NINEDENINE', 'THREEPIO', 'NINEDENINE', 'THREEPIO', 'NINEDENINE', 'JABBA', 'OOLA', 'JABBA', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'BOUSHH', 'THREEPIO', 'INT DUNGEON CORRIDOR AND CELL', 'BOUSHH', 'BOUSHH', 'HAN', 'BOUSHH', 'HAN', 'BOUSHH', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'HAN', 'HAN', 'HAN', 'LEIA', 'LEIA', 'THREEPIO', 'INT DUNGEON CELL', 'HAN', 'HAN', 'HAN', 'HAN', 'HAN', 'HAN', 'LUKE', 'LUKE', 'LUKE', 'LUKE', 'THREEPIO', 'BIB', 'BIB', 'LUKE', 'LUKE', 'LUKE', 'THREEPIO', 'JABBA', 'INT RANCOR PIT', 'THREEPIO', 'HOLDING TUNNEL - RANCOR PIT', 'INT RANCOR PIT', 'INT THRONE ROOM', 'LUKE', 'HAN', 'LUKE', 'HAN', 'LUKE', 'HAN', 'LUKE', 'HAN', 'LEIA', 'THREEPIO', 'HAN', 'THREEPIO', 'THREEPIO', 'HAN', 'LUKE', 'EXT TATOOINE SEA - SKIFF', 'HAN', 'LUKE', 'HAN', 'LUKE', 'HAN', 'INT BARGE OBSERVATION DECK', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'EXT SARLACC PIT', 'EXT SAIL BARGE OBSERVATION DECK', 'THREEPIO', 'EXT SKIFF', 'HAN', 'LUKE', 'INT SAIL BARGE OBSERVATION DECK', 'EXT BARGE - UPPER DECK', 'EXT SKIFF - PLANK', 'EXT SARLACC PIT', 'INT SAIL BARGE', 'EXT SKIFF', 'LUKE', 'LANDO', 'EXT UPPER DECK - SAIL BARGE', 'EXT SKIFF', 'HAN', 'HAN', 'LANDO', 'HAN', 'HAN', 'INT SAIL BARGE', 'EXT SKIFF', 'HAN', 'LANDO', 'HAN', 'HAN', 'HAN', 'HAN', 'LANDO', 'HAN', 'HAN', 'LANDO', 'HAN', 'LANDO', 'HAN', 'EXT UPPER DECK', 'INT SAIL BARGE - OBSERVATION DECK', 'LEIA', 'THREEPIO', 'EXT UPPER DECK - SAIL BARGE', 'LUKE', 'THREEPIO', 'LUKE', 'EXT SKIFF', 'LUKE', 'LANDO', 'EXT SAND DUNE', 'EXT DUNE SEA', 'EXT DUNE SEA - LANDING AREA', 'HAN', 'LEIA', 'HAN', 'HAN', 'LUKE', 'HAN', 'LANDO', 'LEIA', 'LANDO', 'INT X-WING - COCKPIT', 'LUKE', 'LUKE', 'LUKE', 'EXT SPACE - DEATH STAR AND ENDOR', 'INT DEATH STAR - CORRIDOR TO DOCKING BAY', 'INT DOCKING BAY - DEATH STAR', 'VADER', 'EMPEROR', 'VADER', 'EMPEROR', 'VADER', 'EMPEROR', 'YODA', 'LUKE', 'YODA', 'LUKE', 'YODA', 'LUKE', 'YODA', 'LUKE', 'LUKE', 'YODA', 'LUKE', 'YODA', 'YODA', 'LUKE', 'YODA', 'LUKE', 'LUKE', 'YODA', 'YODA', 'EXT DAGOBAH SWAMP - X-WING', 'LUKE', 'LUKE', 'LUKE', 'BEN', 'BEN', 'BEN', 'BEN', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'EXT SPACE - REBEL FLEET', 'INT HEADQUARTERS FRIGATE - MAIN BRIEFING ROOM', 'HAN', 'LANDO', 'HAN', 'MON MOTHMA', 'MON MOTHMA', 'ACKBAR', 'HAN', 'HAN', 'ACKBAR', 'GENERAL MADINE', 'THREEPIO', 'GENERAL MADINE', 'HAN', 'HAN', 'LEIA', 'LEIA', 'HAN', 'LUKE', 'THREEPIO', 'INT HEADQUARTERS FRIGATE - MAIN DOCKING BAY', 'HAN', 'LANDO', 'LANDO', 'LANDO', 'HAN', 'INT IMPERIAL SHUTTLE - COCKPIT', 'HAN', 'LUKE', 'HAN', 'LEIA', 'HAN', 'HAN', 'LUKE', 'THREEPIO', 'HAN', 'EXT SPACE - THE REBEL FLEET', 'VADER', 'EMPEROR', 'VADER', 'EMPEROR', 'VADER', 'EXT SPACE - DEATH STAR - MOON', 'INT STOLEN IMPERIAL SHUTTLE - COCKPIT', 'HAN', 'HAN', 'HAN', 'LEIA', 'HAN', 'LUKE', 'HAN', 'HAN', 'LUKE', 'HAN', 'VADER', 'VADER', 'PIETT', 'PIETT', 'VADER', 'INT STOLEN IMPERIAL SHUTTLE - COCKPIT', 'HAN', 'HAN', 'EXT SPACE - STOLEN IMPERIAL SHUTTLE - ENDOR', 'EXT FOREST LANDING SITE - ENDOR', 'THREEPIO', 'LEIA', 'HAN', 'EXT FOREST CLEARING - CAMPSITE', 'HAN', 'LUKE', 'LEIA', 'LUKE', 'HAN', 'EXT FOREST - THE BIKE CHASE', 'LUKE', 'LUKE', 'LUKE', 'ANOTHER PART OF  ...
# 122
# {'EXT DAGOBAH SWAMP - X-WING', 'INT BUNKER - MAIN CONTROL ROOM', 'EXT FOREST CLEARING - CAMPSITE', 'EXT SPACE - IMPERIAL FLEET', 'EXT BUNKER', 'SECOND COMMANDER', 'JEDI', 'CONTROL ROOM COMMANDER', 'NINEDENINE', 'ACKBAR', 'SHUTTLE CAPTAIN', 'INT SAIL BARGE', 'EXT SPACE - STOLEN IMPERIAL SHUTTLE - ENDOR', 'INT DOCKING BAY - DEATH STAR', 'EXT FOREST - GENERATOR BUNKER', 'OPERATOR', 'SCOUT', 'PILOT', 'INT DUNGEON CORRIDOR', 'INT MILLENNIUM FALCON - COCKPIT', 'END CREDITS OVER STAR FIELD', 'SPACE', 'RED THREE', 'EXT FOREST - SERIES OF SHOTS', 'RED TWO', 'STRANGE VOICE', 'EXT IMPERIAL LANDING PLATFORM - LOWER DECK', 'EXT SPACE - REBEL FLEET', 'EXT FOREST WALKWAY - MOON FOREST', 'EXT SPACE - THE REBEL FLEET', 'EXT BUNKER - ENTRANCE', 'GREEN LEADER', 'NAVIGATOR', 'INT MILLENNIUM FALCON - COCKPIT AND GUN PORTS', 'EXT FOREST - DENSE FOLIAGE', 'INT REBEL STAR CRUISER - BRIDGE', 'BEN', 'GENERAL MADINE', 'EXT UPPER DECK - SAIL BARGE', 'EXT FOREST - IMPERIAL LANDING PLATFORM', 'INT BOILER ROOM', 'LURE', 'EXT EWOK VILLAGE SQUARE - NIGHT', 'EXT SAND DUNE', 'COMMANDER', 'INT DEATH STAR - MAIN DOCKING BAY', 'ANAKIN', 'LEIA', 'EXT SAIL BARGE OBSERVATION DECK', 'EXT TATOOINE SEA - SKIFF', 'INT STOLEN IMPERIAL SHUTTLE - COCKPIT', 'JERJERROD', 'WEDGE', 'INT HEADQUARTERS FRIGATE - MAIN DOCKING BAY', 'CONTROLLER', 'EXT/INT - SPACE BATTLE - FIGHTER AND DEATH STAR', 'INT X-WING - COCKPIT', 'INT THRONE ROOM', 'EXT ENDOR FOREST - NIGHT', 'EXT BARGE - UPPER DECK', 'HOLDING TUNNEL - RANCOR PIT', 'EXT SPACE - DEATH STAR AND ENDOR', 'EXT SPACE - AIR BATTLE', 'PIETT', 'EXT SKIFF - PLANK', 'INT SAIL BARGE - OBSERVATION DECK', 'EXT FOREST - THE BIKE CHASE', 'THREEPIO', 'EXT SARLACC PIT', 'YODA', 'INT IMPERIAL SHUTTLE - COCKPIT', 'INT DUNGEON CELL', 'EXT ENDOR FOREST', 'EXT DUNE SEA', 'ANOTHER PART OF THE FOREST', 'EXT UPPER DECK', 'OOLA', 'HAN', 'OF THE', 'OFFICER', 'BIB', 'BOUSHH', 'VADER', 'INT HEADQUARTERS FRIGATE - MAIN BRIEFING ROOM', 'INT BUNKER - CONTROL ROOM', 'EXT ENDOR - RIDGE OVERLOOKING CONTROL BUNKER', 'GUARD', 'Y-WING PILOT', 'BUNKER COMMANDER', 'INT DEATH STAR - CONTROL ROOM', 'INT SAIL BARGE OBSERVATION DECK', 'FADE OUT', 'RETURN', 'EXT SPACE', 'INT DUNGEON CORRIDOR AND CELL', 'GRAY LEADER', 'RETURN OF THE JEDI', 'STORMTROOPER', 'INT SUPER STAR DESTROYER - BRIDGE', 'EXT SPACE - DEATH STAR SHIELD', 'EXT SPACE - DEATH STAR - MOON', 'EXT RIDGE', 'EXT FOREST LANDING SITE - ENDOR', 'INT DEATH STAR - CORRIDOR TO DOCKING BAY', 'EMPEROR', 'INT BARGE OBSERVATION DECK', 'LUKE', 'REBEL PILOT', 'EXT FOREST', 'EXT DUNE SEA - LANDING AREA', 'INT DEATH STAR - BLAST CHAMBER', 'EXT SCOUT CAMPSITE - FOREST', 'EXT DEATH STAR', 'EXT ENDOR - RIDGE OVERLOOKING SHIELD GENERATOR', 'EXT SPACE - DEATH STAR', 'JABBA', 'EXT EWOK VILLAGE SQUARE', 'LANDO', 'EXT SKIFF', 'EXT EWOK VILLAGE - NIGHT', 'MON MOTHMA', 'INT RANCOR PIT'}
# {'SCOUT CAMPSITE', 'DUNE SE', 'DEATH STA', 'UPPER DEC', 'FOREST', 'MILLENNIUM FALCON', 'X', 'TATOOINE SEA', 'HEADQUARTERS FRIGATE', 'ENDOR FOREST', 'DUNGEON CORRIDOR AND CEL', 'DUNE SEA', 'FOREST CLEARING', 'SARLACC PI', 'SUPER STAR DESTROYER', 'SAIL BARGE', 'SAIL BARG', 'REBEL STAR CRUISER', 'DEATH STAR', 'RIDG', 'OVER STAR FIEL', 'BARGE OBSERVATION DEC', 'DUNGEON CORRIDO', 'BARGE', 'BUNKER', '/INT', 'DUNGEON CEL', 'DOCKING BAY', 'ENDOR FORES', 'EWOK VILLAGE SQUAR', 'EWOK VILLAGE', 'RANCOR PI', 'ENDOR', 'BUNKE', 'DAGOBAH SWAMP', 'IMPERIAL SHUTTLE', 'SAIL BARGE OBSERVATION DEC', 'SKIF', 'FOREST LANDING SITE', 'SAND DUN', 'SPACE', 'SPAC', 'FORES', 'THRONE ROO', 'IMPERIAL LANDING PLATFORM', 'BOILER ROO', 'FOREST WALKWAY', 'EWOK VILLAGE SQUARE', 'SKIFF', 'STOLEN IMPERIAL SHUTTLE', 'UPPER DECK'}
# {'EWOK', 'DEATH', 'DUNGEON', 'SAIL', 'ENDOR', 'FOREST', 'DUNE', 'IMPERIAL', 'UPPER', 'BARGE'}
# {'GREEN LEADER', 'BOUSHH', 'VADER', 'HOLDING TUNNEL - RANCOR PIT', 'NAVIGATOR', 'PIETT', 'SECOND COMMANDER', 'GUARD', 'JEDI', 'CONTROL ROOM COMMANDER', 'NINEDENINE', 'Y-WING PILOT', 'ACKBAR', 'BUNKER COMMANDER', 'SHUTTLE CAPTAIN', 'FADE OUT', 'THREEPIO', 'BEN', 'GENERAL MADINE', 'RETURN', 'GRAY LEADER', 'LURE', 'YODA', 'RETURN OF THE JEDI', 'OPERATOR', 'SCOUT', 'STORMTROOPER', 'PILOT', 'COMMANDER', 'EMPEROR', 'ANAKIN', 'LUKE', 'LEIA', 'REBEL PILOT', 'SPACE', 'ANOTHER PART OF THE FOREST', 'OOLA', 'JERJERROD', 'WEDGE', 'CONTROLLER', 'HAN', 'JABBA', 'RED THREE', 'RED TWO', 'OF THE', 'STRANGE VOICE', 'OFFICER', 'LANDO', 'BIB', 'MON MOTHMA'}
#
# 854
# 513

# %%
def first_wookieepedia_result(query: str) -> str:
    '''Get the url of the first result when searching Wookieepedia for a query
    (best for simple names as queries, ideally generated by the llm for something like
    "Produce a input consisting of the name of the most important element in the query so that its article can be looked up")
    '''
    search_results = requests.get(f'https://starwars.fandom.com/wiki/Special:Search?query={"+".join(query.split(" "))}')
    soup = BeautifulSoup(search_results.content, 'html.parser')
    first_res = soup.find('a', class_ = 'unified-search__result__link')
    return first_res['href']

# first_wookieepedia_result('Darth Plagueis')

# %%
def save_wookieepedia_page(query, url, file_name, save_folder, error_file):
    '''Error-tolerant (hence interruptible) extraction and cleaning of Wookieepedia page's content, then saving it to save_folder\file_name (or recording failure to error_file)
    '''
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        doc = soup.find('div', id = 'content').get_text()
    
        # Cleaning
        doc = doc.split('\n\n\n\n\n\n\n\n\n\n\n\n\n\n')[-1] # The (multiple) preambles are separated by these many newlines; no harm done if not present
        doc = re.sub('\[\d*\]', '', doc) # References (and section title's "[]" suffixes) are noise
        doc = doc.split('\nAppearances\n')[0] # Keep only content before these sections
        doc = doc.split('\nSources\n')[0] # Technically no need to check this if successfully cut on appearances, but no harm done
        doc = re.sub('Contents\n\n(?:[\d\.]+ [^\n]+\n+)+', '', doc) # Remove table of contents

        with open(os.path.join(save_folder, file_name), 'w') as file: file.write(doc)

        print(f'{query} ({url}) saved to {file_name}')
        return True
    except Exception as e:
        with open(error_file, 'a') as file: file.write(f"{query}|{url}|{file_name}\n")

        print(f'{query} failed; could not retrieve from {url}: {e}')
        return False


def scrape_wookieepedia(queries: list[str], save_folder = 'wookieepedia', done_file = 'successful_scrapes.txt', error_file = 'failed_scrapes.txt'):
    '''Error-tolerant (hence interruptible) and restartable scraping of Wookieepedia pages corresponding to the first results of searches with the given queries.
    '''
    done_file  = Path(save_folder) / 'log' / done_file
    error_file = Path(save_folder) / 'log' / error_file
    os.makedirs(save_folder, exist_ok = True)
    os.makedirs(Path(save_folder) / 'log', exist_ok = True)

    # Check log of previously-processed queries and matching files
    if Path(done_file).is_file():
        with open(done_file, 'r') as file: done_queries, done_urls, done_files = zip(*(tuple(line.split('|')) for line in file))
    else: done_queries, done_urls, done_files = [], [], []
    done_query_index = {q: i for i, q in enumerate(done_queries)}
    
    real_done_files = [f for f in os.listdir('wookieepedia') if f not in ['db', 'log']]

    for query in tqdm(set(queries) - set(done_queries)): # Technically this does not cover the queries resulting in duplicate pages, hence not optimal, but no real need for it to be
        if query in done_queries: print(f'{query} ({done_urls[(i := done_query_index[query])]}) already saved to {done_files[i]}')
        else:
            try:
                url = first_wookieepedia_result(query)
                file_name = f'{url.split("/")[-1]}.txt'.replace(':', '__')

                if file_name in real_done_files:
                    print(f'{file_name} already saved')
                else:
                    if save_wookieepedia_page(query, url, file_name, save_folder = save_folder, error_file = error_file):
                        real_done_files.append(file_name)
                        with open(done_file, 'a') as file: file.write(f"('{query}'|'{url}'|{file_name})\n") 
            except Exception as e:
                with open(error_file, 'a') as file: file.write(f"('{query}', '{url}')\n")

                print(f'{query} failed; could not generate an url: {e}')

# %%
# Populate the wookieepedia folder with cleaned page content

scrape_wookieepedia(matches_to_search)
# Out:
#   0%|          | 0/498 [00:00<?, ?it/s]
# TIE FIGHTE (https://starwars.fandom.com/wiki/TIE_fighter_series) saved to TIE_fighter_series.txt
# DAY (https://starwars.fandom.com/wiki/Daye_Azur-Jamin) saved to Daye_Azur-Jamin.txt
# WATTO (https://starwars.fandom.com/wiki/Watto) saved to Watto.txt
# ER JETTSTE (https://starwars.fandom.com/wiki/Maz_Kanata) saved to Maz_Kanata.txt
# SLAVE QUARTERS (https://starwars.fandom.com/wiki/Slave_Quarters_Row) saved to Slave_Quarters_Row.txt
# CHIEF (https://starwars.fandom.com/wiki/Chief) saved to Chief.txt
# CLONE COMMANDER BACARA (https://starwars.fandom.com/wiki/Bacara) saved to Bacara.txt
# OWEN (https://starwars.fandom.com/wiki/Owen) saved to Owen.txt
# TATOOINE SEA (https://starwars.fandom.com/wiki/Star_Wars_Outlaws) saved to Star_Wars_Outlaws.txt
# SECOND COMMANDER (https://starwars.fandom.com/wiki/Triton_Squad%27s_second_commander) saved to Triton_Squad%27s_second_commander.txt
# ASTEROID (https://starwars.fandom.com/wiki/Asteroid) saved to Asteroid.txt
# ROYAL GUARD (https://starwars.fandom.com/wiki/Royal_Guard_(Onderon)) saved to Royal_Guard_(Onderon).txt
# REBEL OFFICER (https://starwars.fandom.com/wiki/Rebel_officer_corps) saved to Rebel_officer_corps.txt
# CONTROL ROOM COMMANDER (https://starwars.fandom.com/wiki/Toos) saved to Toos.txt
# PALPATINES QUARTERS (https://starwars.fandom.com/wiki/Star_Wars:_Dark_Empire) saved to Star_Wars___Dark_Empire.txt
# RUNE (https://starwars.fandom.com/wiki/Rune) saved to Rune.txt
# TRACKING OFFICER (https://starwars.fandom.com/wiki/Tracking_officer) saved to Tracking_officer.txt
# SHUTTLE CAPTAIN (https://starwars.fandom.com/wiki/Enoch) saved to Enoch.txt
# OBI-WAN (https://starwars.fandom.com/wiki/Obi-Wan_Kenobi) saved to Obi-Wan_Kenobi.txt
# ANBOO SPACECRAFT (https://starwars.fandom.com/wiki/Kea_Moll) saved to Kea_Moll.txt
# CAPT. TARPALS (https://starwars.fandom.com/wiki/Star_Wars:_Galactic_Battlegrounds) saved to Star_Wars___Galactic_Battlegrounds.txt
# SAIL BARGE (https://starwars.fandom.com/wiki/Sail_barge) saved to Sail_barge.txt
# IMPERIAL STARDESTROYE (https://starwars.fandom.com/wiki/Stardestroyer) saved to Stardestroyer.txt
# RED SEVEN (https://starwars.fandom.com/wiki/Red_Seven) saved to Red_Seven.txt
# RIDG (https://starwars.fandom.com/wiki/Ridge) saved to Ridge.txt
# SECOND OFFICER (https://starwars.fandom.com/wiki/Second_officer) saved to Second_officer.txt
# CAPTAIN PANAKA (https://starwars.fandom.com/wiki/Quarsh_Panaka) saved to Quarsh_Panaka.txt
# GOLD FIVE (https://starwars.fandom.com/wiki/Gold_Five) saved to Gold_Five.txt
# BANA BREEMU (https://starwars.fandom.com/wiki/Bana_Breemu) saved to Bana_Breemu.txt
# READ LEADER (https://starwars.fandom.com/wiki/Age_of_Resistance_-_General_Hux_1) saved to Age_of_Resistance_-_General_Hux_1.txt
# TURRET ROOM (https://starwars.fandom.com/wiki/Turret_Room) saved to Turret_Room.txt
# REPUBLIC CRUISER (https://starwars.fandom.com/wiki/Republic_(cruiser)) saved to Republic_(cruiser).txt
# KI-ADI-MUNDI (https://starwars.fandom.com/wiki/Ki-Adi-Mundi) saved to Ki-Adi-Mundi.txt
# OFFICER CASS (https://starwars.fandom.com/wiki/Siward_Cass) saved to Siward_Cass.txt
# TATOOINE (https://starwars.fandom.com/wiki/Tatooine) saved to Tatooine.txt
# STAR (https://starwars.fandom.com/wiki/Star) saved to Star.txt
# ANAKINN (https://starwars.fandom.com/wiki/Anakin_Skywalker) saved to Anakin_Skywalker.txt
# DISSOLVE TO (https://starwars.fandom.com/wiki/Touchstone) saved to Touchstone.txt
# ASTEROID BELT (https://starwars.fandom.com/wiki/Asteroid_Belt_Gas_Refinery) saved to Asteroid_Belt_Gas_Refinery.txt
# JOURNAL OF THE WHILLS (https://starwars.fandom.com/wiki/Timeline_of_galactic_history) saved to Timeline_of_galactic_history.txt
# CLONE CAPTAIN (https://starwars.fandom.com/wiki/Clone_Captain) saved to Clone_Captain.txt
# AT-ST CLONE SERGEANT (https://starwars.fandom.com/wiki/Star_Wars:_The_Black_Series) saved to Star_Wars___The_Black_Series.txt
# THE END (https://starwars.fandom.com/wiki/Endor) saved to Endor.txt
# BATTLE DROID CAPTAIN (https://starwars.fandom.com/wiki/Unidentified_B1_battle_droid_captain) saved to Unidentified_B1_battle_droid_captain.txt
# MUSTAFAR (https://starwars.fandom.com/wiki/Mustafar) saved to Mustafar.txt
# AAYLA (https://starwars.fandom.com/wiki/Aayla_Secura) saved to Aayla_Secura.txt
# HALLWAY TO HANGAR BAY (https://starwars.fandom.com/wiki/Cargo_of_Doom) saved to Cargo_of_Doom.txt
# REBEL BLOCKADE RUNNER (https://starwars.fandom.com/wiki/CR90_corvette/Legends) saved to Legends.txt
# VALORUM (https://starwars.fandom.com/wiki/Valorum_(The_Star_Wars)) saved to Valorum_(The_Star_Wars).txt
# BRAVO THREE (https://starwars.fandom.com/wiki/Bravo_Three) saved to Bravo_Three.txt
# Legends.txt already saved
# CORUSCANT (https://starwars.fandom.com/wiki/Coruscant) saved to Coruscant.txt
# RED THREE (https://starwars.fandom.com/wiki/Red_Three) saved to Red_Three.txt
# NABOO LAKE (https://starwars.fandom.com/wiki/Unidentified_Naboo_lake) saved to Unidentified_Naboo_lake.txt
# NABOO EDGE OF SWAMP/ GRASS PLAINS (https://starwars.fandom.com/wiki/Rorworr_(Naboo)) saved to Rorworr_(Naboo).txt
# COUNT DOOKU (https://starwars.fandom.com/wiki/Count_Dooku_(article)) saved to Count_Dooku_(article).txt
# TROOPER (https://starwars.fandom.com/wiki/Trooper) saved to Trooper.txt
# SPEEDER LOT (https://starwars.fandom.com/wiki/Honest_Ellam%27s_Speeder_Lot) saved to Honest_Ellam%27s_Speeder_Lot.txt
# RED LEADER (https://starwars.fandom.com/wiki/Red_Leader) saved to Red_Leader.txt
# RED ELEVEN (https://starwars.fandom.com/wiki/Red_Eleven) saved to Red_Eleven.txt
# STRANGE VOICE (https://starwars.fandom.com/wiki/Deadly_Reunion) saved to Deadly_Reunion.txt
# OBI-WAM (https://starwars.fandom.com/wiki/Star_Wars:_Return_of_the_Jedi_Coloring_Book_(Luke_Skywalker)) saved to Star_Wars___Return_of_the_Jedi_Coloring_Book_(Luke_Skywalker).txt
# SCOUT CAMPSITE (https://starwars.fandom.com/wiki/Porter_Engle) saved to Porter_Engle.txt
# UTAPAU STAIRWAY (https://starwars.fandom.com/wiki/Star_Wars:_Complete_Locations_(2016)) saved to Star_Wars___Complete_Locations_(2016).txt
# Legends.txt already saved
# CAPTAIN TYPHO (https://starwars.fandom.com/wiki/Gregar_Typho) saved to Gregar_Typho.txt
# FREIGHTER DOCKS (https://starwars.fandom.com/wiki/Star_Wars:_Legacy_Volume_II_Book_3%E2%80%94Wanted:_Ania_Solo) saved to Star_Wars___Legacy_Volume_II_Book_3%E2%80%94Wanted___Ania_Solo.txt
# BESPIN SYSTEM (https://starwars.fandom.com/wiki/Bespin_system) saved to Bespin_system.txt
# HERMIONE (https://starwars.fandom.com/wiki/Hermione) saved to Hermione.txt
# Legends.txt already saved
# NAVIGATOR (https://starwars.fandom.com/wiki/Navigator) saved to Navigator.txt
# MOS EISLEY (https://starwars.fandom.com/wiki/Mos_Eisley) saved to Mos_Eisley.txt
# ELAN SLEAZEBAGGANO (https://starwars.fandom.com/wiki/Elan_Sel%27Sabagno) saved to Elan_Sel%27Sabagno.txt
# QUI -GON (https://starwars.fandom.com/wiki/War%27qi) saved to War%27qi.txt
# CLONE SERGEANT (https://starwars.fandom.com/wiki/Clone_Sergeant) saved to Clone_Sergeant.txt
# X (https://starwars.fandom.com/wiki/Xyston-class_Star_Destroyer) saved to Xyston-class_Star_Destroyer.txt
# FEDERATION BATTLESHIP (https://starwars.fandom.com/wiki/Trade_Federation_Battleship_(aquatic)) saved to Trade_Federation_Battleship_(aquatic).txt
# FOURTH MOON OF YAVI (https://starwars.fandom.com/wiki/Yavin_4) saved to Yavin_4.txt
# Legends.txt already saved
# JAR JAR (https://starwars.fandom.com/wiki/Jar_Jar_Binks) saved to Jar_Jar_Binks.txt
# DUNE SEA (https://starwars.fandom.com/wiki/Dune_Sea) saved to Dune_Sea.txt
# POD BAY (https://starwars.fandom.com/wiki/Star_Wars:_Knights_of_the_Old_Republic) saved to Star_Wars___Knights_of_the_Old_Republic.txt
# BESPIN SURFACE (https://starwars.fandom.com/wiki/Land_City) saved to Land_City.txt
# FOREST CLEARING (https://starwars.fandom.com/wiki/Infiltration_(episode)) saved to Infiltration_(episode).txt
# CREATURE (https://starwars.fandom.com/wiki/Creature_Safari) saved to Creature_Safari.txt
# THEED (https://starwars.fandom.com/wiki/Theed) saved to Theed.txt
# SARLACC PI (https://starwars.fandom.com/wiki/Abandoned_sarlacc_pit) saved to Abandoned_sarlacc_pit.txt
# SURFACE (https://starwars.fandom.com/wiki/Surface_Marshal) saved to Surface_Marshal.txt
# BOTTOM OF CLOUD CITY (https://starwars.fandom.com/wiki/The_Force_Theme) saved to The_Force_Theme.txt
# SUPER STAR DESTROYER (https://starwars.fandom.com/wiki/Super_Star_Destroyer) saved to Super_Star_Destroyer.txt
# WRANGLER (https://starwars.fandom.com/wiki/Uvak_wrangler) saved to Uvak_wrangler.txt
# HYPERSPAC (https://starwars.fandom.com/wiki/Hyperspace) saved to Hyperspace.txt
# LURE (https://starwars.fandom.com/wiki/Lure_of_the_Lost) saved to Lure_of_the_Lost.txt
# ESCAPE POD (https://starwars.fandom.com/wiki/Escape_pod) saved to Escape_pod.txt
# OVER STAR FIEL (https://starwars.fandom.com/wiki/Starfield_Road) saved to Starfield_Road.txt
# TARKIN (https://starwars.fandom.com/wiki/Tarkin_family) saved to Tarkin_family.txt
# ELEVATOR LOBBY (https://starwars.fandom.com/wiki/KnollVision) saved to KnollVision.txt
# SANDCRAWLE (https://starwars.fandom.com/wiki/Sandcrawler) saved to Sandcrawler.txt
# BOBA FETT (https://starwars.fandom.com/wiki/Boba_Fett) saved to Boba_Fett.txt
# RUNE HAAKO (https://starwars.fandom.com/wiki/Rune_Haako) saved to Rune_Haako.txt
# MOTTI (https://starwars.fandom.com/wiki/Motti_family) saved to Motti_family.txt
# NABOO PALACE (https://starwars.fandom.com/wiki/Naboo_Palace_Guard) saved to Naboo_Palace_Guard.txt
# ZAM (https://starwars.fandom.com/wiki/Zam) saved to Zam.txt
# DETENTION ARE (https://starwars.fandom.com/wiki/Detention_area) saved to Detention_area.txt
# Anakin_Skywalker.txt already saved
# CATO NEIMOIDIA (https://starwars.fandom.com/wiki/Cato_Neimoidia) saved to Cato_Neimoidia.txt
# ALDERAAN CRUISER (https://starwars.fandom.com/wiki/Alderaan_Cruiser) saved to Alderaan_Cruiser.txt
# SOLA (https://starwars.fandom.com/wiki/Sola) saved to Sola.txt
# BLY (https://starwars.fandom.com/wiki/Bly) saved to Bly.txt
# Boba_Fett.txt already saved
# SURFACE OF THE DEATH STA (https://starwars.fandom.com/wiki/Death_Star_II) saved to Death_Star_II.txt
# CAMIE (https://starwars.fandom.com/wiki/Camie_Marstrap) saved to Camie_Marstrap.txt
# Legends.txt already saved
# BASE VOICE (https://starwars.fandom.com/wiki/Star_Wars_Rebels:_Steps_Into_Shadow) saved to Star_Wars_Rebels___Steps_Into_Shadow.txt
# TECHNICIAN (https://starwars.fandom.com/wiki/Technician) saved to Technician.txt
# JERJERROD (https://starwars.fandom.com/wiki/Jerjerrod_(admiral)) saved to Jerjerrod_(admiral).txt
# IMPERIAL LANDING PLATFORM (https://starwars.fandom.com/wiki/Wicket_Wystri_Warrick) saved to Wicket_Wystri_Warrick.txt
# CONTROLLER (https://starwars.fandom.com/wiki/Controller) saved to Controller.txt
# SENATOR ASK AAK (https://starwars.fandom.com/wiki/Ask_Aak) saved to Ask_Aak.txt
# PADM (https://starwars.fandom.com/wiki/Padm%C3%A9_Amidala) saved to Padm%C3%A9_Amidala.txt
# Legends.txt already saved
# Anakin_Skywalker.txt already saved
# GUI-GON (https://starwars.fandom.com/wiki/Gonky_(Clone_Force_99)) saved to Gonky_(Clone_Force_99).txt
# MAIN HANGER (https://starwars.fandom.com/wiki/Acclamator-class_transgalactic_military_assault_ship) saved to Acclamator-class_transgalactic_military_assault_ship.txt
# SKIFF (https://starwars.fandom.com/wiki/Skiff) saved to Skiff.txt
# GREEDO (https://starwars.fandom.com/wiki/Greedo) saved to Greedo.txt
# PORKINS (https://starwars.fandom.com/wiki/Porkins_Belly_Run) saved to Porkins_Belly_Run.txt
# PLAIN OF HOTH (https://starwars.fandom.com/wiki/1995_Topps_Star_Wars:_The_Empire_Strikes_Back_Widevision) saved to 1995_Topps_Star_Wars___The_Empire_Strikes_Back_Widevision.txt
# Dune_Sea.txt already saved
# MACE-WINDU (https://starwars.fandom.com/wiki/Mace_Windu) saved to Mace_Windu.txt
# CHILDREN (https://starwars.fandom.com/wiki/Children) saved to Children.txt
# SEBULBA (https://starwars.fandom.com/wiki/Sebulba) saved to Sebulba.txt
# IMPERIAL (https://starwars.fandom.com/wiki/Imperial_I-class_Star_Destroyer) saved to Imperial_I-class_Star_Destroyer.txt
# PIETT (https://starwars.fandom.com/wiki/Firmus_Piett) saved to Firmus_Piett.txt
# YAVIN (https://starwars.fandom.com/wiki/Yavin) saved to Yavin.txt
# UPPER (https://starwars.fandom.com/wiki/Upper_City_Cantina) saved to Upper_City_Cantina.txt
# Sandcrawler.txt already saved
# WOMAN CONTROLLER (https://starwars.fandom.com/wiki/Unidentified_Imperial_controller_(female)) saved to Unidentified_Imperial_controller_(female).txt
# NEEDA (https://starwars.fandom.com/wiki/Needan) saved to Needan.txt
# REBEL (https://starwars.fandom.com/wiki/Rebel_Alliance_Navy) saved to Rebel_Alliance_Navy.txt
# CRUISER (https://starwars.fandom.com/wiki/Cruiser) saved to Cruiser.txt
# TERR TANEEL (https://starwars.fandom.com/wiki/Terr_Taneel) saved to Terr_Taneel.txt
# CLONE PILOT (https://starwars.fandom.com/wiki/Fireball_(clone_pilot)) saved to Fireball_(clone_pilot).txt
# IMPERIAL OFFICER (https://starwars.fandom.com/wiki/Imperial_officer) saved to Imperial_officer.txt
# ELAN (https://starwars.fandom.com/wiki/Elan) saved to Elan.txt
# SUPER BATTLE DROID (https://starwars.fandom.com/wiki/Super_battle_droid_rocket_trooper) saved to Super_battle_droid_rocket_trooper.txt
# THREEPIO (https://starwars.fandom.com/wiki/Threepio_Takes_Flight) saved to Threepio_Takes_Flight.txt
# Legends.txt already saved
# MOS ESPA (https://starwars.fandom.com/wiki/Mos_Espa) saved to Mos_Espa.txt
# BATTLEFIELD (https://starwars.fandom.com/wiki/Battlefield_Holographic_Control_Interface) saved to Battlefield_Holographic_Control_Interface.txt
# BARGE OBSERVATION DEC (https://starwars.fandom.com/wiki/The_Thrawn_Trilogy_Sourcebook) saved to The_Thrawn_Trilogy_Sourcebook.txt
# ASSEMBLY (https://starwars.fandom.com/wiki/Assembly) saved to Assembly.txt
# GUARDS (https://starwars.fandom.com/wiki/Guardstar) saved to Guardstar.txt
# Legends.txt already saved
# NABOO (https://starwars.fandom.com/wiki/Naboo) saved to Naboo.txt
# REBEL FIGHTER (https://starwars.fandom.com/wiki/Rebel_Fighter_Squadrons_II_Expansion_Pack) saved to Rebel_Fighter_Squadrons_II_Expansion_Pack.txt
# SUB COCKPIT (https://starwars.fandom.com/wiki/KE-UW33) saved to KE-UW33.txt
# Legends.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# DUNGEON (https://starwars.fandom.com/wiki/Dungeon_ship) saved to Dungeon_ship.txt
# Padm%C3%A9_Amidala.txt already saved
# NABOO SACRED TEMPLE RUINS (https://starwars.fandom.com/wiki/Jedi_Temple) saved to Jedi_Temple.txt
# WOMAN (https://starwars.fandom.com/wiki/Unidentified_woman_(Korvix_Vorn)) saved to Unidentified_woman_(Korvix_Vorn).txt
# BODYGUARD (https://starwars.fandom.com/wiki/Bodyguard) saved to Bodyguard.txt
# Legends.txt already saved
# OFFICE (https://starwars.fandom.com/wiki/Officer) saved to Officer.txt
# VENDOR (https://starwars.fandom.com/wiki/Vendor) saved to Vendor.txt
# Legends.txt already saved
# CAPTAIN (https://starwars.fandom.com/wiki/Captain) saved to Captain.txt
# ANOTHER PART OF THE FOREST (https://starwars.fandom.com/wiki/The_Legends_of_Luke_Skywalker) saved to The_Legends_of_Luke_Skywalker.txt
# NABOO GRASS PALINS (https://starwars.fandom.com/wiki/Star_Wars:_Complete_Locations_(2005)) saved to Star_Wars___Complete_Locations_(2005).txt
# BIGGS (https://starwars.fandom.com/wiki/Biggs_Darklighter) saved to Biggs_Darklighter.txt
# JANGO (https://starwars.fandom.com/wiki/Jango_Fett) saved to Jango_Fett.txt
# RIC OLIE (https://starwars.fandom.com/wiki/Ric_Oli%C3%A9) saved to Ric_Oli%C3%A9.txt
# GUNGAN LOOKOUT (https://starwars.fandom.com/wiki/Battle_of_Naboo_(YJCCG)) saved to Battle_of_Naboo_(YJCCG).txt
# FOREST WALKWAY (https://starwars.fandom.com/wiki/1996_Topps_Star_Wars:_Return_of_the_Jedi_Widevision) saved to 1996_Topps_Star_Wars___Return_of_the_Jedi_Widevision.txt
# SURFACE AROUND THE DEATH STA (https://starwars.fandom.com/wiki/Death_Star_II_Limited) saved to Death_Star_II_Limited.txt
# IMPERIAL STAR DESTROYER (https://starwars.fandom.com/wiki/Imperial_Star_Destroyer_Cymoon_1_Refit) saved to Imperial_Star_Destroyer_Cymoon_1_Refit.txt
# Officer.txt already saved
# Dune_Sea.txt already saved
# TROOPER VOICE (https://starwars.fandom.com/wiki/TK-421) saved to TK-421.txt
# NUTE GUNRAY (https://starwars.fandom.com/wiki/Nute_Gunray) saved to Nute_Gunray.txt
# BATTLE DROID (https://starwars.fandom.com/wiki/Battle_droid) saved to Battle_droid.txt
# 1995_Topps_Star_Wars___The_Empire_Strikes_Back_Widevision.txt already saved
# BIB (https://starwars.fandom.com/wiki/Bib) saved to Bib.txt
# SENATE BUILDING (https://starwars.fandom.com/wiki/Senate_Building) saved to Senate_Building.txt
# GENERATOR ROOM (https://starwars.fandom.com/wiki/Cloak_of_Darkness) saved to Cloak_of_Darkness.txt
# SALEUCAMI (https://starwars.fandom.com/wiki/Saleucami) saved to Saleucami.txt
# TIE_fighter_series.txt already saved
# BOUSHH (https://starwars.fandom.com/wiki/Boushh) saved to Boushh.txt
# DABTH SIDIOUS (https://starwars.fandom.com/wiki/Darth_Sidious) saved to Darth_Sidious.txt
# COCKPIT (https://starwars.fandom.com/wiki/Cockpit) saved to Cockpit.txt
# Legends.txt already saved
# WALD (https://starwars.fandom.com/wiki/Wald) saved to Wald.txt
# Anakin_Skywalker.txt already saved
# Legends.txt already saved
# SNOWSPEEDER (https://starwars.fandom.com/wiki/Snowspeeder) saved to Snowspeeder.txt
# MILLENNIUM (https://starwars.fandom.com/wiki/Millennium) saved to Millennium.txt
# Legends.txt already saved
# GUARD (https://starwars.fandom.com/wiki/Guard) saved to Guard.txt
# Legends.txt already saved
# NABOO STARFIGHTER (https://starwars.fandom.com/wiki/Category:Naboo_starfighter_classes) saved to Category__Naboo_starfighter_classes.txt
# Legends.txt already saved
# REPUBLIC BATTLE CRUISER (https://starwars.fandom.com/wiki/Republic_battlecruiser) saved to Republic_battlecruiser.txt
# BARTENDER (https://starwars.fandom.com/wiki/Bartender) saved to Bartender.txt
# Legends.txt already saved
# FADE OUT (https://starwars.fandom.com/wiki/Durge) saved to Durge.txt
# PANAKA (https://starwars.fandom.com/wiki/Panaka) saved to Panaka.txt
# Legends.txt already saved
# Anakin_Skywalker.txt already saved
# ASTRO-OFFICER (https://starwars.fandom.com/wiki/Unidentified_Astro-Traffic_Control_Officer) saved to Unidentified_Astro-Traffic_Control_Officer.txt
# STORMTROOPER (https://starwars.fandom.com/wiki/Stormtrooper) saved to Stormtrooper.txt
# BUNKER (https://starwars.fandom.com/wiki/Bunker_Krill) saved to Bunker_Krill.txt
# SPACE SLUG MOUT (https://starwars.fandom.com/wiki/Star_Wars:_The_Old_Republic:_Onslaught) saved to Star_Wars___The_Old_Republic___Onslaught.txt
# FIGHTER PILOT (https://starwars.fandom.com/wiki/Naboo_Fighter_Pilot) saved to Naboo_Fighter_Pilot.txt
# BRIDGE (https://starwars.fandom.com/wiki/Bridge) saved to Bridge.txt
# CLONE TROOPER (https://starwars.fandom.com/wiki/Clone_trooper) saved to Clone_trooper.txt
# HOBBIE (https://starwars.fandom.com/wiki/More_than_a_Hobbie!) saved to More_than_a_Hobbie!.txt
# RANCOR PI (https://starwars.fandom.com/wiki/Rancor_Pit) saved to Rancor_Pit.txt
# Legends.txt already saved
# TAUN WE (https://starwars.fandom.com/wiki/Taun_We) saved to Taun_We.txt
# LARS HOMESTEAD (https://starwars.fandom.com/wiki/Lars_homestead) saved to Lars_homestead.txt
# DOOKU (https://starwars.fandom.com/wiki/Dooku) saved to Dooku.txt
# Skiff.txt already saved
# FOREST LANDING SITE (https://starwars.fandom.com/wiki/Endor_Limited) saved to Endor_Limited.txt
# NIGHTCLUB (https://starwars.fandom.com/wiki/Nightclub) saved to Nightclub.txt
# Legends.txt already saved
# DOCKING PORT ENTRY (https://starwars.fandom.com/wiki/Pelta-class_frigate) saved to Pelta-class_frigate.txt
# POGGLE (https://starwars.fandom.com/wiki/Poggle_the_Lesser) saved to Poggle_the_Lesser.txt
# GENERAL GRIEVOUS (https://starwars.fandom.com/wiki/General_Grievous_1) saved to General_Grievous_1.txt
# DAGOBAH (https://starwars.fandom.com/wiki/Dagobah) saved to Dagobah.txt
# THRONE ROO (https://starwars.fandom.com/wiki/Throne_room_gown) saved to Throne_room_gown.txt
# Legends.txt already saved
# Naboo_Fighter_Pilot.txt already saved
# LANDING PLATFORM (https://starwars.fandom.com/wiki/Landing_Platform_Nine) saved to Landing_Platform_Nine.txt
# Legends.txt already saved
# EXHAUST PIP (https://starwars.fandom.com/wiki/PIP/2_systems_control_droid) saved to 2_systems_control_droid.txt
# ALDERAAN (https://starwars.fandom.com/wiki/Alderaan) saved to Alderaan.txt
# Death_Star_II.txt already saved
# FOUR (https://starwars.fandom.com/wiki/Four) saved to Four.txt
# UPPER DECK (https://starwars.fandom.com/wiki/Greef_Karga) saved to Greef_Karga.txt
# ASTEROID CAVE (https://starwars.fandom.com/wiki/Avenger) saved to Avenger.txt
# MO (https://starwars.fandom.com/wiki/Morgan_Elsbeth) saved to Morgan_Elsbeth.txt
# JANSON (https://starwars.fandom.com/wiki/Janson_Hidreck) saved to Janson_Hidreck.txt
# RABE (https://starwars.fandom.com/wiki/Rab%C3%A9_Tonsort) saved to Rab%C3%A9_Tonsort.txt
# TEY HOW (https://starwars.fandom.com/wiki/Tey_How) saved to Tey_How.txt
# MON MOTHMA (https://starwars.fandom.com/wiki/Mon_Mothma) saved to Mon_Mothma.txt
# DODONNA (https://starwars.fandom.com/wiki/Dodonna) saved to Dodonna.txt
# DEATH STA (https://starwars.fandom.com/wiki/Death_Star) saved to Death_Star.txt
# ORN FREE TAA (https://starwars.fandom.com/wiki/Orn_Free_Taa) saved to Orn_Free_Taa.txt
# SECOND THREEPIO (https://starwars.fandom.com/wiki/The_Second_Kessel_Run) saved to The_Second_Kessel_Run.txt
# Legends.txt already saved
# Cato_Neimoidia.txt already saved
# 1995_Topps_Star_Wars___The_Empire_Strikes_Back_Widevision.txt already saved
# CATO (https://starwars.fandom.com/wiki/Cato_Parasitti) saved to Cato_Parasitti.txt
# Darth_Sidious.txt already saved
# MASSASSI OUTPOST (https://starwars.fandom.com/wiki/Great_Temple) saved to Great_Temple.txt
# OU (https://starwars.fandom.com/wiki/Outer_Rim_Territories) saved to Outer_Rim_Territories.txt
# RUWEE (https://starwars.fandom.com/wiki/Ruwee_Naberrie) saved to Ruwee_Naberrie.txt
# STAR WARS (https://starwars.fandom.com/wiki/Star_Wars:_The_Bad_Batch) saved to Star_Wars___The_Bad_Batch.txt
# VEERS (https://starwars.fandom.com/wiki/Maximilian_Veers) saved to Maximilian_Veers.txt
# MILLENNIUM FALCON (https://starwars.fandom.com/wiki/Millennium_Falcon) saved to Millennium_Falcon.txt
# CLONE COMMANDER APPO (https://starwars.fandom.com/wiki/501st_Legion) saved to 501st_Legion.txt
# REBEL CAPTAIN (https://starwars.fandom.com/wiki/Unidentified_Rebel_captain) saved to Unidentified_Rebel_captain.txt
# MYGEETO (https://starwars.fandom.com/wiki/Mygeeto) saved to Mygeeto.txt
# JEDI (https://starwars.fandom.com/wiki/Jedi) saved to Jedi.txt
# Legends.txt already saved
# CAPTAIN ANTILLES (https://starwars.fandom.com/wiki/Captain_Antilles) saved to Captain_Antilles.txt
# Legends.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# HOTH (https://starwars.fandom.com/wiki/Hoth) saved to Hoth.txt
# GANTRY OFFICER (https://starwars.fandom.com/wiki/Gantry_officer) saved to Gantry_officer.txt
# ACKBAR (https://starwars.fandom.com/wiki/Ackbar_(comic)) saved to Ackbar_(comic).txt
# QUI-GON (https://starwars.fandom.com/wiki/Qui-Gon_Jinn) saved to Qui-Gon_Jinn.txt
# THED (https://starwars.fandom.com/wiki/Theda) saved to Theda.txt
# DORME (https://starwars.fandom.com/wiki/Dorm%C3%A9) saved to Dorm%C3%A9.txt
# Jango_Fett.txt already saved
# SECOND CONTROLLER (https://starwars.fandom.com/wiki/Imperial_Sourcebook_(Second_Edition)) saved to Imperial_Sourcebook_(Second_Edition).txt
# NABOO SWAMP (https://starwars.fandom.com/wiki/Naboo_swamp_moss) saved to Naboo_swamp_moss.txt
# Legends.txt already saved
# Legends.txt already saved
# HANGAR DOORWAY (https://starwars.fandom.com/wiki/Takobo_Spaceport_Depot) saved to Takobo_Spaceport_Depot.txt
# Death_Star.txt already saved
# MACE (https://starwars.fandom.com/wiki/Mace) saved to Mace.txt
# SMALL PASSAGEWAY (https://starwars.fandom.com/wiki/Command_center) saved to Command_center.txt
# OPERATOR (https://starwars.fandom.com/wiki/Operator) saved to Operator.txt
# FIXER (https://starwars.fandom.com/wiki/Fixer) saved to Fixer.txt
# Gantry_officer.txt already saved
# Millennium_Falcon.txt already saved
# Legends.txt already saved
# SCOUT (https://starwars.fandom.com/wiki/Scout) saved to Scout.txt
# PILOT (https://starwars.fandom.com/wiki/Pilot) saved to Pilot.txt
# /INT (https://starwars.fandom.com/wiki/Into_the_Breach) saved to Into_the_Breach.txt
# DUNGEON CEL (https://starwars.fandom.com/wiki/Force-sensitive_holding_cell) saved to Force-sensitive_holding_cell.txt
# PILOTS (https://starwars.fandom.com/wiki/Pilot%27s_End) saved to Pilot%27s_End.txt
# FELUCIA (https://starwars.fandom.com/wiki/Felucia) saved to Felucia.txt
# OZZEL (https://starwars.fandom.com/wiki/Ozzel_family) saved to Ozzel_family.txt
# RED LEADER STARSHIP (https://starwars.fandom.com/wiki/Battle_of_Yavin) saved to Battle_of_Yavin.txt
# Legends.txt already saved
# SENATE (https://starwars.fandom.com/wiki/Senate) saved to Senate.txt
# Bunker_Krill.txt already saved
# Legends.txt already saved
# A NEW HOPE (https://starwars.fandom.com/wiki/New_Hope) saved to New_Hope.txt
# Bacara.txt already saved
# BOTTOM (https://starwars.fandom.com/wiki/Bottoms) saved to Bottoms.txt
# CLONE COMMANDER THIRE (https://starwars.fandom.com/wiki/Thire) saved to Thire.txt
# Ki-Adi-Mundi.txt already saved
# ERCO (https://starwars.fandom.com/wiki/E%27ronoh) saved to E%27ronoh.txt
# ALDERAAN STARCRUISER (https://starwars.fandom.com/wiki/Remember_Alderaan_(Star_Cruiser)) saved to Remember_Alderaan_(Star_Cruiser).txt
# LAMA SU (https://starwars.fandom.com/wiki/Lama_Su) saved to Lama_Su.txt
# KnollVision.txt already saved
# SPACE AROUND THE DEATH STAR (https://starwars.fandom.com/wiki/Karthon_Chop_Fields) saved to Karthon_Chop_Fields.txt
# KITSTER (https://starwars.fandom.com/wiki/Kitster_Chanchani_Banai) saved to Kitster_Chanchani_Banai.txt
# SAND DUN (https://starwars.fandom.com/wiki/Eastern_sand_dune) saved to Eastern_sand_dune.txt
# SPACE (https://starwars.fandom.com/wiki/Space_station) saved to Space_station.txt
# PLO KOON (https://starwars.fandom.com/wiki/Plo_Koon) saved to Plo_Koon.txt
# CORD (https://starwars.fandom.com/wiki/Cord) saved to Cord.txt
# RED TWO (https://starwars.fandom.com/wiki/Red_Two) saved to Red_Two.txt
# GUNSHIP (https://starwars.fandom.com/wiki/Gunship) saved to Gunship.txt
# WILLARD (https://starwars.fandom.com/wiki/Willard_Waylin) saved to Willard_Waylin.txt
# MAIN HANGAR (https://starwars.fandom.com/wiki/Ossus_Academy_Main_Hangar) saved to Ossus_Academy_Main_Hangar.txt
# Legends.txt already saved
# QUEEN JAMILLIA (https://starwars.fandom.com/wiki/Jamillia) saved to Jamillia.txt
# FADE IN AND OUT OVER BACKGROUN (https://starwars.fandom.com/wiki/Naboo_Royal_Handmaidens) saved to Naboo_Royal_Handmaidens.txt
# AMEDD (https://starwars.fandom.com/wiki/Mas_Amedda) saved to Mas_Amedda.txt
# WINDU (https://starwars.fandom.com/wiki/Windu%27s_Guile) saved to Windu%27s_Guile.txt
# ANOTHER COCKPI (https://starwars.fandom.com/wiki/There_Is_Always_Another) saved to There_Is_Always_Another.txt
# IMPERIAL SNOW WALKER (https://starwars.fandom.com/wiki/Star_Wars_Scrapbook) saved to Star_Wars_Scrapbook.txt
# MOTEE (https://starwars.fandom.com/wiki/Mote%C3%A9) saved to Mote%C3%A9.txt
# FIRST OFFICER (https://starwars.fandom.com/wiki/Unidentified_first_officer_(Wennis)) saved to Unidentified_first_officer_(Wennis).txt
# DECK OFFICER (https://starwars.fandom.com/wiki/Deck_officer) saved to Deck_officer.txt
# Legends.txt already saved
# OTOH GUNGA (https://starwars.fandom.com/wiki/Otoh_Gunga) saved to Otoh_Gunga.txt
# JEDI GUNSHIP (https://starwars.fandom.com/wiki/Landing_at_Point_Rain) saved to Landing_at_Point_Rain.txt
# CHIEF PILOT (https://starwars.fandom.com/wiki/Unidentified_chief_pilot_(Night_Caller)) saved to Unidentified_chief_pilot_(Night_Caller).txt
# BRAVO TWO (https://starwars.fandom.com/wiki/Bravo_Two) saved to Bravo_Two.txt
# Death_Star_II_Limited.txt already saved
# MASSASSI (https://starwars.fandom.com/wiki/Massassi) saved to Massassi.txt
# Star_Wars___Complete_Locations_(2005).txt already saved
# LIEUTENANT (https://starwars.fandom.com/wiki/Lieutenant) saved to Lieutenant.txt
# Legends.txt already saved
# RED TEN (https://starwars.fandom.com/wiki/Red_Ten) saved to Red_Ten.txt
# Star.txt already saved
# GUNSHIP NUMBER ONE (https://starwars.fandom.com/wiki/Phylanx_Redux_Transmitter) saved to Phylanx_Redux_Transmitter.txt
# BEN (https://starwars.fandom.com/wiki/Ben) saved to Ben.txt
# JIRA (https://starwars.fandom.com/wiki/Jira) saved to Jira.txt
# GENERAL MADINE (https://starwars.fandom.com/wiki/General_Madine%27s_Report_on_Operation_Cobolt) saved to General_Madine%27s_Report_on_Operation_Cobolt.txt
# STAR DESTROYER (https://starwars.fandom.com/wiki/Star_Destroyer) saved to Star_Destroyer.txt
# REBEL STAR CRUISER (https://starwars.fandom.com/wiki/Attack_on_Fondor) saved to Attack_on_Fondor.txt
# POLIS MASSA (https://starwars.fandom.com/wiki/Polis_Massa) saved to Polis_Massa.txt
# DROID GUARD (https://starwars.fandom.com/wiki/Droid_guard_ship) saved to Droid_guard_ship.txt
# ALLEY OUTSIDE NIGHTCLUB (https://starwars.fandom.com/wiki/R3-T7) saved to R3-T7.txt
# Legends.txt already saved
# JOCASTA NU (https://starwars.fandom.com/wiki/Jocasta_Nu) saved to Jocasta_Nu.txt
# DACK (https://starwars.fandom.com/wiki/Dack) saved to Dack.txt
# COMMANDER (https://starwars.fandom.com/wiki/Commander) saved to Commander.txt
# AMIDALA (https://starwars.fandom.com/wiki/Amidalans) saved to Amidalans.txt
# Legends.txt already saved
# CONTROL OFFICER (https://starwars.fandom.com/wiki/Unidentified_control_officer) saved to Unidentified_control_officer.txt
# ASSISTANT OFFICER (https://starwars.fandom.com/wiki/Tigran_Jamiro) saved to Tigran_Jamiro.txt
# Endor.txt already saved
# RED NINE (https://starwars.fandom.com/wiki/Red_Nine) saved to Red_Nine.txt
# IMPERIAL SHUTTLE (https://starwars.fandom.com/wiki/Imperial_shuttle) saved to Imperial_shuttle.txt
# LEIA (https://starwars.fandom.com/wiki/Leia_Skywalker_Organa_Solo) saved to Leia_Skywalker_Organa_Solo.txt
# Padm%C3%A9_Amidala.txt already saved
# BAIL (https://starwars.fandom.com/wiki/Bail) saved to Bail.txt
# REBEL BASE (https://starwars.fandom.com/wiki/Rebel_base) saved to Rebel_base.txt
# VOICE (https://starwars.fandom.com/wiki/Voice) saved to Voice.txt
# PALACE (https://starwars.fandom.com/wiki/Palace) saved to Palace.txt
# WEDGE (https://starwars.fandom.com/wiki/Wedge_Antilles) saved to Wedge_Antilles.txt
# Sail_barge.txt already saved
# AREA (https://starwars.fandom.com/wiki/Area_D-512) saved to Area_D-512.txt
# SIO BIBBLE (https://starwars.fandom.com/wiki/Sio_Bibble) saved to Sio_Bibble.txt
# DEATH STAR TRENC (https://starwars.fandom.com/wiki/Trench_Run_Defense) saved to Trench_Run_Defense.txt
# Legends.txt already saved
# SABE (https://starwars.fandom.com/wiki/Sab%C3%A9) saved to Sab%C3%A9.txt
# Legends.txt already saved
# SPACE AROUND FOURTH MOON OF YAVI (https://starwars.fandom.com/wiki/1995_Topps_Star_Wars_Widevision) saved to 1995_Topps_Star_Wars_Widevision.txt
# WINGMAN (https://starwars.fandom.com/wiki/Unidentified_wingman) saved to Unidentified_wingman.txt
# DOFINE (https://starwars.fandom.com/wiki/Dofine_family) saved to Dofine_family.txt
# ENTERTAINMENT STREET (https://starwars.fandom.com/wiki/Entertainment_Center) saved to Entertainment_Center.txt
# Mace_Windu.txt already saved
# DEATH (https://starwars.fandom.com/wiki/Death) saved to Death.txt
# TITLE CARD (https://starwars.fandom.com/wiki/Opening_crawl) saved to Opening_crawl.txt
# LOTT DOD (https://starwars.fandom.com/wiki/Lott_Dod) saved to Lott_Dod.txt
# HOLDING TUNNEL - RANCOR PIT (https://starwars.fandom.com/wiki/Omega) saved to Omega.txt
# SERVER (https://starwars.fandom.com/wiki/Unidentified_server_droid) saved to Unidentified_server_droid.txt
# UPPER DEC (https://starwars.fandom.com/wiki/Deceived) saved to Deceived.txt
# Legends.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Star_Wars___Galactic_Battlegrounds.txt already saved
# ODD BALL (https://starwars.fandom.com/wiki/Davijaan) saved to Davijaan.txt
# Legends.txt already saved
# REACTOR SHAF (https://starwars.fandom.com/wiki/Reactor_shaft) saved to Reactor_shaft.txt
# SEEK (https://starwars.fandom.com/wiki/Seek) saved to Seek.txt
# Legends.txt already saved
# SHMI (https://starwars.fandom.com/wiki/Shmi_Skywalker_Lars) saved to Shmi_Skywalker_Lars.txt
# YODA (https://starwars.fandom.com/wiki/Yoda) saved to Yoda.txt
# NAS (https://starwars.fandom.com/wiki/Nas) saved to Nas.txt
# SENIOR CONTROLLER (https://starwars.fandom.com/wiki/Senior_Controller) saved to Senior_Controller.txt
# DROID CAPTAIN (https://starwars.fandom.com/wiki/Commando_droid_captain) saved to Commando_droid_captain.txt
# GALAXY (https://starwars.fandom.com/wiki/Galaxy) saved to Galaxy.txt
# BARGE (https://starwars.fandom.com/wiki/Barge_driver) saved to Barge_driver.txt
# Legends.txt already saved
# ELEVATOR (https://starwars.fandom.com/wiki/Unidentified_elevator_(D-Sector)) saved to Unidentified_elevator_(D-Sector).txt
# BESPIN (https://starwars.fandom.com/wiki/Bespin) saved to Bespin.txt
# Coruscant.txt already saved
# POWER STATION (https://starwars.fandom.com/wiki/Power_Station) saved to Power_Station.txt
# Legends.txt already saved
# HUMAN (https://starwars.fandom.com/wiki/Human) saved to Human.txt
# NABOO SWAMP LAKE (https://starwars.fandom.com/wiki/Episode_I_Adventures_13:_Danger_on_Naboo) saved to Episode_I_Adventures_13___Danger_on_Naboo.txt
# BOTTOM OF CLOUD CIT (https://starwars.fandom.com/wiki/Cloud_City) saved to Cloud_City.txt
# Legends.txt already saved
# EXECUTIVE QUARTERS BUILDING (https://starwars.fandom.com/wiki/Star_Wars:_Episode_II_Attack_of_the_Clones_(unabridged_audiobook)) saved to Star_Wars___Episode_II_Attack_of_the_Clones_(unabridged_audiobook).txt
# PAMDE (https://starwars.fandom.com/wiki/Infiltration_of_Bezz_Drexx%27s_tower) saved to Infiltration_of_Bezz_Drexx%27s_tower.txt
# TAGGE (https://starwars.fandom.com/wiki/Tagge_protoblade) saved to Tagge_protoblade.txt
# FIRST CONTROLLER (https://starwars.fandom.com/wiki/The_DarkStryder_Campaign) saved to The_DarkStryder_Campaign.txt
# ANNOUNCER (https://starwars.fandom.com/wiki/Unidentified_announcer) saved to Unidentified_announcer.txt
# CHI EEKWAY (https://starwars.fandom.com/wiki/Chi_Eekway_Papanoida) saved to Chi_Eekway_Papanoida.txt
# OOLA (https://starwars.fandom.com/wiki/Oola) saved to Oola.txt
# ZEV (https://starwars.fandom.com/wiki/Zev) saved to Zev.txt
# BOILER ROO (https://starwars.fandom.com/wiki/Databank_(website)) saved to Databank_(website).txt
# HAN (https://starwars.fandom.com/wiki/Han_(disambiguation)) saved to Han_(disambiguation).txt
# RIEEKAN (https://starwars.fandom.com/wiki/Rieekan_(SIS)) saved to Rieekan_(SIS).txt
# NABOO CRUISER COCKPIT (https://starwars.fandom.com/wiki/Star_Wars:_Complete_Vehicles_(2013)) saved to Star_Wars___Complete_Vehicles_(2013).txt
# OF THE (https://starwars.fandom.com/wiki/The_Bad_Batch_Season_3) saved to The_Bad_Batch_Season_3.txt
# Legends.txt already saved
# Legends.txt already saved
# STOLEN IMPERIAL SHUTTLE (https://starwars.fandom.com/wiki/Phoenix_Cell) saved to Phoenix_Cell.txt
# JOVAL (https://starwars.fandom.com/wiki/Joval_Rykk) saved to Joval_Rykk.txt
# BATTLESTATIONS (https://starwars.fandom.com/wiki/Battle_Stations_of_the_Empire_and_the_First_Order) saved to Battle_Stations_of_the_Empire_and_the_First_Order.txt
# KASHYYYK (https://starwars.fandom.com/wiki/Kashyyyk) saved to Kashyyyk.txt
# Nute_Gunray.txt already saved
# GEONOSIS TUNNEL TO EXECUTION ARENA (https://starwars.fandom.com/wiki/Petranaki_arena) saved to Petranaki_arena.txt
# CAVE ENTRANCE (https://starwars.fandom.com/wiki/Ewoks:_The_Battle_for_Endor) saved to Ewoks___The_Battle_for_Endor.txt
# SENATE APARTMENTS (https://starwars.fandom.com/wiki/Bakur_Memorial_Building) saved to Bakur_Memorial_Building.txt
# HANGAR (https://starwars.fandom.com/wiki/Hangar) saved to Hangar.txt
# Anakin_Skywalker.txt already saved
# Anakin_Skywalker.txt already saved
# IMPERIAL SOLDIER (https://starwars.fandom.com/wiki/Imperial_soldier) saved to Imperial_soldier.txt
# TIE FIGHTER (https://starwars.fandom.com/wiki/TIE_fighter) saved to TIE_fighter.txt
# UTAPAU (https://starwars.fandom.com/wiki/Utapau) saved to Utapau.txt
# TRADE FEDERATION CRUISER (https://starwars.fandom.com/wiki/Trade_Federation_Cruiser_(Second_Battle_of_Lok)) saved to Trade_Federation_Cruiser_(Second_Battle_of_Lok).txt
# FOREST (https://starwars.fandom.com/wiki/Forest) saved to Forest.txt
# Legends.txt already saved
# Legends.txt already saved
# FANTA (https://starwars.fandom.com/wiki/Fanta) saved to Fanta.txt
# ELEVATOR SHAFT (https://starwars.fandom.com/wiki/The_Phantom_Apprentice) saved to The_Phantom_Apprentice.txt
# BUNKER COMMANDER (https://starwars.fandom.com/wiki/Death_Star%27s_shield_generator) saved to Death_Star%27s_shield_generator.txt
# GOLD TWO (https://starwars.fandom.com/wiki/Gold_Two_(rebellion)) saved to Gold_Two_(rebellion).txt
# DEATH STAR SURFAC (https://starwars.fandom.com/wiki/Citadel) saved to Citadel.txt
# RETURN (https://starwars.fandom.com/wiki/Return) saved to Return.txt
# Sail_barge.txt already saved
# GRAY LEADER (https://starwars.fandom.com/wiki/Gray_Leader) saved to Gray_Leader.txt
# NABOO SKIF (https://starwars.fandom.com/wiki/J-type_star_skiff) saved to J-type_star_skiff.txt
# AMEE (https://starwars.fandom.com/wiki/Amee) saved to Amee.txt
# Legends.txt already saved
# YOUNGLINGS (https://starwars.fandom.com/wiki/Younglings_(comic)) saved to Younglings_(comic).txt
# MAIN (https://starwars.fandom.com/wiki/Main_Page) saved to Main_Page.txt
# EWOK VILLAGE (https://starwars.fandom.com/wiki/Ewok_Village) saved to Ewok_Village.txt
# EWOK (https://starwars.fandom.com/wiki/Ewok) saved to Ewok.txt
# SPACECRAFT IN SPAC (https://starwars.fandom.com/wiki/Spaceport) saved to Spaceport.txt
# ERCOM VOIC (https://starwars.fandom.com/wiki/Voices) saved to Voices.txt
# EMPEROR (https://starwars.fandom.com/wiki/Emperor) saved to Emperor.txt
# BIBBLE (https://starwars.fandom.com/wiki/Bibble_UP) saved to Bibble_UP.txt
# HULL (https://starwars.fandom.com/wiki/Hull) saved to Hull.txt
# LUKE (https://starwars.fandom.com/wiki/Luke_Skywalker) saved to Luke_Skywalker.txt
# SENATE CHAMBER (https://starwars.fandom.com/wiki/Senate_chamber) saved to Senate_chamber.txt
# REBEL PILOT (https://starwars.fandom.com/wiki/Rebel_pilot) saved to Rebel_pilot.txt
# Legends.txt already saved
# CLONE COMMANDER CODY (https://starwars.fandom.com/wiki/Clone_Commander_Cody_Commander_Expansion) saved to Clone_Commander_Cody_Commander_Expansion.txt
# The_Thrawn_Trilogy_Sourcebook.txt already saved
# Anakin_Skywalker.txt already saved
# Legends.txt already saved
# SECOND TROOPER (https://starwars.fandom.com/wiki/Unidentified_clone_trooper_(Second_Battle_of_Geonosis)) saved to Unidentified_clone_trooper_(Second_Battle_of_Geonosis).txt
# TEMPLE OF THE JEDI (https://starwars.fandom.com/wiki/Din_Grogu) saved to Din_Grogu.txt
# TUSKEN RAIDER HUTT (https://starwars.fandom.com/wiki/The_Amazing_Book_of_LEGO_Star_Wars) saved to The_Amazing_Book_of_LEGO_Star_Wars.txt
# Forest.txt already saved
# Space_station.txt already saved
# BAIL ORGANA (https://starwars.fandom.com/wiki/Bail_Organa%27s_resistance_movement) saved to Bail_Organa%27s_resistance_movement.txt
# DEAK (https://starwars.fandom.com/wiki/Deak) saved to Deak.txt
# FIRST TROOPER (https://starwars.fandom.com/wiki/First_Trooper) saved to First_Trooper.txt
# MEDICAL DROID (https://starwars.fandom.com/wiki/Medical_droid) saved to Medical_droid.txt
# Cloud_City.txt already saved
# Jedi_Temple.txt already saved
# JABBA (https://starwars.fandom.com/wiki/Jabba_Desilijic_Tiure) saved to Jabba_Desilijic_Tiure.txt
# DERLIN (https://starwars.fandom.com/wiki/Bren_Derlin) saved to Bren_Derlin.txt
# FOOD SERVER (https://starwars.fandom.com/wiki/Ottilie) saved to Ottilie.txt
# CLONE COMMANDER GREE (https://starwars.fandom.com/wiki/Gree_(clone_trooper)) saved to Gree_(clone_trooper).txt
# Citadel.txt already saved
# Legends.txt already saved
# LANDO (https://starwars.fandom.com/wiki/Landonis_Balthazar_Calrissian) saved to Landonis_Balthazar_Calrissian.txt
# STAR CRUISER (https://starwars.fandom.com/wiki/Star_Cruiser) saved to Star_Cruiser.txt
# Great_Temple.txt already saved

# %%
# Post-fetch changes

# for path in ['Aayla_Secura.txt']:#[f for f in os.listdir('wookieepedia') if f not in ['db', 'log']]:
#     with open(Path('wookieepedia') / path, 'r+') as file:
#         text = file.read()
#         text = ...
#         file.seek(0)
#         file.write(text)
