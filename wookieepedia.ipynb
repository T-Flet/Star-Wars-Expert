# %% [markdown]
# # Generate a local copy of Wookieepedia pages for subsequent vectorisation
#
# (Best to get the web part done and can then rebuild a vector store quickly)

# %%
import requests
from bs4 import BeautifulSoup
from tqdm.auto import tqdm

import os
import re

from pathlib import Path
from collections import Counter

# %%
# Get character and location keywords to search by scanning the local copies of the 6 film scripts

all_matches, all_locations, all_likely_planets, all_likely_characters = set(), set(), set(), set()

for script in Path('scripts').iterdir():
    # if script.name == 'Episode VI - Return of the Jedi.txt':
    if script.is_file():
        print(script)
        with open(script, 'r') as file: text = file.read()
        text = re.sub(r'^[\t ]+', '', text, flags = re.MULTILINE) # No leading space
        matchesl = re.findall(r'^(?:\d+[\t ]+)?([A-Z][A-Z\.\-/ ]+[A-Z])[\t ]*(?::.+)?$', text, flags = re.MULTILINE) # All caps name-like line starts (possibly with scene number and possibly with colon and dialogue)
        print(matchesl)

        matches = set(matchesl)
        all_matches |= matches
        print(len(matches))
        print(matches)

        locations = {m[1].strip() for s in matches if (m := re.search(r'(?:INT|EXT|S )\.? ?([^-]+) ?.+', s))} # First portions of location descriptions
        all_locations |= locations
        print(locations)

        likely_planets = {k for k, n in Counter([l.split(' ')[0] for l in locations]).items() if n > 1} # Most mentioned 1-st words
        all_likely_planets |= likely_planets
        print(likely_planets)

        likely_characters = {s for s in matches if not re.search('INT|EXT|S ', s)}
        all_likely_characters |= likely_characters
        print(likely_characters)

        print()

print(len(all_matches))
print(sum(len(x) for x in [all_locations, all_likely_planets, all_likely_characters]))

matches_to_search = all_locations | all_likely_planets | all_likely_characters
# Out:
# scripts\Episode I - The Phantom Menace.txt
# ['TITLE CARD', 'INT. REPUBLIC CRUISER - COCKPIT', 'QUI-GON', 'CAPTAIN', 'QUI-GON', 'CAPTAIN', 'CAPTAIN', 'NUTE', 'INT. FEDERATION BATTLESHIP - DOCKING BAY - SPACE', 'INT. FEDERATION BATTLESHIP - CONFERENCE ROOM', 'OBI-WAN', 'QUI-GON', 'OBI-WAN', 'QUI-GON', 'OBI-WAN', 'QUI-GON', 'OBI-WAN', 'QUI-GON', 'INT. FEDERATION BATTLESHIP - BRIDGE', 'NUTE', 'DOFINE', 'INT. FEDERATION BATTLESHIP - HALLWAY', 'NUTE', 'INT. FEDERATION BATTLESHIP - BRIDGE', 'NUTE', 'RUNE', 'NUTE', 'RUNE', 'NUTE', 'RUNE', 'INT. FEDERATION BATTLESHIP - HALLWAY - OUTSIDE BRIDGE', 'INT. FEDERATION BATTLESHIP - BRIDGE', 'NUTE', 'RUNE', 'NUTE', 'RUNE', 'INT. FEDERATION BATTLESHIP - HALLWAY - OUTSIDE BRIDGE', 'QUI-GON', 'OBI-WAN', 'OBI-WAN', 'QUI-GON', 'INT. FEDERATION BATTLESHIP - BRIDGE', 'RUNE', 'TEY HOW', 'INT. FEDERATION BATTLESHIP - MAIN BAY', 'QUI-GON', 'OBI-WAN', 'QUI-GON', 'OBI-WAN', 'INT. FEDERATION BATTLESHIP - BRIDGE', 'TEY HOW', 'RUNE', 'NUTE', 'NUTE', 'AMIDALA', 'NUTE', 'AMIDALA', 'NUTE', 'AMIDALA', 'NUTE', 'AMIDALA', 'NUTE', 'AMIDALA', 'RUNE', 'NUTE', 'RUNE', 'NUTE', 'INT. NABOO PALACE - THRONE ROOM', 'PALPATINE', 'AMIDALA', 'CAPT. PANAKA', 'BIBBLE', 'CAPT. PANAKA', 'BIBBLE', 'AMIDALA', 'CAPT. PANAKA', 'AMIDALA', 'BIBBLE', 'CAPT. PANAKA', 'AMIDALA', 'EXT. NABOO SWAMP - SHALLOW LAKE - TWILIGHT', 'RUNE', 'NUTE', 'EXT. NABOO SWAMP - TWILIGHT', 'JAR JAR', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'OBI-WAN', 'QUI-GON', 'QUI-GON', 'OBI-WAN', 'JAR JAR', 'OBI-WAN', 'QUI-GON', 'JAR JAR', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'QUI-GON', 'QUI-GON', 'OBI-WAN', 'JAR JAR', 'EXT. NABOO SWAMP LAKE - TWILIGHT', 'QUI-GON', 'JAR JAR', 'JAR JAR', 'OBI-WAN', 'EXT. NABOO LAKE - UNDERWATER', 'INT. OTOH GUNGA - CITY SQUARE', 'JAR JAR', 'CAPT. TARPALS', 'JAR JAR', 'INT. OTOH GUNGA - HIGH TOWER BOARD ROOM', 'BOSS NASS', 'QUI-GON', 'BOSS NASS', 'OBI-WAN', 'BOSS NASS', 'OBI-WAN', 'BOSS NASS', 'QUI-GON', 'BOSS NASS', 'QUI-GON', 'BOSS NASS', 'QUI-GON', 'OBI-WAN', 'QUI-GON', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'OBI-WAN', 'QUI-GON', 'QUI-GON', 'BOSS NASS', 'QUI-GON', 'BOSS NASS', 'JAR JAR', 'QUI-GON', 'BOSS NASS', 'QUI-GON', 'BOSS NASS', 'JAR JAR', 'INT. SUB COCKPIT - UNDERWATER', 'JAR JAR', 'OBI-WAN', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'JAR JAR', 'OBI-WAN', 'JAR JAR', 'OBI-WAN', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'OBI-WAN', 'JAR JAR', 'QUI-GON', 'INT. FEDERATION BATTLESHIP - BRIDGE', 'NUTE', 'DARTH SIDIOUS', 'NUTE', 'DARTH SIDIOUS', 'NUTE', 'RUNE', 'NUTE', 'INT. SUB COCKPIT - UNDERWATER', 'OBI-WAN', 'QUI-GON', 'JAR JAR', 'OBI-WAN', 'JAR JAR', 'JAR JAR', 'QUI-GON', 'OBI-WAN', 'JAR JAR', 'QUI-GON', 'NUTE', 'JAR JAR', 'EXT. THEED - ESTUARY - DAY', 'JAR JAR', 'QUI-GON', 'JAR JAR', 'OBI-WAN', 'JAR JAR', 'JAR JAR', 'QUI-GON', 'QUI-GON', 'JAR JAR', 'OBI-WAN', 'JAR JAR', 'JAR JAR', 'OBI-WAN', 'JAR JAR', 'EXT. THEED - PALACE - DAY', 'INT. THEED - PALACE THRONE ROOM - DAY', 'BIBBLE', 'NUTE', 'AMIDALA', 'NUTE', 'EXT. PALACE - PLAZA - DAY', 'JAR JAR', 'QUI-GON', 'BIBBLE', 'QUI-GON', 'CAPT. PANAKA', 'QUI-GON', 'CAPT. PANAKA', 'INT. CENTRAL HANGER - HALLWAY - DAY', 'CAPT. PANAKA', 'QUI-GON', 'AMIDALA', 'QUI-GON', 'BIBBLE', 'CAPT. PANAKA', 'QUI-GON', 'BIBBLE', 'CAPT. PANAKA', 'BIBBLE', 'AMIDALA', 'PADME', 'QUI-GON', 'AMIDALA', 'INT. CENTRAL HANGER - DAY', 'CAPT. PANAKA', 'OBI-WAN', 'GUARD DROID', 'QUI-GON', 'DROID GUARD', 'INT. NABOO SPACECRAFT - COCKPIT', 'RIC OLIE', 'INT. NABOO SPACECRAFT - DROID HOLD', 'OBI-WAN', 'JAR JAR', 'JAR JAR', 'JAR JAR', 'RIC OLIE', 'RIC OLIE', 'QUI-GON', 'OBI-WAN', 'CAPT. PANAKA', 'QUI-GON', 'CAPT. PANAKA', 'OBI-WAN', 'CAPT. PANAKA', 'QUI-GON', 'INT. FEDERATION BATTLESHIP - CONFERENCE ROOM', 'NUTE', 'DARTH SIDIOUS', 'NUTE', 'DARTH SIDIOUS', 'NUTE', 'DARTH SIDIOUS', 'DARTH SIDIOUS', 'NUTE', 'NUTE', 'RUNE', 'INT. NABOO SPACECRAFT - QUEENS CHAMBERS', 'CAPT. PANAKA', 'AMIDALA', 'CAPT. PANAKA', 'AMIDALA', 'AMIDALA', 'QUI-GON', 'CAPTAIN PANAKA', 'QUI-GON' ...
# 167
# {'GUARD', 'INT. NABOO PALACE - THRONE ROOM', 'THREEPIO', 'INT. PALACE OF THE JEDI - COUNCIL CHAMBERS - SUNSET', 'KITSTER', 'EXT. CORUSCANT - SENATE LANDING PLATFORM - DAY', 'INT. FEDERATION BATTLESHIP - HALLWAY', 'EXT. NABOO GRASS PLAINS - DAY', 'EXT. TATOOINE - STREET - SLAVE QUARTERS - DAY', 'WATTO', 'INT. ANBOO SPACECRAFT - COCKPIT', 'INT. NABOO CRUISER COCKPIT - DAY', 'EXT . NABOO GRASS PLAINS DAY', 'FIGHTER PILOT', 'CAPTAIN PANAKA', 'EXT. PALACE OF THE JEDI - BALCONY - SUNSET', 'FOUR', 'FODE/BEED', 'ASSEMBLY', 'GUARDS', 'EXT MOS ESPA - SLAVE QUARTERS - PORCH - DAY', 'IRIS OUT', 'EXT. THEED - PALACE - OVER WATERFALL - DAY', 'INT. COCKPIT - SPACE', 'RABE', 'EXT. TATOOINE - NABOO SPACECRAFT RAMP - DAY', 'NUTE', 'EXT. TATOOINE - DESERT - NABOO SPACECRAFT - DAY', 'EXT. TATOOINE - DESERT MESA - DAY', 'KI-ADI', 'FANTA', 'EXT. NABOO SWAMP - SHALLOW LAKE - TWILIGHT', 'INT. NABOO PALACE - THRONE ROOM - DAY', 'AKS MOE', 'DOFINE', 'BRAVO TWO', 'INT. NABOO SPACECRAFT - COCKPIT', 'VALORUM', 'GUARD DROID', 'EXT. THEED - PALACE - DAY', 'EXT. MOS ESPA - ARENA - GRANDSTAND - DAY', 'INT. THEED - PALACE - HALLWAY TO THRONE ROOM', 'EXT. TATOOINE - DESERT - SPACESHIP - DAY', 'EXT. THEED - CENTRAL HANGER - DAY', 'AMIDALA', 'BAIL ORGANA', 'INT. THEED - PALACE - THRONE ROOM - DAY', 'INT. NABOO STARFIGHTER - COCKPIT -SPACE', 'INT. THEED - POWER GENERATOR - MELTING PIT', 'INT. THEED - PALACE THRONE ROOM - DAY', 'BRAVO THREE', 'INT. THEED - POWER GENERATOR PIT - DAY', 'DROID GUARD', 'GUNGAN LOOKOUT', 'EXT. MOS ESPA - DESERT RACE ARENA - DAY', 'CAPT. TARPALS', 'EXT. MOS ESPA - SLAVE QUARTERS - BACK YARD - DAY', 'RUNE', 'EXT. MOS ESPA - STREET - DAY', 'SHMI', 'PADME', 'INT. OTOH GUNGA - CITY SQUARE', 'INT. NABOO STARFIGHTER - COCKPIT - FEDERATION HANGER', 'INT. OTOH GUNGA - HIGH TOWER BOARD ROOM', 'PALAPATINE', 'INT. NABOO FIGHTER - COCKPIT - SPACE', 'SABE', 'INT. FEDERATION BATTLESHIP - CONFERENCE ROOM', 'INT. TEMPLE OF THE JEDI - COUNCIL CHAMBERS - DAY', 'EXT. MOS ESPA - ARENA - MAIN HANGER - DAY', 'EXT. NABOO GRASS PALINS - DAY', 'ANAKN', 'EXT. TATOOINE - DESERT MESA - NIGHT', 'EXT. NABOO EDGE OF SWAMP/ GRASS PLAINS - DAY', 'EXT. MOS ESPA - STREET - SLAVE QUARTERS - DAY', 'INT. MOS ESPA - ARENA - MAIN HANGER - DAY', 'INT. NABOO SPACECRAFT - MAIN AREA', 'INT. FEDERATION BATTLESHIP - BRIDGE', 'PALPATINE', 'CAPT. PANAKA', 'INT. FEDERATION BATTLESHIP - HALLWAY - OUTSIDE BRIDGE', 'ANAKNI', 'FODE BEED', 'EXT. MOS ESPA - SLAVE QUARTERS - PORCH - DAY', 'INT. THED - PALACE THRONE ROOM - DAY', 'EXT. NABOO SWAMP LAKE - DAY', 'EXT. MOS ESPA - STREET - ALCOVE - DAY', 'EXT. THEED - ESTUARY - DAY', 'DARTH MAUL', 'JAR JAR', 'DARTH SIDIOUS', 'EXT. NABOO SWAMP - DAY', 'EXT. SLAVE QUARTERS - BALCONY - NIGHT', 'LOTT DOD', 'EXT. MOS ESPA - SLAVE QUARTERS - BACK YARD - SUNRISE', 'INT. NABOO SPACECRAFT - QUEENS CHAMBERS', 'BOSS NASS', 'EXT. MOS ESPA - STREET - MARKET - DAY', 'GUI-GON', 'JIRA', 'INT. MAIN HANGER - COURTYARD - DAY', 'EXT. MOS ESPA - SLAVE QUARTERS - STREET - SANDSTORM - DAY', 'INT. SPACE - NABOO SPACECRAFT COCKPIT', 'TEY HOW', 'INT. SUB COCKPIT - UNDERWATER', 'INT. FEDERATION BATTLESHIP - DOCKING BAY - SPACE', 'JABBA', 'INT. TURRET ROOM - NABOO PALACE - LATE DAY', 'TITLE CARD', 'MAD AMEDDA', 'SEEK', 'EXT. NABOO SWAMP LAKE - TWILIGHT', 'EXT. CORUSCANT - BALCONY OVERLOOKING CITY - NIGHT', 'QUI-GON', 'INT. CENTRAL HANGER - DAY', 'EXT. NABOO LAKE - UNDERWATER', 'EXT. MOS ESPA - ARENA - STARTING GRID - DAY', 'INT. NABOO SPACECRAFT - MAIN HOLD', 'EXT. MOS ESPA - STREET - FRUIT STAND - DAY', 'INT. MAIN ROTUNDA - GALACTIC SENATE - DAY', 'EXT. THEED - CENTRAL PLAZA - DAY', 'SEBULBA', 'EXT. NABOO SPACECRAFT - MAIN AREA', 'EXT. THEED - CENTRAL PLAZA - FUNERAL TEMPLE STEPS - SUNSET', 'EXT. MOS ESPA - SLAVE QUARTERS - PORCH - SUNRISE', 'INT. THEED - PALACE - HALLWAY - DAY', 'WALD', 'VENDOR', 'CAPTAIN', 'INT. NABOO SPACECRAFT - DROID HOLD', 'INT. THEED - POWER GENERATOR ELECRIC BEAM - HALLWAY', 'EXT. MOS ESPA - JUNK DEALER PLAZA - DAY', 'GENERAL CEEL', 'EXT MOS ESPA - S ...
# {'OU', 'NABOO PALACE', 'NABOO GRASS PLAINS', 'THEED', 'TEMPLE OF THE JEDI', 'SPACE', 'NABOO SPACECRAFT', 'PALPATINES QUARTERS', 'MOS ESPA', 'ANBOO SPACECRAFT', 'SLAVE QUARTERS', 'MAIN ROTUNDA', 'NABOO LAKE', 'AMEDD', 'OTOH GUNGA', 'FEDERATION BATTLESHIP', 'NABOO CRUISER COCKPIT', 'NABOO SWAMP LAKE', 'TURRET ROOM', 'CENTRAL HANGER', 'CORUSCANT', 'NABOO SACRED TEMPLE RUINS', 'SUB COCKPIT', 'NAS', '. NABOO GRASS PLAINS DA', 'NABOO FIGHTER', 'THED', 'PALACE OF THE JEDI', 'NABOO STARFIGHTER', 'NABOO SWAMP', 'NABOO GRASS PALINS', 'NABOO EDGE OF SWAMP/ GRASS PLAINS', 'MAIN HANGER', 'COCKPIT', 'REPUBLIC CRUISER', 'PALACE', 'TATOOINE', 'MO'}
# {'MAIN', 'NABOO', 'PALACE'}
# {'GUARD', 'WALD', 'THREEPIO', 'VENDOR', 'KITSTER', 'CAPTAIN', 'DOFINE', 'PANAKA', 'BRAVO TWO', 'PALPATINE', 'CAPT. PANAKA', 'ANAKNI', 'WATTO', 'FODE BEED', 'VALORUM', 'GUARD DROID', 'GENERAL CEEL', 'AMIDALA', 'FIGHTER PILOT', 'BAIL ORGANA', 'CAPTAIN PANAKA', 'DARTH MAUL', 'FOUR', 'JAR JAR', 'FODE/BEED', 'BRAVO THREE', 'DARTH SIDIOUS', 'ASSEMBLY', 'LOTT DOD', 'DROID GUARD', 'GUARDS', 'GUNGAN LOOKOUT', 'GUI-GON', 'OBI-WAN', 'RIC OLIE', 'JIRA', 'CAPT. TARPALS', 'ANAKIN', 'RUNE', 'BIBBLE', 'SHMI', 'PADME', 'TEY HOW', 'JABBA', 'RABE', 'TITLE CARD', 'MAD AMEDDA', 'YODA', 'ARTOO BEEPS', 'PILOT', 'SEEK', 'NUTE', 'ANKAIN', 'PALAPATINE', 'QUI-GON', 'GREEDO', 'SABE', 'KI-ADI', 'MACE WINDU', 'FANTA', 'AMEE', 'ODY', 'ANAKN', 'BATTLE DROID CAPTAIN', 'SEBULBA'}
#
# scripts\Episode II - Attack of the Clones.txt
# ['EXT. SPACE', 'CAPTAIN TYPHO', 'PADM', 'CORD', 'AMIDALA', 'AMIDALA', 'CAPTAIN TYPHO', 'CAPTAIN TYPHO', 'EXT. SENATE BUILDING - DAY', 'INT. SENATE CHAMBER - DAY', 'MAS AMEDDA', 'PALPATINE', 'PALPATINE', 'SENATOR ASK AAK', 'AMBASSADOR DARSANA', 'ORN FREE TAA', 'PALPATINE', 'AMIDALA', 'PALPATINE', 'PADM', 'PADM', 'PADM', 'ORN FREE TAA', 'PALPATINE', 'EXT. EXECUTIVE QUARTERS BUILDING - DAY', 'PALPATINE', 'MACE WINDU', 'PALPATINE', 'MACE WINDU', 'PALPATINE', 'YODA', 'PALPATINE', 'MACE WINDU', 'YODA', 'DAR WAC', 'PALPATINE', 'YODA', 'PADM', 'MACE WINDU', 'PADM', 'MACE WINDU', 'KI-ADI-MUNDI', 'YODA', 'PALPATINE', 'PADM', 'PALPATINE', 'BAIL ORGANA', 'PADM', 'PALPATINE', 'PADM', 'PALPATINE', 'MACE WINDU', 'PALPATINE', 'PADM', 'PALPATINE', 'MACE WINDU', 'YODA', 'PALPATINE', 'EXT. SENATE APARTMENTS - TWILIGHT', 'JAR JAR', 'OBI-WAN', 'JAR JAR', 'JAR JAR', 'ANAKIN', 'JAR JAR', 'JAR JAR', 'OBI-WAN', 'PADM', 'OBI-WAN', 'PADM', 'ANAKIN', 'PADM', 'OBI-WAN', 'CAPTAIN TYPHO', 'PADM', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'PADM', 'CAPTAIN TYPHO', 'JAR JAR', 'ANAKIN', 'JAR JAR', 'OBI-WAN', 'ANAKIN', 'EXT. JEDI TEMPLE - EVENING', 'MACE WINDU', 'YODA', 'MACE WINDU', 'YODA', 'MACE WINDU', 'YODA', 'MACE WINDU', 'YODA', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'EXT. SENATE APARTMENTS - ENTRANCE - NIGHT', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'ANAKIN', 'EXT. ENTERTAINMENT STREET - NIGHT', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'INT. NIGHTCLUB - NIGHT', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ELAN SLEAZEBAGGANO', 'OBI-WAN', 'ELAN', 'OBI-WAN', 'ELAN', 'ANAKIN', 'EXT. ALLEY OUTSIDE NIGHTCLUB - NIGHT', 'OBI-WAN', 'ZAM WESSEL', 'OBI-WAN', 'ZAM WESSEL', 'ANAKIN', 'ZAM WESSEL', 'OBI-WAN', 'ANAKIN', 'ZAM', 'OBI-WAN', 'PADM', 'JAR JAR', 'PADM', 'JAR JAR', 'PADM', 'JAR JAR', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADME', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'CAPTAIN TYPHO', 'PADM', 'DORME', 'PADM', 'DORME', 'PADM', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'PADM', 'ANAKIN', 'PADM', 'OBI-WAN', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'OBI-WAN', 'CAPTAIN TYPHO', 'EXT. FREIGHTER DOCKS - CORUSCANT - DAY', 'OBI-WAN', 'OBI-WAN', 'OBI-WAN', 'SERVER', 'FOOD SERVER', 'ANAKIN', 'ANAKIN', 'PADM', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'ANAKIN', 'PADM', 'ANAKIN', 'HERMIONE', 'OBI-WAN', 'HERMIONE BAGWA', 'OBI-WAN', 'HERMIONE BAGWA', 'DEXTER JETTSTER', 'OBI-WAN', 'DEXTER JETTSTER', 'HERMIONE BAGWA', 'OBI-WAN', 'DEXTER JETTSTER', 'OBI-WAN', 'DEXTER JETTSTER', 'OBI-WAN', 'DEXTER JETTSTER', 'DEXTER JETTSTER', 'OBI-WAN', 'DEXTER JETTSTER', 'OBI-WAN', 'DEXTER JETTSTER', 'OBI-WAN', 'DEXTER JETTSTER', 'OBI-WAN', 'DEXTER JETTSTER', 'OBI-WAN', 'DEXTER JETTSTER', 'EXT. NABOO SPACEPORT - DAY', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'ANAKIN', 'PADM', 'QUEEN JAMILLIA', 'PADM', 'SIO BIBBLE', 'QUEEN JAMILLIA', 'PADM', 'SIO  ...
# 84
# {'BERU', 'DORME', 'THREEPIO', 'DOOKU', 'JANGO', 'EXT. EXECUTIVE QUARTERS BUILDING - DAY', 'WATTO', 'JOCASTA NU', 'COUNT DOOKU', 'CAPTAIN TYPHO', 'NUTE GUNRAY', 'CHILDREN', 'SOLA', 'LAMA SU', 'INT. SENATE CHAMBER - DAY', 'BOBA FETT', 'JANGO FETT', 'INT. TUSKEN RAIDER HUTT - NIGHT', 'INT. GEONOSIS TUNNEL TO EXECUTION ARENA - DAY', 'CLONE CAPTAIN', 'EXT. ALLEY OUTSIDE NIGHTCLUB - NIGHT', 'DAR WAC', 'PADM', 'INT. NIGHTCLUB - NIGHT', 'DEXTER JETTSTER', 'POGGLE', 'JOVAL', 'SENATOR ASK AAK', 'INT. GUNSHIP NUMBER TWO - DAY', 'EXT. SENATE APARTMENTS - ENTRANCE - NIGHT', 'SUN RIT', 'SIO BIBBLE', 'OWEN', 'AMIDALA', 'ZAM', 'BAIL ORGANA', 'SHMI', 'PADME', 'MACE-WINDU', 'THE END', 'JEDI CHILD MAY', 'FOOD SERVER', 'MACE', 'ELAN SLEAZEBAGGANO', 'EXT. SENATE APARTMENTS - TWILIGHT', 'PLO KOON', 'DROID CAPTAIN', 'ORN FREE TAA', 'SERVER', 'PALPATINE', 'TAUN WE', 'EXT. JEDI TEMPLE - EVENING', 'JAR JAR', 'DARTH SIDIOUS', 'WINDU', 'BOBA', 'ZAM WESSEL', 'OBI-WAM', 'HERMIONE BAGWA', 'HERMIONE', 'EXT. NABOO LAKE RETREAT - NIGHT', 'PAMDE', 'EXT. NABOO SPACEPORT - DAY', 'EXT. ENTERTAINMENT STREET - NIGHT', 'CORD', 'ELAN', 'CLIEGG', 'KI-ADI-MUNDI', 'AMBASSADOR DARSANA', 'OBI-WAN', 'JOBAL', 'ANAKIN', 'RUWEE', 'YODA', 'ARTOO BEEPS', 'EXT. SENATE BUILDING - DAY', 'JEDI CHILD JACK', 'EXT. FREIGHTER DOCKS - CORUSCANT - DAY', 'INT. GUNSHIP NUMBER ONE - DAY', 'EXT. JEDI TEMPLE - DAY', 'MACE WINDU', 'QUEEN JAMILLIA', 'EXT. SPACE', 'MAS AMEDDA'}
# {'ER JETTSTE', 'NABOO LAKE RETREAT', 'NABOO SPACEPORT', 'SENATE BUILDING', 'FREIGHTER DOCKS', 'EXECUTIVE QUARTERS BUILDING', 'GEONOSIS TUNNEL TO EXECUTION ARENA', 'SENATE APARTMENTS', 'NIGHTCLUB', 'SENATE CHAMBER', 'ALLEY OUTSIDE NIGHTCLUB', 'GUNSHIP NUMBER TWO', 'SPAC', 'GUNSHIP NUMBER ONE', 'JEDI TEMPLE', 'AMEDD', 'TUSKEN RAIDER HUTT', 'ENTERTAINMENT STREET'}
# {'SENATE', 'GUNSHIP', 'NABOO'}
# {'BERU', 'THREEPIO', 'DORME', 'JOVAL', 'CLIEGG', 'SENATOR ASK AAK', 'ORN FREE TAA', 'DOOKU', 'SERVER', 'KI-ADI-MUNDI', 'JANGO', 'PALPATINE', 'AMBASSADOR DARSANA', 'WATTO', 'TAUN WE', 'JOCASTA NU', 'SUN RIT', 'SIO BIBBLE', 'OWEN', 'AMIDALA', 'ZAM', 'BAIL ORGANA', 'OBI-WAN', 'JAR JAR', 'DARTH SIDIOUS', 'WINDU', 'COUNT DOOKU', 'BOBA', 'CAPTAIN TYPHO', 'NUTE GUNRAY', 'ZAM WESSEL', 'JOBAL', 'CHILDREN', 'SOLA', 'LAMA SU', 'OBI-WAM', 'ANAKIN', 'RUWEE', 'BOBA FETT', 'JANGO FETT', 'SHMI', 'PADME', 'MACE-WINDU', 'HERMIONE BAGWA', 'HERMIONE', 'PAMDE', 'YODA', 'ARTOO BEEPS', 'CLONE CAPTAIN', 'THE END', 'JEDI CHILD JACK', 'CORD', 'ELAN', 'JEDI CHILD MAY', 'FOOD SERVER', 'MACE', 'ELAN SLEAZEBAGGANO', 'MACE WINDU', 'DAR WAC', 'PADM', 'PLO KOON', 'QUEEN JAMILLIA', 'POGGLE', 'DROID CAPTAIN'}
#
# scripts\Episode III - Revenge of the Sith.txt
# ['EXT. SPACE', 'INT. ANAKINS STARFIGHTER COCKPIT-SPACE', 'ANAKIN', 'OBI-WAN', 'EXT. CORUSCANT-SPACE BATTLE', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'ANAKIN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ODD BALL', 'OBI-WAN', 'ODD BALL', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ODD BALL', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'ANAKIN', 'ODD BALL', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'INT. BRIDGE-TRADE FEDERATION CRUISER', 'GENERAL GRIEVOUS', 'CAPTAIN', 'GENERAL GRIEVOUS', 'INT. HANGAR-TRADE FEDERATION CRUISER', 'BODYGUARD I', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'INT. GENERATOR ROOM-TRADE FEDERATION CRUISER', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'INT. VENT SHAFT-TRADE FEDERATION CRUISER', 'ANAKIN', 'INT. SMALL PASSAGEWAY-TRADE FEDERATION CRUISER', 'INT. HALLWAY-TRADE FEDERATION CRUISER', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'INT. VENT SHAFT-TRADE FEDERATION CRUISER', 'INT. GENERATOR ROOM-TRADE FEDERATION CRUISER', 'EXT. TRADE FEDERATION CRUISER-BATTLE', 'INT. HALLWAY-TRADE FEDERATION CRUISER', 'OBI-WAN', 'INT. WIDE HALLWAY-TRADE FEDERATION CRUISER', 'ANAKIN', 'BATTLE DROID', 'INT HANGAR-TRADE FEDERATION CRUISER', 'INT. ELEVATOR-TRADE FEDERATION CRUISER', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'INT MAIN HANGAR-TRADE FEDERATION CRUISER', 'INT. ELEVATOR-TRADE FEDERATION CRUISER', 'OBI-WAN', 'OBI-WAN', 'INT MAIN HANGAR-TRADE FEDERATION CRUISER', 'OBI-WAN', 'INT. ELEVATOR SHAFT-TRADE FEDERATION CRUISER', 'INT. ELEVATOR-TRADE FEDERATION CRUISER', 'OBI-WAN', 'INT. ELEVATOR SHAFT-TRADE FEDERATION CRUISER', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'OBI-WAN', 'INT. ELEVATOR-TRADE FEDERATION CRUISER', 'OBI-WAN', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'INT. ELEVATOR-TRADE FEDERATION CRUISER', 'OBI-WAN', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'INT. ELEVATOR SHAFT-TRADE FEDERATION CRUISER', 'OBI-WAN', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'INT. ELEVATOR SHAFT-TRADE FEDERATION CRUISER', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'OBI-WAN', 'ANAKIN', 'PALPATINE', 'OBI-WAN', 'ANAKIN', 'PALPATINE', 'OBI-WAN', 'COUNT DOOKU', 'OBI-WAN', 'COUNT DOOKU', 'ANAKIN', 'COUNT DOOKU', 'COUNT DOOKU', 'COUNT DOOKU', 'PALPATINE', 'ANAKIN', 'PALPATINE', 'ANAKIN', 'PALPATINE', 'ANAKIN', 'ANAKIN', 'PALPATINE', 'PALPATINE', 'ANAKIN', 'PALPATINE', 'ANAKIN', 'INT. BRIDGE-TRADE FEDERATION CRUISER', 'GENERAL GRIEVOUS', 'PILOT', 'INT. BATTLESTATIONS-REPUBLIC CRUISER', 'ANAKIN', 'ANAKIN', 'ANAKIN', 'INT. BRIDGE-TRADE FEDERATION CRUISER', 'PILOT', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'INT. BRIDGE-TRADE FEDERATION CRUISER', 'PILOT', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'EXT. SPACE-CORUSCANT', 'ANAKIN', 'INT. BRIDGE-TRADE FEDERATION CRUISER', 'GENERAL GRIEVOUS', 'PILOT', 'INT. ELEVATOR SHAFT ON SIDE-TRADE FEDERATION CRUISER', 'ANAKIN', 'OBI-WAN', 'ANAKINN', 'OBI-WAN', 'OBI-WAN', 'ANAKIN', 'OBI-WAN', 'INT. ELEVATOR LOBBY-TRADE FEDERATION CRUISER', 'OBI-WAN', 'ANAKIN', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'INT. HALLWAY TO HANGAR BAY-TRADE FEDERATION CRUISER', 'INT. DOORW ...
# 201
# {'DABTH SIDIOUS', 'GUARD', 'THREEPIO', 'BODYGUARD I', 'EXT. CATO XEIMOIDIA-JEDI STARFIGHTER-DAY', 'EXT. CORUSCANT-SENATE OFFICE BUILDING-UNDERGROUND LANDING PLATFORM-DAY', 'CLONE COMMANDER GREE', 'EXT. UTAPAU-UNDERWATER CAVES-DAY', 'INT. KASHYYYK-HOLOGRAM AREA-DAY', 'EXT. CORUSCANT-SENATE LANDING PLATFORM-LATE DAY', 'ROYAL GUARD', 'EXT. UTAPAU-UNDERWATER SINKHOLE-DAY', 'AT-ST CLONE SERGEANT', 'INT. CORUSCANT-PADME SAPARTMENT-PRE-DAWN', 'EXT. NABOO-ALDERAAN STARCRUISER', 'INT. HANGAR DOORWAY-TRADE FEDERATION CRUISER', 'EXT. MUSTAFAR-LANDING PLATFORM-NABOO SKIFF-DAY', 'EXT. KASHYYYK-BEACH HEAD-DAY', 'EXT. KASHYYYK-MEETING HALL BALCONY-DAY', 'EXT. UTAPAU-OBSERVATION DECK-DAY', 'INT. HALLWAY TO HANGAR BAY-TRADE FEDERATION CRUISER', 'COUNT DOOKU', 'EXT. CORUSCANT-INDUSTRIAL LANDING PLATFORM-AFTERNOON', 'EXT. MUSTAFAR-LAVA FIELDS-DAY', 'EXT. FELUCIA-FOREST-DAY', 'CAPTAIN TYPHO', 'INT. SMALL PASSAGEWAY-TRADE FEDERATION CRUISER', 'NUTE GUNRAY', 'CLONE TROOPER', 'INT. CORUSCANT-JEDI TEMPLE-COMPUTER ROOM-NIGHT', 'INT. MUSTAFAR-VOLCANO PIT-DAY', 'INT. BATTLESTATIONS-REPUBLIC CRUISER', 'EXT. UTAPAU-SPACE', 'INT. POLIS MASSA-MEDICAL CENTER-NIGHT', 'INT. WIDE HALLWAY-TRADE FEDERATION CRUISER', 'EXT. UTAPAU-SINKHOLE WALL-LIZARD-DAY', 'EXT. SALEUCAMI-FOREST', 'EXT. CORUSCANT-JEDI TEMPLE-LATE DAY', 'CLONE CAPTAIN', 'INT. ALDERAAN-STARCRUISER-HALLWAY-DAY', 'MOTEE', 'INT. CATO NEIMOIDIA-COCKPIT CLONE FIGHTER-DAY', 'EXT. CORUSCANT-JEDI TEMPLE-LANDING PLATFORM-PRE-DAWN', 'CHI EEKWAY', 'INT. MUSTAFAR-MAIN CONTROL CENTER-DAY', 'INT. CORUSCANT-SENATE OFFICE BUILDING-MAIN HALLWAY-LATE AFTERNOON', 'INT. ANAKINS STARFIGHTER COCKPIT-SPACE', 'INT. UTAPAU-CITY-DRAGON CORRAL-DAY', 'INT. ELEVATOR SHAFT ON SIDE-TRADE FEDERATION CRUISER', 'EXT. DAGOBAH-DAY', 'BATTLE DROID', 'ODD BALL', 'EXT. SPACE-CORUSCANT', 'CAPTAIN ANTILLES', 'INT. CORUSCANT-IMPERIAL REHAB CENTER-DAY', 'MAS AMEDDA', 'INT. ALDERAAN STARCRUISER-HALLWAY- SPACE', 'INT. CORUSCANT-CHANCELLOR S OFFICE-EARLY EVENING', 'INT. CORUSCANT-GALAXIES OPERA HOUSE-NIGHT', 'EXT. CORUSCANT-SENATE BUILDING-SUNSET', 'INT. CORUSCANT-JEDI TEMPLE-HALLWAY-SUNSET', 'EXT. MUSTAFAR-VOLCANO PIT-DAY', 'INT. ALDERAAN CRUISER-CONFERENCE ROOM', 'INT. UTAPAU-CITY TUNNEL SYSTEM-DAY', 'INT. CORUSCANT-JEDI TEMPLE-HALLWAY OUTSIDE COUNCIL CHAMBERS-DAY', 'EXT. CORUSCANT-SENATE OFFICE BUILDING-NIGHT', 'BODYGUARD', 'EXT. MYGEETO-DAWN', 'BAIL ORGANA', 'INT. HALLWAY-TRADE FEDERATION CRUISER', 'EXT. KASHYYYK-EDGE OF VILIAGE-DAY', 'EXT. LANDING PLATFORM-CORUSCANT-IMPERIAL REHAB CENTER-DAY', 'INT. MAIN HANGAR-TRADE FEDERATION CRUISER', 'EXT. CORUSCANT-SENATE OFFICE BUILDING-SUNSET', 'INT. CORUSCANT-SENATE OFFICE BUILDING-MAIN HALLWAY-DAY', 'INT. CORUSCANT-JEDI TEMPLE-BATTLE-NIGHT', 'INT. MUSTAFAR-MAIN CONTROL CENTER-HALLWAY-DAY', 'EXT. CORUSCANT-CITYSCAPE-PRE-DAWN', 'EXT. MUSTAFAR-MAIN CONTROL CENTER BALCONY-DAY', 'CLONE COMMANDER BACARA', 'EXT. KASHYYYK-MEETING HALL-DAY', 'INT. MUSTAFAR-CONTROL CENTER-BALCONY-DAY', 'INT. NABOO SKIFF', 'ANAKINN', 'INT. CORUSCANT-SENATE CHAMBER-SUNSET', 'EXT. KASHYYYK-DAY', 'INT. MUSTAFAR-MAIN CONTROL CENTER-CONFERENCE ROOM-DAY', 'MEDICAL DROID', 'PADME', 'INT. CORUSCANT-JEDI GUNSHIP-DAY', 'EXT. MUSTAFAR-JEDI STARFIGHTER-SPACE', 'EXT. CORUSCANT-SPACE BATTLE', 'INT. CORUSCANT-JEDI WAR ROOM-EARLY EVENING', 'MON MOTHMA', 'INT ALDERAAN-STARCRUISER-HALLWAY-DAY', 'BLY', 'EXT. CORUSCANT-CLONE LANDING PLATFORM-DAY', 'MACE', 'EXT. NABOO-MAIN SQUARE-DAWN', 'EXT. HULL-TRADE FEDERATION CRUISER-SPACE', 'PLO KOON', 'INT. CATO NEIMOIDIA-JEDI STARFIGHTER-DAY', 'INT. POLIS MASSA-OBSERVATION DOME-NIGHT', 'EXT. MUSTAFAR-VOLCANO EDGE-DAY', 'EXT. CORUSCANT-SENATE OFFICE BUILDING-LANDING PLATFORM-EARLY EVENING', 'INT. ELEVATOR-TRADE FEDERATION CRUISER', 'BAIL', 'INT. MUSTAFAR-COXFERENCE ROOM-DAY', 'EXT. TRADE FEDERATION CRUISER-BATTLE', 'PALPATINE', 'INT. ESCAPE POD-SPACE', 'INT. JEDI GUNSHIP-LANDING PLATFORM-EARLY EVENING', 'INT HANGAR-TRADE FEDERATION CRUISER', 'EXT. UTAPAU-SINKHOLE WALL-LATE DAY', 'FANG ZAR', 'CLONE COMMAND ...
# {'ELEVATOR SHAFT', 'ALDERAAN', 'JEDI GUNSHIP', 'HANGAR', 'CATO NEIMOIDIA', 'POD BAY', 'WIDE HALLWAY', 'ALDERAAN CRUISER', 'IMPERIAL STAR DESTROYER', 'SPAC', 'SPACE', 'MUSTAFAR', 'ESCAPE POD', 'FELUCIA', 'DAGOBAH', 'BRIDGE', 'AMEDD', 'UTAPAU', 'REPUBLIC BATTLE CRUISER', 'HALLWAY TO HANGAR BAY', 'HALLWAY', 'GENERATOR ROOM', 'CORUSCANT', 'NABOO SKIF', 'POLIS MASSA', 'MAIN HANGAR', 'CATO XEIMOIDIA', 'ELEVATOR LOBBY', 'ELEVATOR SHAFT ON SIDE', 'LANDING PLATFORM', 'CRUISER', 'VENT SHAFT', 'KASHYYYK', 'SALEUCAMI', 'HULL', 'ELEVATOR', 'TRADE FEDERATION CRUISER', 'MYGEETO', 'UTAPAU STAIRWAY', 'SMALL PASSAGEWAY', 'ANAKINS STARFIGHTER COCKPIT', 'HANGAR DOORWAY', 'NABOO', 'BATTLESTATIONS', 'DOORWAY TO HANGAR BAY', 'JEDI FIGHTER', 'TATOOINE', 'ALDERAAN STARCRUISER'}
# {'ALDERAAN', 'HANGAR', 'UTAPAU', 'NABOO', 'CATO', 'ELEVATOR', 'JEDI', 'HALLWAY'}
# {'ODD BALL', 'DABTH SIDIOUS', 'GUARD', 'CAPTAIN ANTILLES', 'THREEPIO', 'AAYLA', 'BODYGUARD I', 'CAPTAIN', 'BAIL', 'FANGZAR', 'CLONE COMMANDER GREE', 'PALPATINE', 'BANA BREEMU', 'DARTH VADER', 'FANG ZAR', 'ROYAL GUARD', 'AT-ST CLONE SERGEANT', 'CLONE COMMANDER THIRE', 'BODYGUARD', 'YOUNGLINGS', 'BAIL ORGANA', 'OBI-WAN', 'JAR JAR', 'DARTH SIDIOUS', 'COUNT DOOKU', 'WRANGLER', 'ANAKIN/OBI-WAN', 'CAPTAIN TYPHO', 'NUTE GUNRAY', 'CLONE TROOPER', 'QUI -GON', 'CLONE SERGEANT', 'CLONE COMMANDER BACARA', 'ANAKIN', 'CLONE COMMANDER APPO', 'CLONE COMMANDER CODY', 'GIDDEAN DANU', 'ANAKINN', 'MEDICAL DROID', 'PADME', 'SUPER BATTLE DROID', 'YODA', 'PILOT', 'MON MOTHMA', 'CLONE CAPTAIN', 'MOTEE', 'CREATURE', 'CHI EEKWAY', 'BLY', 'RUNE HAAKO', 'GENERAL GRIEVOUS', 'MACE', 'QUI-GON', 'MACE WINDU', 'TERR TANEEL', 'PLO KOON', 'CLONE PILOT', 'BATTLE DROID'}
#
# scripts\Episode IV - A New Hope.txt
# ['STAR WARS', 'A NEW HOPE', 'JOURNAL OF THE WHILLS', 'INT. REBEL BLOCKADE RUNNER - MAIN PASSAGEWAY', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'EXT. SPACECRAFT IN SPACE', 'INT. REBEL BLOCKADE RUNNER', 'THREEPIO', 'EXT. TATOOINE - DESERT WASTELAND - DAY', 'LUKE', 'INT. REBEL BLOCKADE RUNNER - MAIN HALLWAY', 'INT. REBEL BLOCKADE RUNNER', 'INT. REBEL BLOCKADE RUNNER', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'INT. REBEL BLOCKADE RUNNER - CORRIDOR', 'IMPERIAL OFFICER', 'VADER', 'VADER', 'REBEL OFFICER', 'VADER', 'VADER', 'INT. REBEL BLOCKADE RUNNER - SUBHALLWAY', 'TROOPER', 'TROOPER', 'INT. REBEL BLOCKADE RUNNER - SUBHALLWAY', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'INT. IMPERIAL STARDESTROYER', 'CHIEF PILOT', 'CAPTAIN', 'INT. LIFEPOD', 'THREEPIO', 'THREEPIO', 'EXT. TATOOINE - ANCHORHEAD SETTLEMENT - POWER STATION - DAY', 'WOMAN', 'INT. POWER STATION - DAY', 'FIXER', 'CAMIE', 'LUKE', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'DEAK', 'DAY', 'LUKE', 'BIGGS', 'LUKE', 'LUKE', 'CAMIE', 'FIXER', 'INT. REBEL BLOCKADE RUNNER - HALLWAY', 'LEIA', 'VADER', 'LEIA', 'VADER', 'COMMANDER', 'VADER', 'COMMANDER', 'VADER', 'SECOND OFFICER', 'VADER', 'COMMANDER', 'EXT. SPACE', 'EXT. TATOOINE - DESERT', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'EXT. TATOOINE - DUNE SEA', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'EXT. TATOOINE - ANCHORHEAD SETTLEMENT - POWER STATION - DAY', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'LUKE', 'BIGGS', 'EXT. TATOOINE - ROCK CANYON - SUNSET', 'EXT. TATOOINE - ROCK CANYON - SANDCRAWLER - SUNSET', 'INT. SANDCRAWLER - HOLD AREA', 'INT. SANDCRAWLER - PRISON AREA', 'THREEPIO', 'EXT. TATOOINE - ROCK CANYON - SANDCRAWLER - SUNSET', 'EXT. TATOOINE - DESERT - DAY', 'FIRST TROOPER', 'SECOND TROOPER', 'EXT. TATOOINE - DUNES', 'INT. SANDCRAWLER', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'EXT. TATOOINE - DESERT - LARS HOMESTEAD - AFTERNOON', 'BERU', 'LUKE', 'OWEN', 'THREEPIO', 'OWEN', 'THREEPIO', 'OWEN', 'THREEPIO', 'OWEN', 'THREEPIO', 'OWEN', 'LUKE', 'OWEN', 'LUKE', 'LUKE', 'OWEN', 'LUKE', 'OWEN', 'THREEPIO', 'LUKE', 'OWEN', 'LUKE', 'OWEN', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'INT. LARS HOMESTEAD - GARAGE AREA - LATE AFTERNOON', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'LEIA', 'LUKE', 'THREEPIO', 'LEIA', 'THREEPIO', 'LUKE', 'THREEPIO', 'LEIA', 'THREEPIO', 'LUKE', 'THREEPIO', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'LUKE', 'THREEPIO', 'LUKE', 'LUKE', 'LUKE', 'THREEPIO', 'AUNT BERU', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'INT. LARS HOMESTEAD - DINING AREA', 'LUKE', 'OWEN', 'LUKE', 'LUKE', 'OWEN', 'LUKE', 'OWEN', 'LUKE', 'OWEN', 'LUKE', 'OWEN', 'LUKE', 'OWEN', 'OWEN', 'LUKE', 'OWEN', 'LUKE', 'AUNT BERU', 'LUKE', 'AUNT BERU', 'OWEN', 'AUNT BERU', 'OWEN', 'EXT. TATOOINE - LARS HOMESTEAD', 'INT. LARS HOMESTEAD - GARAGE', 'LUKE', 'THREEPIO', 'LUKE', 'EXT. TATOOINE - LARS HOMESTEAD', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'OWEN', 'LUKE', 'LUKE', 'THREEPIO', 'INT. LARS HOMESTEAD - PLAZA', 'OWEN', 'INT. LARS HOMESTEAD - KITCHEN', 'OWEN', 'AUNT BERU', 'OWEN', 'AUNT BERU', 'OWEN', 'DAY', 'LUKE', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'EXT. TATOOINE - ROCK MESA - DUNE SEA - COASTLINE - DAY', 'EXT. TATOOINE - ROCK MESA - CANYON', 'EXT. TATOOINE - ROCK CANYON - FLOOR', 'LUKE', 'THREEPIO', 'LUKE', 'THREEPIO', 'LUKE', 'LUKE', 'THREEPIO', 'LUKE', 'EXT. TATOOINE - ROCK CANYON - RIDGE - DAY', 'LUKE', 'EXT. TATOOINE - ROCK CANYON - FLOOR - DAY', 'BEN', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'BEN', 'LUKE', 'EXT. TATOOINE - SAND PIT - ROCK  ...
# 191
# {'BERU', 'THREEPIO', 'EXT. TATOOINE - ROCK MESA - DUNE SEA - COASTLINE - DAY', 'EXT. TATOOINE - ROCK CANYON - FLOOR', 'EXT. TATOOINE - MOS EISLEY - STREET - ALLEYWAY - USED', 'INT. DEATH STAR - DETENTION CORRIDOR', 'EXT. TATOOINE - DESERT - DAY', 'EXT. SPACE - PLANET TATOOINE', 'MASSASSI INTERCOM VOICE', 'INT. RED LEADER STARSHIP - COCKPIT', 'END CREDITS OVER STARS', 'INT. DEATH STAR - MAIN BAY GANTRY - CONTROL TOWER', 'INT. DEATH STAR - CONFERENCE ROOM', 'INT. LARS HOMESTEAD - GARAGE', 'BIGGS', 'SECOND TROOPER', 'INT. MILLENNIUM FALCON - DEATH STAR', 'EXT. MASSASSI OUTPOST - JUNGLE', 'COMMANDER', 'STAR WARS', 'INT. MASSASSI OUTPOST - MAIN THRONE ROOM', 'DEATH STAR INTERCOM VOICE', 'CONTROL OFFICER', 'TROOPER VOICE', 'FIXER', 'AUNT BERU', 'INT. DEATH STAR - SUBHALLWAY', 'INT. MILLENNIUM FALCON - PASSAGEWAY', 'A NEW HOPE', 'EXT. MASSASSI OUTPOST', 'OFFICER', 'GOLD FIVE', 'AREA', 'EXT. DEATH STAR SURFACE - GUN EMPLACEMENTS', 'INT. DEATH STAR - CORRIDOR - BLAST SHIELDS DOOR', 'EXT. DEATH STAR TRENCH', 'EXT. TATOOINE - SAND PIT - ROCK MESA - DAY', 'EXT. SPACE - MILLENNIUM FALCON', 'EXT. SPACE AROUND THE DEATH STAR - TIE FIGHTER', 'CAMIE', 'INT. MASSASSI OUTPOST - MAIN HANGAR', 'EXT. TATOOINE - WASTELAND', 'IMPERIAL OFFICER', 'INT. DEATH STAR - MAIN FORWARD BAY - SERVICE PANEL', 'EXT. TATOOINE - ROCK CANYON - SUNSET', 'INT. LARS HOMESTEAD - PLAZA', 'OWEN', 'INT. TATOOINE - MOS EISLEY - CANTINA', 'GANTRY OFFICER', 'WILLARD', 'RED NINE', 'TAGGE', 'INT. DEATH STAR - HALLWAY LEADING TO MAIN FORWARD BAY', 'EXT. TATOOINE - DUNE SEA', 'MOTTI', 'WEDGE', 'EXT. TATOOINE - MOS EISLEY - STREET', 'EXT. TATOOINE - DESERT WASTELAND - DAY', 'INT. SANDCRAWLER - PRISON AREA', 'INT. MASSASSI - MAIN HANGAR DECK', 'INT. LIFEPOD', 'INT. REBEL BLOCKADE RUNNER - SUBHALLWAY', 'HUMAN', 'INT. DEATH STAR - CONTROL ROOM', 'INT. REBEL BLOCKADE RUNNER - MAIN PASSAGEWAY', 'INT. REBEL BLOCKADE RUNNER - MAIN HALLWAY', 'INT. MASSASSI OUTPOST - MAIN HANGAR DECK', 'RED ELEVEN', 'WOMAN', 'EXT. SPACE - MILLENNIUM FALCON/TIE FIGHTERS', 'THE END', 'EXT. TATOOINE - ROCK CANYON - RIDGE - DAY', 'EXT. DEATH STAR', 'REBEL OFFICER', 'INT. LARS HOMESTEAD - KITCHEN', 'DAY', 'INT. X-WING FIGHTER - COCKPIT - TRAVELING', 'EXT. TATOOINE - ROCK MESA - CANYON', 'DEAK', 'INT. MASSASSI OUTPOST - WAR ROOM', 'INT. DEATH STAR - BLAST CHAMBER', 'INT. DEATH STAR - MAIN GANTRY - COMMAND OFFICE', 'PORKINS', 'READ LEADER', 'FIRST TROOPER', 'VOICE', 'INT. MILLENNIUM FALCON - GUNPORT', 'INT. MILLENNIUM FALCON - GUNPORT - COCKPIT', 'RED LEADER', 'GOLD TWO', 'INT. MILLENNIUM FALCON', 'EXT. MASSASSI OUTPOST - JUNGLE TEMPLE', 'VOICE OVER DEATH STAR INTERCOM', 'EXT. YAVIN - JUNGLE', 'EXT. SURFACE OF THE DEATH STAR', 'INT. DEATH STAR - NARROW PASSAGEWAY', 'INT. MILLENNIUM FALCON - HOLD AREA', 'INT. DEATH STAR - MAIN FORWARD BAY', 'INTERCOM VOICE', 'INT. REBEL BLOCKADE RUNNER', 'EXT. SPACE - DEATH STAR TRENCH', 'INT. TIE FIGHTER - COCKPIT', 'EXT. SPACE - ANOTHER ANGLE', 'JOURNAL OF THE WHILLS', 'EXT. SPACE AROUND THE DEATH STAR', 'WINGMAN', 'INT. LARS HOMESTEAD - DINING AREA', 'BEN', 'INT. DEATH STAR', 'INT. DEATH STAR - TRACTOR BEAM - POWER GENERATOR TRENCH', 'INT. MILLENNIUM FALCON - GUNPORTS - COCKPIT', 'EXT. MILLENNIUM FALCON - IN SPACE', 'INT. DEATH STAR - CELL ROW', 'INT. MILLENNIUM FALCON - HALLWAY', 'EXT. TIE FIGHTER - SPACE', 'JABBA', 'CHIEF', 'INT. MILLENNIUM FALCON - MAIN PASSAGEWAY', 'CREATURE', 'INT. REBEL BLOCKADE RUNNER - HALLWAY', 'RED TEN', 'VADER', 'SECOND OFFICER', 'TARKIN', 'EXT. SPACECRAFT IN SPACE', 'LUKE', 'INT. DEATH STAR - MAIN HALLWAY', 'INT. DEATH STAR - DOCKING BAY', 'INT. IMPERIAL STARDESTROYER', 'INT. MASSASSI - WAR ROOM BRIEFING AREA', 'DODONNA', 'EXT. SURFACE AROUND THE DEATH STAR', 'INT. DETENTION AREA', 'EXT. TIE FIGHTER', 'CAPTAIN', 'RED SEVEN', 'INT. MILLENNIUM FALCON - CENTRAL HOLD AREA', 'ASTRO-OFFICER', 'EXT. TATOOINE - DESERT', 'INT. ANOTHER COCKPIT', 'EXT. DEATH STAR - GUN EMPLACEMENTS', 'INT. DEATH STAR - DETENTION AREA - HALLWAY', 'INT. REBEL BLOCKADE RUNNER - C ...
# {'SPACE AROUND FOURTH MOON OF YAVI', 'RED LEADER STARSHIP', 'HYPERSPAC', 'MILLENNIUM FALCO', 'DOCKING PORT ENTRY', 'MASSASSI', 'SURFACE OF DEATH STA', 'SANDCRAWLE', 'SPAC', 'SPACE', 'LIFEPO', 'DETENTION ARE', 'POWER STATION', 'SURFACE OF THE DEATH STA', 'DEATH STAR SURFAC', 'ERCO', 'TIE FIGHTER', 'LARS HOMESTEAD', 'ERCOM VOIC', 'MOS EISLEY', 'REBEL BLOCKADE RUNNE', 'X', 'MILLENNIUM FALCON', 'SPACECRAFT IN SPAC', 'SPACE AROUND THE DEATH STA', 'MASSASSI OUTPOST', 'SANDCRAWLER', 'SPACE AROUND THE DEATH STAR', 'DEATH STA', 'ANOTHER COCKPI', 'DEATH STAR', 'IMPERIAL STARDESTROYE', 'SURFACE AROUND THE DEATH STA', 'YAVIN', 'DEATH STAR TRENC', 'REBEL BLOCKADE RUNNER', 'FOURTH MOON OF YAVI', 'MASSASSI OUTPOS', 'TIE FIGHTE', 'TATOOINE', 'DEATH STAR SURFACE', 'OVER STAR'}
# {'SURFACE', 'REBEL', 'DEATH', 'MASSASSI', 'MILLENNIUM', 'SPACE', 'TIE'}
# {'BERU', 'THREEPIO', 'PORKINS', 'IMPERIAL OFFICER', 'READ LEADER', 'FIRST TROOPER', 'CAPTAIN', 'RED SEVEN', 'ASTRO-OFFICER', 'VOICE', 'RED LEADER', 'GOLD TWO', 'SPACE', 'LEIA', 'OWEN', 'GANTRY OFFICER', 'WILLARD', 'BIGGS', 'SECOND TROOPER', 'RED NINE', 'TAGGE', 'BARTENDER', 'MOTTI', 'COMMANDER', 'JOURNAL OF THE WHILLS', 'STAR WARS', 'GOLD LEADER', 'WEDGE', 'WINGMAN', 'BEN', 'CONTROL OFFICER', 'TROOPER VOICE', 'FIRST OFFICER', 'CHIEF PILOT', 'HUMAN', 'FIXER', 'AUNT BERU', 'JABBA', 'CHIEF', 'HAN', 'RED ELEVEN', 'WOMAN', 'A NEW HOPE', 'THE END', 'OFFICER', 'GOLD FIVE', 'CREATURE', 'AREA', 'RED TEN', 'VADER', 'SECOND OFFICER', 'TARKIN', 'LUKE', 'GREEDO', 'REBEL OFFICER', 'SPEEDER LOT', 'DODONNA', 'OFFICER CASS', 'TROOPER', 'DAY', 'CAMIE', 'TECHNICIAN', 'BASE VOICE', 'DEAK'}
#
# scripts\Episode V - The Empire Strikes Back.txt
# ['THE EMPIRE STRIKES BACK', 'EXT. GALAXY - PLANET HOTH', 'EXT. HOTH - METEORITE CRATER - SNOW PLAIN - DAY', 'EXT. PLAIN OF HOTH - DAY', 'LUKE', 'HAN', 'LUKE', 'HAN', 'LUKE', 'LUKE', 'LUKE', 'EXT. HOTH - REBEL BASE ENTRANCE - DAY', 'INT. HOTH - REBEL BASE - MAIN HANGAR DECK', 'HAN', 'HAN', 'INT. HOTH - REBEL BASE - COMMAND CENTER', 'RIEEKAN', 'HAN', 'RIEEKAN', 'HAN', 'RIEEKAN', 'HAN', 'RIEEKAN', 'HAN', 'RIEEKAN', 'HAN', 'HAN', 'LEIA', 'HAN', 'INT. HOTH - REBEL BASE - ICE CORRIDOR', 'LEIA', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'INT. HOTH - REBEL BASE - ANOTHER ICE CORRIDOR', 'THREEPIO', 'THREEPIO', 'INT. HOTH - REBEL BASE - MAIN HANGAR DECK', 'HAN', 'THREEPIO', 'HAN', 'THREEPIO', 'HAN', 'THREEPIO', 'HAN', 'THREEPIO', 'HAN', 'THREEPIO', 'HAN', 'THREEPIO', 'HAN', 'THREEPIO', 'DECK OFFICER', 'HAN', 'DECK OFFICER', 'HAN', 'DECK OFFICER', 'THREEPIO', 'HAN', 'THREEPIO', 'INT. HOTH - REBEL BASE - MAIN ICE TUNNEL', 'DECK OFFICER', 'HAN', 'DECK OFFICER', 'HAN', 'DECK OFFICER', 'HAN', 'ASSISTANT OFFICER', 'DECK OFFICER', 'HAN', 'EXT. HOTH - ICE GORGE - DUSK', 'EXT. HOTH - ENTRANCE TO ICE GORGE - DUSK', 'EXT. HOTH - SNOW PLAIN - DUSK', 'THREEPIO', 'THREEPIO', 'EXT. HOTH - SNOW DRIFT - DUSK', 'INT. REBEL BASE - MAIN HANGAR DECK - ENTRANCE - NIGHT', 'LIEUTENANT', 'THREEPIO', 'DERLIN', 'DERLIN', 'LIEUTENANT', 'THREEPIO', 'THREEPIO', 'EXT. HOTH - SNOW DRIFT - DUSK', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'HAN', 'HAN', 'LUKE', 'HAN', 'LUKE', 'HAN', 'LUKE', 'HAN', 'LUKE', 'HAN', 'EXT. HOTH - SNOWDRIFT - DAWN', 'INT. SNOWSPEEDER COCKPIT', 'ZEV', 'EXT. HOTH - SNOWDRIFT', 'INT. SNOWSPEEDER - COCKPIT', 'ZEV', 'HAN', 'ZEV', 'EXT. HOTH - SNOWDRIFT - DAY', 'INT. REBEL BASE - MEDICAL CENTER', 'INT. REBEL BASE - MEDICAL CENTER - RECOVERY ROOM', 'THREEPIO', 'THREEPIO', 'HAN', 'LUKE', 'HAN', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'HAN', 'LEIA', 'HAN', 'LEIA', 'ANNOUNCER', 'HAN', 'THREEPIO', 'INT. HOTH - REBEL BASE - COMMAND CENTER', 'RIEEKAN', 'RIEEKAN', 'SENIOR CONTROLLER', 'LEIA', 'HAN', 'SENIOR CONTROLLER', 'THREEPIO', 'HAN', 'RIEEKAN', 'EXT. HOTH - SNOW PLAIN - DAY', 'INT. HOTH - REBEL BASE - COMMAND CENTER', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'RIEEKAN', 'EXT. SPACE - IMPERIAL FLEET', 'PIETT', 'OZZEL', 'PIETT', 'OZZEL', 'PIETT', 'OZZEL', 'PIETT', 'VADER', 'PIETT', 'VADER', 'OZZEL', 'VADER', 'INT. HOTH - REBEL BASE - TRANSPORT BAY', 'REBEL CAPTAIN', 'REBEL FIGHTER', 'INT. HOTH - REBEL BASE - MAIN HANGAR DECK', 'HAN', 'INT. REBEL BASE - MEDICAL CENTER', 'MEDICAL DROID', 'LUKE', 'MEDICAL DROID', 'LUKE', 'INT. REBEL BASE - MAIN HANGAR DECK', 'LUKE', 'HAN', 'LUKE', 'HAN', 'LUKE', 'CONTROLLER', 'RIEEKAN', 'VADER', 'VEERS', 'VADER', 'VEERS', 'VADER', 'VEERS', 'OZZEL', 'VADER', 'PIETT', 'VADER', 'PIETT', 'INT. REBEL BASE - MAIN HANGAR DECK', 'LEIA', 'HOBBIE', 'LEIA', 'PILOTS', 'LEIA', 'DERLIN', 'EXT. HOTH - ICE PLAIN - SNOW TRENCH - DAY', 'EXT. HOTH - ICE PLAIN - POWER GENERATORS', 'INT. REBEL BASE - COMMAND CENTER', 'RIEEKAN', 'EXT. ICE PLAIN', 'EXT. SPACE - IMPERIAL STAR DESTROYER', 'INT. IMPERIAL STAR DESTROYER - BRIDGE', 'CONTROLLER', 'CAPTAIN', 'INT. REBEL BASE - COMMAND CENTER', 'WOMAN CONTROLLER', 'EXT. REBEL BASE ICE CAVE - ION CANNON', 'EXT. SPACE - HOTH - REBEL TRANSPORT', 'INT. REBEL BASE - MAIN HANGAR DECK', 'ANNOUNCER', 'DACK', 'LUKE', 'DACK', 'LUKE', 'EXT. HOTH - ICE PLAIN', 'EXT. HOTH - ICE PLAIN - SNOW TRENCH', 'TRENCH OFFICER', 'INT. REBEL BASE - CORRIDOR', 'TRENCH OFFICER', 'CONTROLLER', 'EXT. HOTH - ICE PLAIN - SNOW TRENCH', 'LUKE', 'EXT. HOTH - ICE PLAIN - BATTLEFIELD', 'LUKE', 'DACK', 'LUKE', 'EXT. HOTH - ICE PLAIN - BATTLEFIELD', 'LUKE', 'LUKE', 'EXT. HOTH - ICE PLAIN - BATTLEFIELD', 'EXT. HOTH - ICE PLAIN - SNOWTRENCH', 'EXT. HOTH - ICE PLAIN - BATTLEFIELD', 'INT. IMPERIAL SNOW WALKER - COCKPIT', 'LUKE', 'LUKE', 'DACK', 'LUKE', 'EXT. HOTH - ICE PLAIN - BATTLEFIELD', 'LUKE', 'EXT. HOTH - ICE PLAIN - SNOW TRENCH AREA', 'EXT. HOTH - ICE PLAIN - B ...
# 178
# {'TRACKING OFFICER', 'INT. IMPERIAL STAR DESTROYER - BRIDGE', 'INT. MILLENNIUM FALCON - MAIN HOLD AREA', 'THREEPIO', 'COMMUNICATIONS OFFICER', 'EXT. DAGOBAH - BOG - DAY', 'FIRST CONTROLLER', 'RIEEKAN', 'DERLIN', 'EXT. HOTH - ENTRANCE TO ICE GORGE - DUSK', 'EXT. LANDING PLATFORM - CLOUD CITY - DUSK', 'EXT. HOTH - SNOWDRIFT', 'NEEDA', 'EXT. SPACE - STAR DESTROYERS - ASTEROID FIELD', 'INT. CLOUD CITY - JUNK ROOM', 'INT. CLOUD CITY - LARGE CELL', 'EXT. SPACE - IMPERIAL STAR DESTROYER', 'INT. REBEL BASE - MAIN HANGAR DECK', 'JANSON', 'ANNOUNCER', 'LIEUTENANT', 'EXT. HOTH - ICE PLAIN', 'INT. SNOWSPEEDER - COCKPIT', 'EXT. DAGOBAH - CAVE - DUSK', 'HOBBIE', 'EXT. SPACE - STAR DESTROYER - ASTEROID BELT', 'VEERS', 'INT. REACTOR SHAFT', 'EXT. ASTEROID CAVE - MILLENNIUM FALCON', 'EXT. HOTH - SNOW TRENCH', 'INT. CLOUD CITY - CORRIDOR', 'INT. CLOUD CITY - HOLDING CHAMBER', 'CONTROLLER', 'BOBA FETT', 'INT. CLOUD CITY - PRISON ENTRY AREA', 'INT. HOTH - REBEL BASE - ICE CORRIDOR', 'DACK', 'EXT. HOTH - METEORITE CRATER - SNOW PLAIN - DAY', 'END CREDITS FADE IN AND OUT OVER BACKGROUND', 'EXT. HOTH - SNOW PLAIN - DUSK', 'REBEL FIGHTER', 'EXT. BOTTOM OF CLOUD CITY', 'EXT. HOTH - SNOWDRIFT - DAWN', 'OFFICER', 'INT. CLOUD CITY - CORRIDOR LEADING TO LANDING PLATFORM', 'EXT. BESPIN SURFACE - MILLENNIUM FALCON', 'INT. ASTEROID CAVE - MILLENNIUM FALCON - COCKPIT', 'WOMAN CONTROLLER', 'EXT. ICE PLAIN', 'EXT. SPACE - MILLENNIUM FALCON', 'EXT. CLOUD CITY - LANDING PLATFORM', 'INT. HOTH - REBEL BASE - MAIN HANGAR DECK', 'PIETT', 'EXT. HOTH - ICE PLAIN - SNOW TRENCH', 'EXT. HOTH - BATTLEFIELD', 'EXT. HOTH - BATTLEFIELD - ICE PLAIN', 'EXT. CAVE ENTRANCE - GIANT ASTEROID', 'DECK OFFICER', 'SECOND THREEPIO', 'INT. CLOUD CITY - LIVING QUARTERS - DAY', 'IMPERIAL OFFICER', 'THE EMPIRE STRIKES BACK', 'REBEL CAPTAIN', 'OZZEL', 'INT. ASTEROID CAVE - MILLENNIUM FALCON - ENTRY AREA', 'INT. CLOUD CITY - CORRIDOR - DAY', 'INT. STAR CRUISER - MEDICAL CENTER', 'INT. CLOUD CITY - CARBON-FREEZING CHAMBER', 'EXT. ASTEROID BELT - MILLENNIUM FALCON', 'EXT. MILLENNIUM FALCON - TIE FIGHTERS - ASTEROID BELT', 'EXT. BOTTOM OF CLOUD CITY - WEATHER VANE', 'WEDGE', 'EMPEROR', 'EXT. GALAXY - SPACE', 'INT. GIANT ASTEROID CRATER', 'INT. HOTH - REBEL BASE - ICE CORRIDORS', 'MEDICAL DROID', 'INT. CLOUD CITY - ANTEROOM', 'EXT. DAGOBAH - DUSK', 'STRANGE VOICE', 'HEAD CONTROLLER', 'EXT. CLOUD CITY - MILLENNIUM FALCON - CLOUD CARS', 'THE END', 'EXT. HOTH - ICE SLOPE - DAY', 'INT. CLOUD CITY - CARBON-FREEZING CHAMBER - ANTEROOM', 'INT. MILLENNIUM FALCON - SLEEPING QUARTERS', 'DISSOLVE TO', 'INT. REBEL BASE - MAIN HANGER - MILLENNIUM FALCON', 'EXT. MILLENNIUM FALCON - ASTEROID BELT', 'INT. REBEL BASE - COMMAND CENTER', 'EXT. HOTH - ICE PLAIN - POWER GENERATORS', 'EXT. SPACE - MILLENNIUM FALCON - TIE FIGHTERS', 'SECOND CONTROLLER', 'TRENCH OFFICER', 'INT. GANTRY - OUTSIDE CONTROL ROOM - REACTOR SHAFT', 'EXT. HOTH - REBEL BASE ENTRANCE - DAY', 'INT. REBEL BASE - MEDICAL CENTER', 'EXT. SPACE - MILLENNIUM FALCON - ASTEROID FIELD', 'INT. HOTH - REBEL BASE - MAIN ICE TUNNEL', 'EXT. SPACE - ASTEROID FIELD', 'EXT. HOTH - ICE PLAIN - SNOWTRENCH', 'INT. MILLENNIUM FALCON', 'EXT. SPACE - CLOUD CITY - DAY', 'EXT. PLAIN OF HOTH - DAY', 'EXT. DAGOBAH - BOG - DUSK', 'EXT. REBEL BASE ICE CAVE - ION CANNON', 'INT. HOTH - REBEL BASE - MAIN HANGAR', 'EXT. MILLENNIUM FALCON - GIANT ASTEROID CRATER', 'INTERCOM VOICE', 'INT. EXHAUST PIPE', 'BEN', 'INT. REBEL BASE - MAIN HANGAR DECK - ENTRANCE - NIGHT', 'INT. IMPERIAL SNOW WALKER - COCKPIT', 'EXT. SPACE - MILLENNIUM FALCON - STAR DESTROYERS', 'EXT. HOTH - ICE GORGE - DUSK', 'INT. DAGOBAH - TREE CAVE', 'CREATURE', 'EXT. DAGOBAH - DAY', 'INT. CLOUD CITY - HALLWAY LEADING TO ANTEROOM', 'EXT. CLOUD CITY - LANDING PLATFORM - MILLENNIUM FALCON', 'INT. MILLENNIUM FALCON - CORRIDOR', 'VADER', 'SECOND OFFICER', 'LUKE', 'INT. ASTEROID CAVE - MILLENNIUM FALCON - HOLD AREA', 'EXT. HOTH - SNOW DRIFT - DUSK', 'EXT. BATTLEFIELD - SNOW TRENCH', 'EXT. SPACE - IMPERIAL FLEET', 'INT. MIL ...
# {'HOTH', 'BOTTOM OF CLOUD CITY', 'STAR DESTROYER', 'BATTLEFIELD', 'MILLENNIUM FALCO', 'IMPERIAL STAR DESTROYER', 'BESPIN SURFACE', 'EAST LANDING PLATFORM', 'SPACE', 'SPACE SLUG MOUT', 'SPAC', 'IMPERIAL SNOW WALKER', 'GANTRY', 'DAGOBAH', 'EXHAUST PIP', 'REACTOR SHAF', 'FADE IN AND OUT OVER BACKGROUN', 'REBEL BASE', 'OFFICE', 'ERCOM VOIC', 'STAR CRUISER', 'BESPIN SYSTEM', 'MILLENNIUM FALCON', 'REBEL BASE ICE CAVE', 'BOTTOM OF CLOUD CIT', 'MAIN HANGAR', 'GIANT ASTEROID CRATE', 'CAVE ENTRANCE', 'LANDING PLATFORM', 'ICE PLAI', 'SNOWSPEEDER COCKPI', 'ASTEROID CAVE', 'SNOWSPEEDER', 'PLAIN OF HOTH', 'ASTEROID BELT', 'GALAXY', 'CLOUD CITY', 'BAC'}
# {'BOTTOM', 'STAR', 'REBEL', 'MILLENNIUM', 'BESPIN', 'SPACE', 'SNOWSPEEDER', 'ASTEROID', 'IMPERIAL'}
# {'TRACKING OFFICER', 'SECOND CONTROLLER', 'TRENCH OFFICER', 'THREEPIO', 'DECK OFFICER', 'FIRST CONTROLLER', 'SECOND THREEPIO', 'RIEEKAN', 'DERLIN', 'IMPERIAL OFFICER', 'CAPTAIN', 'PILOTS', 'NEEDA', 'REBEL CAPTAIN', 'LEIA', 'OZZEL', 'LANDO', 'JANSON', 'SENIOR CONTROLLER', 'ANNOUNCER', 'LIEUTENANT', 'ZEV', 'HOBBIE', 'VEERS', 'WEDGE', 'EMPEROR', 'BEN', 'IMPERIAL SOLDIER', 'CONTROLLER', 'MEDICAL DROID', 'BOBA FETT', 'STRANGE VOICE', 'HEAD CONTROLLER', 'DACK', 'HAN', 'YODA', 'PILOT', 'REBEL FIGHTER', 'THE END', 'OFFICER', 'CREATURE', 'VADER', 'SECOND OFFICER', 'ASSISTANT OFFICER', 'LUKE', 'WOMAN CONTROLLER', 'DISSOLVE TO', 'PIETT'}
#
# scripts\Episode VI - Return of the Jedi.txt
# ['RETURN', 'OF THE', 'JEDI', 'SPACE', 'RETURN OF THE JEDI', 'INT IMPERIAL SHUTTLE - COCKPIT', 'SHUTTLE CAPTAIN', 'SHUTTLE CAPTAIN', 'INT DEATH STAR - CONTROL ROOM', 'OFFICER', 'OPERATOR', 'INT DEATH STAR - MAIN DOCKING BAY', 'JERJERROD', 'VADER', 'JERJERROD', 'VADER', 'JERJERROD', 'VADER', 'JERJERROD', 'VADER', 'VADER', 'JERJERROD', 'VADER', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'STRANGE VOICE', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'BIB', 'THREEPIO', 'BIB', 'THREEPIO', 'THREEPIO', 'BIB', 'THREEPIO', 'THREEPIO', 'JABBA', 'THREEPIO', 'LUKE', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'INT DUNGEON CORRIDOR', 'THREEPIO', 'INT BOILER ROOM', 'NINEDENINE', 'THREEPIO', 'NINEDENINE', 'THREEPIO', 'NINEDENINE', 'THREEPIO', 'NINEDENINE', 'THREEPIO', 'NINEDENINE', 'JABBA', 'OOLA', 'JABBA', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'BOUSHH', 'THREEPIO', 'INT DUNGEON CORRIDOR AND CELL', 'BOUSHH', 'BOUSHH', 'HAN', 'BOUSHH', 'HAN', 'BOUSHH', 'HAN', 'LEIA', 'HAN', 'LEIA', 'HAN', 'HAN', 'HAN', 'HAN', 'LEIA', 'LEIA', 'THREEPIO', 'INT DUNGEON CELL', 'HAN', 'HAN', 'HAN', 'HAN', 'HAN', 'HAN', 'LUKE', 'LUKE', 'LUKE', 'LUKE', 'THREEPIO', 'BIB', 'BIB', 'LUKE', 'LUKE', 'LUKE', 'THREEPIO', 'JABBA', 'INT RANCOR PIT', 'THREEPIO', 'HOLDING TUNNEL - RANCOR PIT', 'INT RANCOR PIT', 'INT THRONE ROOM', 'LUKE', 'HAN', 'LUKE', 'HAN', 'LUKE', 'HAN', 'LUKE', 'HAN', 'LEIA', 'THREEPIO', 'HAN', 'THREEPIO', 'THREEPIO', 'HAN', 'LUKE', 'EXT TATOOINE SEA - SKIFF', 'HAN', 'LUKE', 'HAN', 'LUKE', 'HAN', 'INT BARGE OBSERVATION DECK', 'THREEPIO', 'THREEPIO', 'THREEPIO', 'EXT SARLACC PIT', 'EXT SAIL BARGE OBSERVATION DECK', 'THREEPIO', 'EXT SKIFF', 'HAN', 'LUKE', 'INT SAIL BARGE OBSERVATION DECK', 'EXT BARGE - UPPER DECK', 'EXT SKIFF - PLANK', 'EXT SARLACC PIT', 'INT SAIL BARGE', 'EXT SKIFF', 'LUKE', 'LANDO', 'EXT UPPER DECK - SAIL BARGE', 'EXT SKIFF', 'HAN', 'HAN', 'LANDO', 'HAN', 'HAN', 'INT SAIL BARGE', 'EXT SKIFF', 'HAN', 'LANDO', 'HAN', 'HAN', 'HAN', 'HAN', 'LANDO', 'HAN', 'HAN', 'LANDO', 'HAN', 'LANDO', 'HAN', 'EXT UPPER DECK', 'INT SAIL BARGE - OBSERVATION DECK', 'LEIA', 'THREEPIO', 'EXT UPPER DECK - SAIL BARGE', 'LUKE', 'THREEPIO', 'LUKE', 'EXT SKIFF', 'LUKE', 'LANDO', 'EXT SAND DUNE', 'EXT DUNE SEA', 'EXT DUNE SEA - LANDING AREA', 'HAN', 'LEIA', 'HAN', 'HAN', 'LUKE', 'HAN', 'LANDO', 'LEIA', 'LANDO', 'INT X-WING - COCKPIT', 'LUKE', 'LUKE', 'LUKE', 'EXT SPACE - DEATH STAR AND ENDOR', 'INT DEATH STAR - CORRIDOR TO DOCKING BAY', 'INT DOCKING BAY - DEATH STAR', 'VADER', 'EMPEROR', 'VADER', 'EMPEROR', 'VADER', 'EMPEROR', 'YODA', 'LUKE', 'YODA', 'LUKE', 'YODA', 'LUKE', 'YODA', 'LUKE', 'LUKE', 'YODA', 'LUKE', 'YODA', 'YODA', 'LUKE', 'YODA', 'LUKE', 'LUKE', 'YODA', 'YODA', 'EXT DAGOBAH SWAMP - X-WING', 'LUKE', 'LUKE', 'LUKE', 'BEN', 'BEN', 'BEN', 'BEN', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'LUKE', 'BEN', 'EXT SPACE - REBEL FLEET', 'INT HEADQUARTERS FRIGATE - MAIN BRIEFING ROOM', 'HAN', 'LANDO', 'HAN', 'MON MOTHMA', 'MON MOTHMA', 'ACKBAR', 'HAN', 'HAN', 'ACKBAR', 'GENERAL MADINE', 'THREEPIO', 'GENERAL MADINE', 'HAN', 'HAN', 'LEIA', 'LEIA', 'HAN', 'LUKE', 'THREEPIO', 'INT HEADQUARTERS FRIGATE - MAIN DOCKING BAY', 'HAN', 'LANDO', 'LANDO', 'LANDO', 'HAN', 'INT IMPERIAL SHUTTLE - COCKPIT', 'HAN', 'LUKE', 'HAN', 'LEIA', 'HAN', 'HAN', 'LUKE', 'THREEPIO', 'HAN', 'EXT SPACE - THE REBEL FLEET', 'VADER', 'EMPEROR', 'VADER', 'EMPEROR', 'VADER', 'EXT SPACE - DEATH STAR - MOON', 'INT STOLEN IMPERIAL SHUTTLE - COCKPIT', 'HAN', 'HAN', 'HAN', 'LEIA', 'HAN', 'LUKE', 'HAN', 'HAN', 'LUKE', 'HAN', 'VADER', 'VADER', 'PIETT', 'PIETT', 'VADER', 'INT STOLEN IMPERIAL SHUTTLE - COCKPIT', 'HAN', 'HAN', 'EXT SPACE - STOLEN IMPERIAL SHUTTLE - ENDOR', 'EXT FOREST LANDING SITE - ENDOR', 'THREEPIO', 'LEIA', 'HAN', 'EXT FOREST CLEARING - CAMPSITE', 'HAN', 'LUKE', 'LEIA', 'LUKE', 'HAN', 'EXT FOREST - THE BIKE CHASE', 'LUKE', 'LUKE', 'LUKE', 'ANOTHER PART OF  ...
# 122
# {'EXT SPACE - DEATH STAR SHIELD', 'GUARD', 'THREEPIO', 'EXT FOREST WALKWAY - MOON FOREST', 'REBEL PILOT', 'END CREDITS OVER STAR FIELD', 'ANOTHER PART OF THE FOREST', 'HOLDING TUNNEL - RANCOR PIT', 'INT BOILER ROOM', 'EXT BUNKER', 'INT RANCOR PIT', 'INT REBEL STAR CRUISER - BRIDGE', 'COMMANDER', 'EXT FOREST - IMPERIAL LANDING PLATFORM', 'EXT UPPER DECK', 'EXT SAIL BARGE OBSERVATION DECK', 'CONTROL ROOM COMMANDER', 'CONTROLLER', 'JEDI', 'BOUSHH', 'OFFICER', 'EXT FOREST - SERIES OF SHOTS', 'INT DEATH STAR - CONTROL ROOM', 'EXT ENDOR - RIDGE OVERLOOKING SHIELD GENERATOR', 'INT SAIL BARGE OBSERVATION DECK', 'EXT FOREST CLEARING - CAMPSITE', 'EXT BUNKER - ENTRANCE', 'EXT SPACE - DEATH STAR AND ENDOR', 'RETURN OF THE JEDI', 'EXT ENDOR - RIDGE OVERLOOKING CONTROL BUNKER', 'EXT TATOOINE SEA - SKIFF', 'PIETT', 'EXT FOREST LANDING SITE - ENDOR', 'EXT UPPER DECK - SAIL BARGE', 'INT X-WING - COCKPIT', 'GREEN LEADER', 'EXT DUNE SEA', 'EXT ENDOR FOREST', 'JERJERROD', 'NINEDENINE', 'EXT IMPERIAL LANDING PLATFORM - LOWER DECK', 'EXT FOREST', 'EXT SPACE - DEATH STAR', 'STORMTROOPER', 'INT SAIL BARGE', 'EXT SPACE', 'EXT BARGE - UPPER DECK', 'BIB', 'EXT EWOK VILLAGE SQUARE', 'WEDGE', 'EMPEROR', 'GRAY LEADER', 'NAVIGATOR', 'STRANGE VOICE', 'EXT SPACE - STOLEN IMPERIAL SHUTTLE - ENDOR', 'BUNKER COMMANDER', 'INT SAIL BARGE - OBSERVATION DECK', 'EXT SARLACC PIT', 'INT DUNGEON CORRIDOR', 'RED TWO', 'EXT DEATH STAR', 'MON MOTHMA', 'INT THRONE ROOM', 'EXT SKIFF - PLANK', 'OOLA', 'ACKBAR', 'FADE OUT', 'EXT SPACE - AIR BATTLE', 'INT DEATH STAR - CORRIDOR TO DOCKING BAY', 'INT MILLENNIUM FALCON - COCKPIT AND GUN PORTS', 'INT DOCKING BAY - DEATH STAR', 'EXT ENDOR FOREST - NIGHT', 'EXT SPACE - DEATH STAR - MOON', 'EXT/INT - SPACE BATTLE - FIGHTER AND DEATH STAR', 'BEN', 'EXT SCOUT CAMPSITE - FOREST', 'INT DUNGEON CELL', 'INT HEADQUARTERS FRIGATE - MAIN BRIEFING ROOM', 'EXT DUNE SEA - LANDING AREA', 'SECOND COMMANDER', 'JABBA', 'RED THREE', 'INT SUPER STAR DESTROYER - BRIDGE', 'VADER', 'LUKE', 'INT BUNKER - CONTROL ROOM', 'EXT FOREST - GENERATOR BUNKER', 'INT DEATH STAR - BLAST CHAMBER', 'EXT FOREST - DENSE FOLIAGE', 'INT DUNGEON CORRIDOR AND CELL', 'INT STOLEN IMPERIAL SHUTTLE - COCKPIT', 'LURE', 'SPACE', 'LEIA', 'INT DEATH STAR - MAIN DOCKING BAY', 'INT BUNKER - MAIN CONTROL ROOM', 'LANDO', 'EXT RIDGE', 'Y-WING PILOT', 'EXT EWOK VILLAGE - NIGHT', 'EXT SPACE - THE REBEL FLEET', 'OF THE', 'ANAKIN', 'RETURN', 'EXT SPACE - IMPERIAL FLEET', 'EXT SPACE - REBEL FLEET', 'SHUTTLE CAPTAIN', 'HAN', 'YODA', 'PILOT', 'EXT DAGOBAH SWAMP - X-WING', 'INT HEADQUARTERS FRIGATE - MAIN DOCKING BAY', 'EXT SKIFF', 'EXT FOREST - THE BIKE CHASE', 'INT BARGE OBSERVATION DECK', 'GENERAL MADINE', 'OPERATOR', 'INT MILLENNIUM FALCON - COCKPIT', 'SCOUT', 'INT IMPERIAL SHUTTLE - COCKPIT', 'EXT SAND DUNE', 'EXT EWOK VILLAGE SQUARE - NIGHT'}
# {'FOREST WALKWAY', 'SCOUT CAMPSITE', 'SARLACC PI', 'SAND DUN', 'SPAC', 'SPACE', 'BUNKER', 'DOCKING BAY', 'STOLEN IMPERIAL SHUTTLE', 'BARGE OBSERVATION DEC', 'UPPER DEC', 'DUNGEON CEL', 'EWOK VILLAGE SQUAR', 'DUNGEON CORRIDOR AND CEL', 'UPPER DECK', 'SAIL BARGE', 'DUNE SEA', 'BUNKE', 'EWOK VILLAGE SQUARE', 'DAGOBAH SWAMP', 'IMPERIAL SHUTTLE', 'SKIF', 'DUNGEON CORRIDO', 'FOREST', 'SAIL BARGE OBSERVATION DEC', 'SUPER STAR DESTROYER', 'X', 'SAIL BARG', 'MILLENNIUM FALCON', 'RANCOR PI', 'FOREST LANDING SITE', 'FOREST CLEARING', 'DEATH STA', 'THRONE ROO', 'HEADQUARTERS FRIGATE', 'DEATH STAR', 'FORES', '/INT', 'ENDOR FOREST', 'ENDOR', 'RIDG', 'REBEL STAR CRUISER', 'BOILER ROO', 'OVER STAR FIEL', 'TATOOINE SEA', 'EWOK VILLAGE', 'SKIFF', 'DUNE SE', 'ENDOR FORES', 'IMPERIAL LANDING PLATFORM', 'BARGE'}
# {'UPPER', 'SAIL', 'IMPERIAL', 'DEATH', 'DUNE', 'FOREST', 'DUNGEON', 'EWOK', 'BARGE', 'ENDOR'}
# {'GREEN LEADER', 'GUARD', 'THREEPIO', 'JERJERROD', 'FADE OUT', 'REBEL PILOT', 'ANOTHER PART OF THE FOREST', 'NINEDENINE', 'SPACE', 'LEIA', 'HOLDING TUNNEL - RANCOR PIT', 'STORMTROOPER', 'LANDO', 'Y-WING PILOT', 'COMMANDER', 'BIB', 'WEDGE', 'EMPEROR', 'BEN', 'OF THE', 'GRAY LEADER', 'ANAKIN', 'RETURN', 'CONTROL ROOM COMMANDER', 'CONTROLLER', 'NAVIGATOR', 'STRANGE VOICE', 'BUNKER COMMANDER', 'SECOND COMMANDER', 'JABBA', 'RED TWO', 'RED THREE', 'SHUTTLE CAPTAIN', 'JEDI', 'HAN', 'MON MOTHMA', 'YODA', 'BOUSHH', 'OFFICER', 'PILOT', 'VADER', 'LUKE', 'RETURN OF THE JEDI', 'GENERAL MADINE', 'OOLA', 'OPERATOR', 'SCOUT', 'PIETT', 'LURE', 'ACKBAR'}
#
# 854
# 513

# %%
def first_wookieepedia_result(query: str) -> str:
    '''Get the url of the first result when searching Wookieepedia for a query
    (best for simple names as queries, ideally generated by the llm for something like
    "Produce a input consisting of the name of the most important element in the query so that its article can be looked up")
    '''
    search_results = requests.get(f'https://starwars.fandom.com/wiki/Special:Search?query={"+".join(query.split(" "))}')
    soup = BeautifulSoup(search_results.content, 'html.parser')
    first_res = soup.find('a', class_ = 'unified-search__result__link')
    return first_res['href']

# first_wookieepedia_result('Darth Plagueis')

# %%
def save_wookieepedia_page(query, url, file_name, save_folder, error_file):
    '''Error-tolerant (hence interruptible) extraction and cleaning of Wookieepedia page's content, then saving it to save_folder\file_name (or recording failure to error_file)
    '''
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        doc = soup.find('div', id = 'content').get_text()
    
        # There probably is a very long preamble and unnecessary info at the end, however, if more than one gap then ignore and proceed with full document
        if len(parts := doc.split('\n\n\n\n\n\n\n\n\n\n\n\n\n\n \xa0 \xa0')) == 2: doc = parts[1]
        if len(parts := doc.split('\nAppearances')) == 2: doc = parts[0]
        elif len(parts := doc.split('\nSources')) == 2: doc = parts[0] # No need to check this if cut on appearances
        doc = re.sub(r'\n{2,}', '\n', doc) # And remove excessive spacing
        doc = re.sub(r'\t{2,}', '\t', doc)

        with open(os.path.join(save_folder, file_name), 'w') as file: file.write(doc)

        print(f'{query} ({url}) saved to {file_name}')
        return True
    except Exception as e:
        with open(error_file, 'a') as file: file.write(f"{query}|{url}|{file_name}\n")

        print(f'{query} failed; could not retrieve from {url}: {e}')
        return False


def scrape_wookieepedia(queries: list[str], save_folder = 'wookieepedia', done_file = 'successful_scrapes.txt', error_file = 'failed_scrapes.txt'):
    '''Error-tolerant (hence interruptible) and restartable scraping of Wookieepedia pages corresponding to the first results of searches with the given queries.
    '''
    done_file  = Path(save_folder) / 'log' / done_file
    error_file = Path(save_folder) / 'log' / error_file

    os.makedirs(save_folder, exist_ok = True)
    real_done_files = [f for f in os.listdir('wookieepedia') if f not in ['db', 'log']]

    # Check log of previously-processed queries and matching files
    if Path(done_file).is_file():
        with open(done_file, 'r') as file: done_queries, done_urls, done_files = zip(*(tuple(line.split('|')) for line in file))
    else: done_queries, done_urls, done_files = [], [], []
    done_query_index = {q: i for i, q in enumerate(done_queries)}

    for query in tqdm(set(queries) - set(done_queries)): # Technically this does not cover the queries resulting in duplicate pages, hence not optimal, but no real need for it to be
        if query in done_queries: print(f'{query} ({done_urls[(i := done_query_index[query])]}) already saved to {done_files[i]}')
        else:
            try:
                url = first_wookieepedia_result(query)
                file_name = f'{url.split("/")[-1]}.txt'.replace(':', '__')

                if file_name in real_done_files:
                    print(f'{file_name} already saved')
                else:
                    if save_wookieepedia_page(query, url, file_name, save_folder = save_folder, error_file = error_file):
                        real_done_files.append(file_name)
                        with open(done_file, 'a') as file: file.write(f"('{query}'|'{url}'|{file_name})\n") 
            except Exception as e:
                with open(error_file, 'a') as file: file.write(f"('{query}', '{url}')\n")

                print(f'{query} failed; could not generate an url: {e}')

# %%
# Populate the wookieepedia folder with cleaned page content

scrape_wookieepedia(matches_to_search)
# Out:
#   0%|          | 0/104 [00:00<?, ?it/s]
# Darth_Sidious.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Jango_Fett.txt already saved
# Space_station.txt already saved
# Sail_barge.txt already saved
# Naboo_Fighter_Pilot.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Skiff.txt already saved
# Forest.txt already saved
# Millennium_Falcon.txt already saved
# Cloud_City.txt already saved
# Boba_Fett.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Nute_Gunray.txt already saved
# Legends.txt already saved
# Anakin_Skywalker.txt already saved
# Ki-Adi-Mundi.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Padm%C3%A9_Amidala.txt already saved
# Legends.txt already saved
# Bacara.txt already saved
# Legends.txt already saved
# Cato_Neimoidia.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Bunker_Krill.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Star_Wars___Galactic_Battlegrounds.txt already saved
# Anakin_Skywalker.txt already saved
# Great_Temple.txt already saved
# KnollVision.txt already saved
# Star.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Death_Star_II_Limited.txt already saved
# Legends.txt already saved
# Endor.txt already saved
# Legends.txt already saved
# Dune_Sea.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Death_Star_II.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Anakin_Skywalker.txt already saved
# Anakin_Skywalker.txt already saved
# The_Thrawn_Trilogy_Sourcebook.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Officer.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Sail_barge.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Padm%C3%A9_Amidala.txt already saved
# Legends.txt already saved
# 1995_Topps_Star_Wars___The_Empire_Strikes_Back_Widevision.txt already saved
# Legends.txt already saved
# Anakin_Skywalker.txt already saved
# Citadel.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Star_Wars___Complete_Locations_(2005).txt already saved
# Legends.txt already saved
# Sandcrawler.txt already saved
# Legends.txt already saved
# Gantry_officer.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Jedi_Temple.txt already saved
# Legends.txt already saved
# Coruscant.txt already saved
# Anakin_Skywalker.txt already saved
# 1995_Topps_Star_Wars___The_Empire_Strikes_Back_Widevision.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Death_Star.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# TIE_fighter_series.txt already saved
# Mace_Windu.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Legends.txt already saved
# Dune_Sea.txt already saved
